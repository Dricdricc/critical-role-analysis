# %% [markdown]
# # Load Dependencies

# %%
import pandas as pds
import os
import pathlib
import re
import itertools

actorList = ['MATT', 'MARISHA', 'TRAVIS', 'LAURA', 'SAM', 'LIAM', 'ASHLEY', 'TALIESIN', 'ORION']

# %% [markdown]
# # Get Character Intros

# %%
introPath = 'FINAL TEXT FILES/zcharacter-backgrounds_FINAL.txt'
folderPath = 'data/INTROS/'

try:
    os.mkdir('data/INTROS')
    print("Directory 'data/INTROS' was created.")
    
except:
    print("Directory 'data/INTROS' already exists")

#Open the file
current_file = open(introPath, "r", encoding = 'utf8')

#Read the file
introContent = current_file.read()
current_file.close()

#Replace \n and double whitespaces with a single whitespace
introContent_noBreaks =  introContent.replace("\n", " ")
introContent_noBreaks = introContent_noBreaks.replace("  ", " ")

for actor in actorList:
    
    if actor == 'LAURA':
        searchRegex = r"({actor}((, [A-Z]+)?):\s*.*)".format(actor = actor)
    
    else:
        searchRegex = r"({actor}((, [A-Z]+)?):\s*.*?[A-Z+]:)".format(actor = actor)
        
    pattern = re.compile(searchRegex, re.MULTILINE)
    matches = re.findall(pattern, introContent_noBreaks)
    
    #If matches is an empty list, then skip.
    if len(matches) == 0:
        print('No matches for {actor}'.format(actor = actor))
        continue


    #If matches has items in list,    
    elif len(matches) > 0:

    #Flatten list of tuples with itertools

        flatMatches = list(itertools.chain(*matches))
        flatMatches = list(filter(('').__ne__, flatMatches))

        finalMatches = []

        #For each item in the list,
        for i in flatMatches:

            #Remove the <ACTOR>:'s
            fixedContent = re.sub(r"[A-Z]*:", "", i)

            #Strip the whitespace right after the text
            fixedContent = fixedContent.rstrip()

            #Append to a temporary list
            finalMatches.append(fixedContent)


        #Join list into one long string of text for that actor
        tempStr = ""
        tempStr = tempStr.join(finalMatches)
        tempStr = tempStr.strip()
        
        tempStr = tempStr.replace('Impression', 'impression')
        
        save_file = open('data/INTROS/{actor}_intro.txt'.format(actor = actor),'w+b')
        save_file.write(tempStr.encode('utf8'))
        save_file.close()

        print("Saved matches to data/INTROS/{actor}_intro.txt!".format(actor = actor))
# Out:
# Directory 'data/INTROS' already exists
# No matches for MATT
# Saved matches to data/INTROS/MARISHA_intro.txt!
# Saved matches to data/INTROS/TRAVIS_intro.txt!
# Saved matches to data/INTROS/LAURA_intro.txt!
# Saved matches to data/INTROS/SAM_intro.txt!
# Saved matches to data/INTROS/LIAM_intro.txt!
# Saved matches to data/INTROS/ASHLEY_intro.txt!
# Saved matches to data/INTROS/TALIESIN_intro.txt!
# Saved matches to data/INTROS/ORION_intro.txt!

# %% [markdown]
# # Transcripts to Corpora

# %%
folder = 'FINAL TEXT FILES'

for actor in actorList:
    #Check if folder has been created
    folderPath = 'data/ACTOR TRANSCRIPTS/{actor}'.format(actor = actor)

    try:  
        # Create directory
        os.mkdir(folderPath)
        print("Directory '{folderPath}' was created.".format(folderPath = folderPath))


    except FileExistsError:
        print("Directory '{folderPath}' already exists.".format(folderPath = folderPath))

#For each file in the folder,
for path in pathlib.Path(folder).iterdir():

    if path.is_file():
        print("\n{path}".format(path = path))
        
        #Open the file
        current_file = open(path, "r", encoding = 'utf8')
        
        #Read the file
        content = current_file.read()
        current_file.close()

        #Replace \n and double whitespaces with a single whitespace
        content_noBreaks =  content.replace("\n", " ")
        content_noBreaks = content_noBreaks.replace("  ", " ")


        #For each actor,
        for actor in actorList:
            
            #Find this specific pattern in the text and put into 'matches'
            searchRegex = r"({actor}((, [A-Z]+)?):\s*.*?[A-Z+]:)".format(actor = actor)
            pattern = re.compile(searchRegex, re.MULTILINE)
            matches = re.findall(pattern, content_noBreaks)
            
            #If matches is an empty list, then skip.
            if len(matches) == 0:
                print('No matches for {actor}'.format(actor = actor))
                continue
                
                
            #If matches has items in list,    
            elif len(matches) > 0:
                
            #Flatten list of tuples with itertools

                flatMatches = list(itertools.chain(*matches))
                flatMatches = list(filter(('').__ne__, flatMatches))

                finalMatches = []

                #For each item in the list,
                for i in flatMatches:

                    #Remove the <ACTOR>:'s
                    fixedContent = re.sub(r"[A-Z]*:", "", i)

                    #Strip the whitespace right after the text
                    fixedContent = fixedContent.rstrip()

                    #Append to a temporary list
                    finalMatches.append(fixedContent)


                #Join list into one long string of text for that actor
                tempStr = ""
                tempStr = tempStr.join(finalMatches)
                
                tempStr = tempStr.strip()

                save_file = open('data/ACTOR TRANSCRIPTS/{actor}/{filename}_{actor}.txt'.format(actor = actor, filename = path.stem), 'w+b')
                save_file.write(tempStr.encode('utf8'))
                save_file.close()

                print("Saved matches to {actor}/{filename}_{actor}.txt!".format(actor = actor, filename = path.stem))
# Out:
# Directory 'data/ACTOR TRANSCRIPTS/MATT' already exists.
# Directory 'data/ACTOR TRANSCRIPTS/MARISHA' already exists.
# Directory 'data/ACTOR TRANSCRIPTS/TRAVIS' already exists.
# Directory 'data/ACTOR TRANSCRIPTS/LAURA' already exists.
# Directory 'data/ACTOR TRANSCRIPTS/SAM' already exists.
# Directory 'data/ACTOR TRANSCRIPTS/LIAM' already exists.
# Directory 'data/ACTOR TRANSCRIPTS/ASHLEY' already exists.
# Directory 'data/ACTOR TRANSCRIPTS/TALIESIN' already exists.
# Directory 'data/ACTOR TRANSCRIPTS/ORION' already exists.
#
# FINAL TEXT FILES\C1E001_FINAL.txt
# No matches for MATT
# No matches for MARISHA
# No matches for TRAVIS
# No matches for LAURA
# No matches for SAM
# No matches for LIAM
# No matches for ASHLEY
# No matches for TALIESIN
# No matches for ORION
#
# FINAL TEXT FILES\C1E001_FINAL_V2.txt
# Saved matches to MATT/C1E001_FINAL_V2_MATT.txt!
# Saved matches to MARISHA/C1E001_FINAL_V2_MARISHA.txt!
# Saved matches to TRAVIS/C1E001_FINAL_V2_TRAVIS.txt!
# Saved matches to LAURA/C1E001_FINAL_V2_LAURA.txt!
# Saved matches to SAM/C1E001_FINAL_V2_SAM.txt!
# Saved matches to LIAM/C1E001_FINAL_V2_LIAM.txt!
# No matches for ASHLEY
# Saved matches to TALIESIN/C1E001_FINAL_V2_TALIESIN.txt!
# Saved matches to ORION/C1E001_FINAL_V2_ORION.txt!
#
# FINAL TEXT FILES\C1E002_FINAL.txt
# Saved matches to MATT/C1E002_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E002_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E002_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E002_FINAL_LAURA.txt!
# Saved matches to SAM/C1E002_FINAL_SAM.txt!
# Saved matches to LIAM/C1E002_FINAL_LIAM.txt!
# No matches for ASHLEY
# Saved matches to TALIESIN/C1E002_FINAL_TALIESIN.txt!
# Saved matches to ORION/C1E002_FINAL_ORION.txt!
#
# FINAL TEXT FILES\C1E003_FINAL.txt
# Saved matches to MATT/C1E003_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E003_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E003_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E003_FINAL_LAURA.txt!
# Saved matches to SAM/C1E003_FINAL_SAM.txt!
# Saved matches to LIAM/C1E003_FINAL_LIAM.txt!
# No matches for ASHLEY
# Saved matches to TALIESIN/C1E003_FINAL_TALIESIN.txt!
# Saved matches to ORION/C1E003_FINAL_ORION.txt!
#
# FINAL TEXT FILES\C1E004_FINAL.txt
# Saved matches to MATT/C1E004_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E004_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E004_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E004_FINAL_LAURA.txt!
# Saved matches to SAM/C1E004_FINAL_SAM.txt!
# Saved matches to LIAM/C1E004_FINAL_LIAM.txt!
# Saved matches to ASHLEY/C1E004_FINAL_ASHLEY.txt!
# Saved matches to TALIESIN/C1E004_FINAL_TALIESIN.txt!
# Saved matches to ORION/C1E004_FINAL_ORION.txt!
#
# FINAL TEXT FILES\C1E005_FINAL.txt
# Saved matches to MATT/C1E005_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E005_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E005_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E005_FINAL_LAURA.txt!
# No matches for SAM
# Saved matches to LIAM/C1E005_FINAL_LIAM.txt!
# Saved matches to ASHLEY/C1E005_FINAL_ASHLEY.txt!
# Saved matches to TALIESIN/C1E005_FINAL_TALIESIN.txt!
# Saved matches to ORION/C1E005_FINAL_ORION.txt!
#
# FINAL TEXT FILES\C1E006_FINAL.txt
# Saved matches to MATT/C1E006_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E006_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E006_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E006_FINAL_LAURA.txt!
# Saved matches to SAM/C1E006_FINAL_SAM.txt!
# Saved matches to LIAM/C1E006_FINAL_LIAM.txt!
# Saved matches to ASHLEY/C1E006_FINAL_ASHLEY.txt!
# Saved matches to TALIESIN/C1E006_FINAL_TALIESIN.txt!
# Saved matches to ORION/C1E006_FINAL_ORION.txt!
#
# FINAL TEXT FILES\C1E007_FINAL.txt
# Saved matches to MATT/C1E007_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E007_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E007_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E007_FINAL_LAURA.txt!
# Saved matches to SAM/C1E007_FINAL_SAM.txt!
# Saved matches to LIAM/C1E007_FINAL_LIAM.txt!
# Saved matches to ASHLEY/C1E007_FINAL_ASHLEY.txt!
# Saved matches to TALIESIN/C1E007_FINAL_TALIESIN.txt!
# Saved matches to ORION/C1E007_FINAL_ORION.txt!
#
# FINAL TEXT FILES\C1E008_FINAL.txt
# Saved matches to MATT/C1E008_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E008_FINAL_MARISHA.txt!
# No matches for TRAVIS
# Saved matches to LAURA/C1E008_FINAL_LAURA.txt!
# Saved matches to SAM/C1E008_FINAL_SAM.txt!
# Saved matches to LIAM/C1E008_FINAL_LIAM.txt!
# Saved matches to ASHLEY/C1E008_FINAL_ASHLEY.txt!
# Saved matches to TALIESIN/C1E008_FINAL_TALIESIN.txt!
# Saved matches to ORION/C1E008_FINAL_ORION.txt!
#
# FINAL TEXT FILES\C1E009_FINAL.txt
# Saved matches to MATT/C1E009_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E009_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E009_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E009_FINAL_LAURA.txt!
# Saved matches to SAM/C1E009_FINAL_SAM.txt!
# Saved matches to LIAM/C1E009_FINAL_LIAM.txt!
# Saved matches to ASHLEY/C1E009_FINAL_ASHLEY.txt!
# Saved matches to TALIESIN/C1E009_FINAL_TALIESIN.txt!
# Saved matches to ORION/C1E009_FINAL_ORION.txt!
#
# FINAL TEXT FILES\C1E010_FINAL.txt
# Saved matches to MATT/C1E010_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E010_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E010_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E010_FINAL_LAURA.txt!
# Saved matches to SAM/C1E010_FINAL_SAM.txt!
# Saved matches to LIAM/C1E010_FINAL_LIAM.txt!
# Saved matches to ASHLEY/C1E010_FINAL_ASHLEY.txt!
# Saved matches to TALIESIN/C1E010_FINAL_TALIESIN.txt!
# Saved matches to ORION/C1E010_FINAL_ORION.txt!
#
# FINAL TEXT FILES\C1E011_FINAL.txt
# Saved matches to MATT/C1E011_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E011_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E011_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E011_FINAL_LAURA.txt!
# Saved matches to SAM/C1E011_FINAL_SAM.txt!
# Saved matches to LIAM/C1E011_FINAL_LIAM.txt!
# Saved matches to ASHLEY/C1E011_FINAL_ASHLEY.txt!
# Saved matches to TALIESIN/C1E011_FINAL_TALIESIN.txt!
# Saved matches to ORION/C1E011_FINAL_ORION.txt!
#
# FINAL TEXT FILES\C1E012_FINAL.txt
# Saved matches to MATT/C1E012_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E012_FINAL_MARISHA.txt!
# No matches for TRAVIS
# No matches for LAURA
# No matches for SAM
# Saved matches to LIAM/C1E012_FINAL_LIAM.txt!
# No matches for ASHLEY
# Saved matches to TALIESIN/C1E012_FINAL_TALIESIN.txt!
# Saved matches to ORION/C1E012_FINAL_ORION.txt!
#
# FINAL TEXT FILES\C1E013_FINAL.txt
# Saved matches to MATT/C1E013_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E013_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E013_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E013_FINAL_LAURA.txt!
# Saved matches to SAM/C1E013_FINAL_SAM.txt!
# Saved matches to LIAM/C1E013_FINAL_LIAM.txt!
# Saved matches to ASHLEY/C1E013_FINAL_ASHLEY.txt!
# Saved matches to TALIESIN/C1E013_FINAL_TALIESIN.txt!
# Saved matches to ORION/C1E013_FINAL_ORION.txt!
#
# FINAL TEXT FILES\C1E014_FINAL.txt
# Saved matches to MATT/C1E014_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E014_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E014_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E014_FINAL_LAURA.txt!
# No matches for SAM
# Saved matches to LIAM/C1E014_FINAL_LIAM.txt!
# Saved matches to ASHLEY/C1E014_FINAL_ASHLEY.txt!
# Saved matches to TALIESIN/C1E014_FINAL_TALIESIN.txt!
# Saved matches to ORION/C1E014_FINAL_ORION.txt!
#
# FINAL TEXT FILES\C1E015-FINAL.txt
# Saved matches to MATT/C1E015-FINAL_MATT.txt!
# Saved matches to MARISHA/C1E015-FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E015-FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E015-FINAL_LAURA.txt!
# Saved matches to SAM/C1E015-FINAL_SAM.txt!
# Saved matches to LIAM/C1E015-FINAL_LIAM.txt!
# Saved matches to ASHLEY/C1E015-FINAL_ASHLEY.txt!
# Saved matches to TALIESIN/C1E015-FINAL_TALIESIN.txt!
# Saved matches to ORION/C1E015-FINAL_ORION.txt!
#
# FINAL TEXT FILES\C1E015_FINAL.txt
# Saved matches to MATT/C1E015_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E015_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E015_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E015_FINAL_LAURA.txt!
# Saved matches to SAM/C1E015_FINAL_SAM.txt!
# Saved matches to LIAM/C1E015_FINAL_LIAM.txt!
# Saved matches to ASHLEY/C1E015_FINAL_ASHLEY.txt!
# Saved matches to TALIESIN/C1E015_FINAL_TALIESIN.txt!
# Saved matches to ORION/C1E015_FINAL_ORION.txt!
#
# FINAL TEXT FILES\C1E016_FINAL.txt
# Saved matches to MATT/C1E016_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E016_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E016_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E016_FINAL_LAURA.txt!
# Saved matches to SAM/C1E016_FINAL_SAM.txt!
# Saved matches to LIAM/C1E016_FINAL_LIAM.txt!
# Saved matches to ASHLEY/C1E016_FINAL_ASHLEY.txt!
# Saved matches to TALIESIN/C1E016_FINAL_TALIESIN.txt!
# Saved matches to ORION/C1E016_FINAL_ORION.txt!
#
# FINAL TEXT FILES\C1E017_FINAL.txt
# Saved matches to MATT/C1E017_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E017_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E017_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E017_FINAL_LAURA.txt!
# Saved matches to SAM/C1E017_FINAL_SAM.txt!
# Saved matches to LIAM/C1E017_FINAL_LIAM.txt!
# Saved matches to ASHLEY/C1E017_FINAL_ASHLEY.txt!
# Saved matches to TALIESIN/C1E017_FINAL_TALIESIN.txt!
# Saved matches to ORION/C1E017_FINAL_ORION.txt!
#
# FINAL TEXT FILES\C1E018_FINAL.txt
# Saved matches to MATT/C1E018_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E018_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E018_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E018_FINAL_LAURA.txt!
# Saved matches to SAM/C1E018_FINAL_SAM.txt!
# Saved matches to LIAM/C1E018_FINAL_LIAM.txt!
# No matches for ASHLEY
# Saved matches to TALIESIN/C1E018_FINAL_TALIESIN.txt!
# Saved matches to ORION/C1E018_FINAL_ORION.txt!
#
# FINAL TEXT FILES\C1E019_FINAL.txt
# Saved matches to MATT/C1E019_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E019_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E019_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E019_FINAL_LAURA.txt!
# Saved matches to SAM/C1E019_FINAL_SAM.txt!
# No matches for LIAM
# No matches for ASHLEY
# Saved matches to TALIESIN/C1E019_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E020_FINAL.txt
# Saved matches to MATT/C1E020_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E020_FINAL_MARISHA.txt!
# No matches for TRAVIS
# No matches for LAURA
# No matches for SAM
# Saved matches to LIAM/C1E020_FINAL_LIAM.txt!
# No matches for ASHLEY
# No matches for TALIESIN
# Saved matches to ORION/C1E020_FINAL_ORION.txt!
#
# FINAL TEXT FILES\C1E021_FINAL.txt
# Saved matches to MATT/C1E021_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E021_FINAL_MARISHA.txt!
# No matches for TRAVIS
# No matches for LAURA
# No matches for SAM
# Saved matches to LIAM/C1E021_FINAL_LIAM.txt!
# No matches for ASHLEY
# Saved matches to TALIESIN/C1E021_FINAL_TALIESIN.txt!
# Saved matches to ORION/C1E021_FINAL_ORION.txt!
#
# FINAL TEXT FILES\C1E022_FINAL.txt
# Saved matches to MATT/C1E022_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E022_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E022_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E022_FINAL_LAURA.txt!
# No matches for SAM
# Saved matches to LIAM/C1E022_FINAL_LIAM.txt!
# Saved matches to ASHLEY/C1E022_FINAL_ASHLEY.txt!
# Saved matches to TALIESIN/C1E022_FINAL_TALIESIN.txt!
# Saved matches to ORION/C1E022_FINAL_ORION.txt!
#
# FINAL TEXT FILES\C1E023_FINAL.txt
# Saved matches to MATT/C1E023_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E023_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E023_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E023_FINAL_LAURA.txt!
# Saved matches to SAM/C1E023_FINAL_SAM.txt!
# Saved matches to LIAM/C1E023_FINAL_LIAM.txt!
# No matches for ASHLEY
# Saved matches to TALIESIN/C1E023_FINAL_TALIESIN.txt!
# Saved matches to ORION/C1E023_FINAL_ORION.txt!
#
# FINAL TEXT FILES\C1E024_FINAL.txt
# Saved matches to MATT/C1E024_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E024_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E024_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E024_FINAL_LAURA.txt!
# Saved matches to SAM/C1E024_FINAL_SAM.txt!
# Saved matches to LIAM/C1E024_FINAL_LIAM.txt!
# No matches for ASHLEY
# Saved matches to TALIESIN/C1E024_FINAL_TALIESIN.txt!
# Saved matches to ORION/C1E024_FINAL_ORION.txt!
#
# FINAL TEXT FILES\C1E025_FINAL.txt
# Saved matches to MATT/C1E025_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E025_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E025_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E025_FINAL_LAURA.txt!
# Saved matches to SAM/C1E025_FINAL_SAM.txt!
# Saved matches to LIAM/C1E025_FINAL_LIAM.txt!
# No matches for ASHLEY
# Saved matches to TALIESIN/C1E025_FINAL_TALIESIN.txt!
# Saved matches to ORION/C1E025_FINAL_ORION.txt!
#
# FINAL TEXT FILES\C1E026_FINAL.txt
# Saved matches to MATT/C1E026_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E026_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E026_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E026_FINAL_LAURA.txt!
# Saved matches to SAM/C1E026_FINAL_SAM.txt!
# Saved matches to LIAM/C1E026_FINAL_LIAM.txt!
# No matches for ASHLEY
# No matches for TALIESIN
# Saved matches to ORION/C1E026_FINAL_ORION.txt!
#
# FINAL TEXT FILES\C1E027_FINAL.txt
# Saved matches to MATT/C1E027_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E027_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E027_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E027_FINAL_LAURA.txt!
# Saved matches to SAM/C1E027_FINAL_SAM.txt!
# Saved matches to LIAM/C1E027_FINAL_LIAM.txt!
# No matches for ASHLEY
# Saved matches to TALIESIN/C1E027_FINAL_TALIESIN.txt!
# Saved matches to ORION/C1E027_FINAL_ORION.txt!
#
# FINAL TEXT FILES\C1E028_FINAL.txt
# Saved matches to MATT/C1E028_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E028_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E028_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E028_FINAL_LAURA.txt!
# Saved matches to SAM/C1E028_FINAL_SAM.txt!
# Saved matches to LIAM/C1E028_FINAL_LIAM.txt!
# No matches for ASHLEY
# Saved matches to TALIESIN/C1E028_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E029_FINAL.txt
# Saved matches to MATT/C1E029_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E029_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E029_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E029_FINAL_LAURA.txt!
# Saved matches to SAM/C1E029_FINAL_SAM.txt!
# Saved matches to LIAM/C1E029_FINAL_LIAM.txt!
# No matches for ASHLEY
# Saved matches to TALIESIN/C1E029_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E030_FINAL.txt
# Saved matches to MATT/C1E030_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E030_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E030_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E030_FINAL_LAURA.txt!
# Saved matches to SAM/C1E030_FINAL_SAM.txt!
# Saved matches to LIAM/C1E030_FINAL_LIAM.txt!
# No matches for ASHLEY
# Saved matches to TALIESIN/C1E030_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E031-1_FINAL.txt
# Saved matches to MATT/C1E031-1_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E031-1_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E031-1_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E031-1_FINAL_LAURA.txt!
# Saved matches to SAM/C1E031-1_FINAL_SAM.txt!
# Saved matches to LIAM/C1E031-1_FINAL_LIAM.txt!
# No matches for ASHLEY
# Saved matches to TALIESIN/C1E031-1_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E031-2_FINAL.txt
# Saved matches to MATT/C1E031-2_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E031-2_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E031-2_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E031-2_FINAL_LAURA.txt!
# Saved matches to SAM/C1E031-2_FINAL_SAM.txt!
# Saved matches to LIAM/C1E031-2_FINAL_LIAM.txt!
# No matches for ASHLEY
# Saved matches to TALIESIN/C1E031-2_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E032_FINAL.txt
# Saved matches to MATT/C1E032_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E032_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E032_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E032_FINAL_LAURA.txt!
# Saved matches to SAM/C1E032_FINAL_SAM.txt!
# Saved matches to LIAM/C1E032_FINAL_LIAM.txt!
# Saved matches to ASHLEY/C1E032_FINAL_ASHLEY.txt!
# Saved matches to TALIESIN/C1E032_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E033-1_FINAL.txt
# Saved matches to MATT/C1E033-1_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E033-1_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E033-1_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E033-1_FINAL_LAURA.txt!
# Saved matches to SAM/C1E033-1_FINAL_SAM.txt!
# Saved matches to LIAM/C1E033-1_FINAL_LIAM.txt!
# No matches for ASHLEY
# Saved matches to TALIESIN/C1E033-1_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E033-2_FINAL.txt
# Saved matches to MATT/C1E033-2_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E033-2_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E033-2_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E033-2_FINAL_LAURA.txt!
# Saved matches to SAM/C1E033-2_FINAL_SAM.txt!
# Saved matches to LIAM/C1E033-2_FINAL_LIAM.txt!
# No matches for ASHLEY
# Saved matches to TALIESIN/C1E033-2_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E034_FINAL.txt
# Saved matches to MATT/C1E034_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E034_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E034_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E034_FINAL_LAURA.txt!
# Saved matches to SAM/C1E034_FINAL_SAM.txt!
# Saved matches to LIAM/C1E034_FINAL_LIAM.txt!
# Saved matches to ASHLEY/C1E034_FINAL_ASHLEY.txt!
# Saved matches to TALIESIN/C1E034_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E035-1_FINAL.txt
# Saved matches to MATT/C1E035-1_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E035-1_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E035-1_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E035-1_FINAL_LAURA.txt!
# Saved matches to SAM/C1E035-1_FINAL_SAM.txt!
# Saved matches to LIAM/C1E035-1_FINAL_LIAM.txt!
# Saved matches to ASHLEY/C1E035-1_FINAL_ASHLEY.txt!
# Saved matches to TALIESIN/C1E035-1_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E035-2_FINAL.txt
# Saved matches to MATT/C1E035-2_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E035-2_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E035-2_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E035-2_FINAL_LAURA.txt!
# Saved matches to SAM/C1E035-2_FINAL_SAM.txt!
# Saved matches to LIAM/C1E035-2_FINAL_LIAM.txt!
# Saved matches to ASHLEY/C1E035-2_FINAL_ASHLEY.txt!
# Saved matches to TALIESIN/C1E035-2_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E036_FINAL.txt
# Saved matches to MATT/C1E036_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E036_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E036_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E036_FINAL_LAURA.txt!
# Saved matches to SAM/C1E036_FINAL_SAM.txt!
# Saved matches to LIAM/C1E036_FINAL_LIAM.txt!
# Saved matches to ASHLEY/C1E036_FINAL_ASHLEY.txt!
# Saved matches to TALIESIN/C1E036_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E037_FINAL.txt
# Saved matches to MATT/C1E037_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E037_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E037_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E037_FINAL_LAURA.txt!
# Saved matches to SAM/C1E037_FINAL_SAM.txt!
# Saved matches to LIAM/C1E037_FINAL_LIAM.txt!
# Saved matches to ASHLEY/C1E037_FINAL_ASHLEY.txt!
# Saved matches to TALIESIN/C1E037_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E038_FINAL.txt
# Saved matches to MATT/C1E038_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E038_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E038_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E038_FINAL_LAURA.txt!
# Saved matches to SAM/C1E038_FINAL_SAM.txt!
# Saved matches to LIAM/C1E038_FINAL_LIAM.txt!
# Saved matches to ASHLEY/C1E038_FINAL_ASHLEY.txt!
# Saved matches to TALIESIN/C1E038_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E039_FINAL.txt
# Saved matches to MATT/C1E039_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E039_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E039_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E039_FINAL_LAURA.txt!
# Saved matches to SAM/C1E039_FINAL_SAM.txt!
# Saved matches to LIAM/C1E039_FINAL_LIAM.txt!
# No matches for ASHLEY
# Saved matches to TALIESIN/C1E039_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E040_FINAL.txt
# Saved matches to MATT/C1E040_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E040_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E040_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E040_FINAL_LAURA.txt!
# No matches for SAM
# Saved matches to LIAM/C1E040_FINAL_LIAM.txt!
# Saved matches to ASHLEY/C1E040_FINAL_ASHLEY.txt!
# Saved matches to TALIESIN/C1E040_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E041_FINAL.txt
# Saved matches to MATT/C1E041_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E041_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E041_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E041_FINAL_LAURA.txt!
# Saved matches to SAM/C1E041_FINAL_SAM.txt!
# Saved matches to LIAM/C1E041_FINAL_LIAM.txt!
# Saved matches to ASHLEY/C1E041_FINAL_ASHLEY.txt!
# Saved matches to TALIESIN/C1E041_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E042_FINAL.txt
# Saved matches to MATT/C1E042_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E042_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E042_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E042_FINAL_LAURA.txt!
# Saved matches to SAM/C1E042_FINAL_SAM.txt!
# Saved matches to LIAM/C1E042_FINAL_LIAM.txt!
# No matches for ASHLEY
# Saved matches to TALIESIN/C1E042_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E043_FINAL.txt
# Saved matches to MATT/C1E043_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E043_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E043_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E043_FINAL_LAURA.txt!
# Saved matches to SAM/C1E043_FINAL_SAM.txt!
# Saved matches to LIAM/C1E043_FINAL_LIAM.txt!
# No matches for ASHLEY
# Saved matches to TALIESIN/C1E043_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E044_FINAL.txt
# Saved matches to MATT/C1E044_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E044_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E044_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E044_FINAL_LAURA.txt!
# Saved matches to SAM/C1E044_FINAL_SAM.txt!
# Saved matches to LIAM/C1E044_FINAL_LIAM.txt!
# No matches for ASHLEY
# Saved matches to TALIESIN/C1E044_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E045_FINAL.txt
# Saved matches to MATT/C1E045_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E045_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E045_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E045_FINAL_LAURA.txt!
# Saved matches to SAM/C1E045_FINAL_SAM.txt!
# Saved matches to LIAM/C1E045_FINAL_LIAM.txt!
# No matches for ASHLEY
# Saved matches to TALIESIN/C1E045_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E046_FINAL.txt
# Saved matches to MATT/C1E046_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E046_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E046_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E046_FINAL_LAURA.txt!
# Saved matches to SAM/C1E046_FINAL_SAM.txt!
# Saved matches to LIAM/C1E046_FINAL_LIAM.txt!
# No matches for ASHLEY
# Saved matches to TALIESIN/C1E046_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E047_FINAL.txt
# Saved matches to MATT/C1E047_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E047_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E047_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E047_FINAL_LAURA.txt!
# Saved matches to SAM/C1E047_FINAL_SAM.txt!
# Saved matches to LIAM/C1E047_FINAL_LIAM.txt!
# No matches for ASHLEY
# Saved matches to TALIESIN/C1E047_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E048_FINAL.txt
# Saved matches to MATT/C1E048_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E048_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E048_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E048_FINAL_LAURA.txt!
# Saved matches to SAM/C1E048_FINAL_SAM.txt!
# Saved matches to LIAM/C1E048_FINAL_LIAM.txt!
# Saved matches to ASHLEY/C1E048_FINAL_ASHLEY.txt!
# Saved matches to TALIESIN/C1E048_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E049-5_FINAL.txt
# Saved matches to MATT/C1E049-5_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E049-5_FINAL_MARISHA.txt!
# No matches for TRAVIS
# No matches for LAURA
# No matches for SAM
# No matches for LIAM
# No matches for ASHLEY
# Saved matches to TALIESIN/C1E049-5_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E049_FINAL.txt
# Saved matches to MATT/C1E049_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E049_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E049_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E049_FINAL_LAURA.txt!
# Saved matches to SAM/C1E049_FINAL_SAM.txt!
# Saved matches to LIAM/C1E049_FINAL_LIAM.txt!
# No matches for ASHLEY
# Saved matches to TALIESIN/C1E049_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E050_FINAL.txt
# Saved matches to MATT/C1E050_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E050_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E050_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E050_FINAL_LAURA.txt!
# Saved matches to SAM/C1E050_FINAL_SAM.txt!
# Saved matches to LIAM/C1E050_FINAL_LIAM.txt!
# Saved matches to ASHLEY/C1E050_FINAL_ASHLEY.txt!
# Saved matches to TALIESIN/C1E050_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E051_FINAL.txt
# Saved matches to MATT/C1E051_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E051_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E051_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E051_FINAL_LAURA.txt!
# Saved matches to SAM/C1E051_FINAL_SAM.txt!
# Saved matches to LIAM/C1E051_FINAL_LIAM.txt!
# Saved matches to ASHLEY/C1E051_FINAL_ASHLEY.txt!
# Saved matches to TALIESIN/C1E051_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E052_FINAL.txt
# Saved matches to MATT/C1E052_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E052_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E052_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E052_FINAL_LAURA.txt!
# Saved matches to SAM/C1E052_FINAL_SAM.txt!
# Saved matches to LIAM/C1E052_FINAL_LIAM.txt!
# Saved matches to ASHLEY/C1E052_FINAL_ASHLEY.txt!
# Saved matches to TALIESIN/C1E052_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E053_FINAL.txt
# Saved matches to MATT/C1E053_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E053_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E053_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E053_FINAL_LAURA.txt!
# Saved matches to SAM/C1E053_FINAL_SAM.txt!
# Saved matches to LIAM/C1E053_FINAL_LIAM.txt!
# Saved matches to ASHLEY/C1E053_FINAL_ASHLEY.txt!
# Saved matches to TALIESIN/C1E053_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E054_FINAL.txt
# Saved matches to MATT/C1E054_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E054_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E054_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E054_FINAL_LAURA.txt!
# Saved matches to SAM/C1E054_FINAL_SAM.txt!
# Saved matches to LIAM/C1E054_FINAL_LIAM.txt!
# Saved matches to ASHLEY/C1E054_FINAL_ASHLEY.txt!
# Saved matches to TALIESIN/C1E054_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E055_FINAL.txt
# Saved matches to MATT/C1E055_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E055_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E055_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E055_FINAL_LAURA.txt!
# Saved matches to SAM/C1E055_FINAL_SAM.txt!
# Saved matches to LIAM/C1E055_FINAL_LIAM.txt!
# Saved matches to ASHLEY/C1E055_FINAL_ASHLEY.txt!
# Saved matches to TALIESIN/C1E055_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E056_FINAL.txt
# Saved matches to MATT/C1E056_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E056_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E056_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E056_FINAL_LAURA.txt!
# Saved matches to SAM/C1E056_FINAL_SAM.txt!
# Saved matches to LIAM/C1E056_FINAL_LIAM.txt!
# Saved matches to ASHLEY/C1E056_FINAL_ASHLEY.txt!
# Saved matches to TALIESIN/C1E056_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E057_FINAL.txt
# Saved matches to MATT/C1E057_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E057_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E057_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E057_FINAL_LAURA.txt!
# Saved matches to SAM/C1E057_FINAL_SAM.txt!
# Saved matches to LIAM/C1E057_FINAL_LIAM.txt!
# Saved matches to ASHLEY/C1E057_FINAL_ASHLEY.txt!
# Saved matches to TALIESIN/C1E057_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E058-5_FINAL.txt
# No matches for MATT
# No matches for MARISHA
# Saved matches to TRAVIS/C1E058-5_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E058-5_FINAL_LAURA.txt!
# Saved matches to SAM/C1E058-5_FINAL_SAM.txt!
# Saved matches to LIAM/C1E058-5_FINAL_LIAM.txt!
# No matches for ASHLEY
# Saved matches to TALIESIN/C1E058-5_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E058_FINAL.txt
# Saved matches to MATT/C1E058_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E058_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E058_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E058_FINAL_LAURA.txt!
# Saved matches to SAM/C1E058_FINAL_SAM.txt!
# Saved matches to LIAM/C1E058_FINAL_LIAM.txt!
# Saved matches to ASHLEY/C1E058_FINAL_ASHLEY.txt!
# Saved matches to TALIESIN/C1E058_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E059_FINAL.txt
# Saved matches to MATT/C1E059_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E059_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E059_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E059_FINAL_LAURA.txt!
# Saved matches to SAM/C1E059_FINAL_SAM.txt!
# Saved matches to LIAM/C1E059_FINAL_LIAM.txt!
# Saved matches to ASHLEY/C1E059_FINAL_ASHLEY.txt!
# Saved matches to TALIESIN/C1E059_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E060_FINAL.txt
# Saved matches to MATT/C1E060_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E060_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E060_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E060_FINAL_LAURA.txt!
# Saved matches to SAM/C1E060_FINAL_SAM.txt!
# Saved matches to LIAM/C1E060_FINAL_LIAM.txt!
# No matches for ASHLEY
# Saved matches to TALIESIN/C1E060_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E061_FINAL.txt
# Saved matches to MATT/C1E061_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E061_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E061_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E061_FINAL_LAURA.txt!
# Saved matches to SAM/C1E061_FINAL_SAM.txt!
# Saved matches to LIAM/C1E061_FINAL_LIAM.txt!
# No matches for ASHLEY
# Saved matches to TALIESIN/C1E061_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E062_FINAL.txt
# Saved matches to MATT/C1E062_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E062_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E062_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E062_FINAL_LAURA.txt!
# Saved matches to SAM/C1E062_FINAL_SAM.txt!
# No matches for LIAM
# Saved matches to ASHLEY/C1E062_FINAL_ASHLEY.txt!
# Saved matches to TALIESIN/C1E062_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E063_FINAL.txt
# Saved matches to MATT/C1E063_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E063_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E063_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E063_FINAL_LAURA.txt!
# Saved matches to SAM/C1E063_FINAL_SAM.txt!
# Saved matches to LIAM/C1E063_FINAL_LIAM.txt!
# No matches for ASHLEY
# Saved matches to TALIESIN/C1E063_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E064_FINAL.txt
# Saved matches to MATT/C1E064_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E064_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E064_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E064_FINAL_LAURA.txt!
# Saved matches to SAM/C1E064_FINAL_SAM.txt!
# Saved matches to LIAM/C1E064_FINAL_LIAM.txt!
# No matches for ASHLEY
# Saved matches to TALIESIN/C1E064_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E065-5_FINAL.txt
# No matches for MATT
# No matches for MARISHA
# Saved matches to TRAVIS/C1E065-5_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E065-5_FINAL_LAURA.txt!
# Saved matches to SAM/C1E065-5_FINAL_SAM.txt!
# Saved matches to LIAM/C1E065-5_FINAL_LIAM.txt!
# No matches for ASHLEY
# No matches for TALIESIN
# No matches for ORION
#
# FINAL TEXT FILES\C1E065_FINAL.txt
# Saved matches to MATT/C1E065_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E065_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E065_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E065_FINAL_LAURA.txt!
# Saved matches to SAM/C1E065_FINAL_SAM.txt!
# Saved matches to LIAM/C1E065_FINAL_LIAM.txt!
# No matches for ASHLEY
# Saved matches to TALIESIN/C1E065_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E066_FINAL.txt
# Saved matches to MATT/C1E066_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E066_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E066_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E066_FINAL_LAURA.txt!
# Saved matches to SAM/C1E066_FINAL_SAM.txt!
# Saved matches to LIAM/C1E066_FINAL_LIAM.txt!
# No matches for ASHLEY
# Saved matches to TALIESIN/C1E066_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E067_FINAL.txt
# Saved matches to MATT/C1E067_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E067_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E067_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E067_FINAL_LAURA.txt!
# Saved matches to SAM/C1E067_FINAL_SAM.txt!
# Saved matches to LIAM/C1E067_FINAL_LIAM.txt!
# No matches for ASHLEY
# Saved matches to TALIESIN/C1E067_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E068_FINAL.txt
# Saved matches to MATT/C1E068_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E068_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E068_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E068_FINAL_LAURA.txt!
# Saved matches to SAM/C1E068_FINAL_SAM.txt!
# Saved matches to LIAM/C1E068_FINAL_LIAM.txt!
# No matches for ASHLEY
# Saved matches to TALIESIN/C1E068_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E069_FINAL.txt
# Saved matches to MATT/C1E069_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E069_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E069_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E069_FINAL_LAURA.txt!
# Saved matches to SAM/C1E069_FINAL_SAM.txt!
# Saved matches to LIAM/C1E069_FINAL_LIAM.txt!
# Saved matches to ASHLEY/C1E069_FINAL_ASHLEY.txt!
# Saved matches to TALIESIN/C1E069_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E070_FINAL.txt
# Saved matches to MATT/C1E070_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E070_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E070_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E070_FINAL_LAURA.txt!
# Saved matches to SAM/C1E070_FINAL_SAM.txt!
# Saved matches to LIAM/C1E070_FINAL_LIAM.txt!
# No matches for ASHLEY
# Saved matches to TALIESIN/C1E070_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E071_FINAL.txt
# Saved matches to MATT/C1E071_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E071_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E071_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E071_FINAL_LAURA.txt!
# Saved matches to SAM/C1E071_FINAL_SAM.txt!
# Saved matches to LIAM/C1E071_FINAL_LIAM.txt!
# Saved matches to ASHLEY/C1E071_FINAL_ASHLEY.txt!
# Saved matches to TALIESIN/C1E071_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E072_FINAL.txt
# Saved matches to MATT/C1E072_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E072_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E072_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E072_FINAL_LAURA.txt!
# Saved matches to SAM/C1E072_FINAL_SAM.txt!
# Saved matches to LIAM/C1E072_FINAL_LIAM.txt!
# No matches for ASHLEY
# Saved matches to TALIESIN/C1E072_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E073_FINAL.txt
# Saved matches to MATT/C1E073_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E073_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E073_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E073_FINAL_LAURA.txt!
# Saved matches to SAM/C1E073_FINAL_SAM.txt!
# Saved matches to LIAM/C1E073_FINAL_LIAM.txt!
# No matches for ASHLEY
# Saved matches to TALIESIN/C1E073_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E074_FINAL.txt
# Saved matches to MATT/C1E074_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E074_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E074_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E074_FINAL_LAURA.txt!
# Saved matches to SAM/C1E074_FINAL_SAM.txt!
# Saved matches to LIAM/C1E074_FINAL_LIAM.txt!
# Saved matches to ASHLEY/C1E074_FINAL_ASHLEY.txt!
# Saved matches to TALIESIN/C1E074_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E075_FINAL.txt
# Saved matches to MATT/C1E075_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E075_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E075_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E075_FINAL_LAURA.txt!
# Saved matches to SAM/C1E075_FINAL_SAM.txt!
# Saved matches to LIAM/C1E075_FINAL_LIAM.txt!
# Saved matches to ASHLEY/C1E075_FINAL_ASHLEY.txt!
# Saved matches to TALIESIN/C1E075_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E076_FINAL.txt
# Saved matches to MATT/C1E076_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E076_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E076_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E076_FINAL_LAURA.txt!
# Saved matches to SAM/C1E076_FINAL_SAM.txt!
# Saved matches to LIAM/C1E076_FINAL_LIAM.txt!
# Saved matches to ASHLEY/C1E076_FINAL_ASHLEY.txt!
# Saved matches to TALIESIN/C1E076_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E077_FINAL.txt
# Saved matches to MATT/C1E077_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E077_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E077_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E077_FINAL_LAURA.txt!
# Saved matches to SAM/C1E077_FINAL_SAM.txt!
# Saved matches to LIAM/C1E077_FINAL_LIAM.txt!
# Saved matches to ASHLEY/C1E077_FINAL_ASHLEY.txt!
# Saved matches to TALIESIN/C1E077_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E078_FINAL.txt
# Saved matches to MATT/C1E078_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E078_FINAL_MARISHA.txt!
# No matches for TRAVIS
# Saved matches to LAURA/C1E078_FINAL_LAURA.txt!
# Saved matches to SAM/C1E078_FINAL_SAM.txt!
# Saved matches to LIAM/C1E078_FINAL_LIAM.txt!
# No matches for ASHLEY
# Saved matches to TALIESIN/C1E078_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E079_FINAL.txt
# Saved matches to MATT/C1E079_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E079_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E079_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E079_FINAL_LAURA.txt!
# Saved matches to SAM/C1E079_FINAL_SAM.txt!
# Saved matches to LIAM/C1E079_FINAL_LIAM.txt!
# No matches for ASHLEY
# Saved matches to TALIESIN/C1E079_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E080_FINAL.txt
# Saved matches to MATT/C1E080_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E080_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E080_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E080_FINAL_LAURA.txt!
# Saved matches to SAM/C1E080_FINAL_SAM.txt!
# Saved matches to LIAM/C1E080_FINAL_LIAM.txt!
# No matches for ASHLEY
# Saved matches to TALIESIN/C1E080_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E081_FINAL.txt
# Saved matches to MATT/C1E081_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E081_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E081_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E081_FINAL_LAURA.txt!
# Saved matches to SAM/C1E081_FINAL_SAM.txt!
# Saved matches to LIAM/C1E081_FINAL_LIAM.txt!
# No matches for ASHLEY
# Saved matches to TALIESIN/C1E081_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E082_FINAL.txt
# Saved matches to MATT/C1E082_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E082_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E082_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E082_FINAL_LAURA.txt!
# No matches for SAM
# Saved matches to LIAM/C1E082_FINAL_LIAM.txt!
# No matches for ASHLEY
# Saved matches to TALIESIN/C1E082_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E083_FINAL.txt
# Saved matches to MATT/C1E083_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E083_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E083_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E083_FINAL_LAURA.txt!
# Saved matches to SAM/C1E083_FINAL_SAM.txt!
# Saved matches to LIAM/C1E083_FINAL_LIAM.txt!
# No matches for ASHLEY
# Saved matches to TALIESIN/C1E083_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E084_FINAL.txt
# Saved matches to MATT/C1E084_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E084_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E084_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E084_FINAL_LAURA.txt!
# Saved matches to SAM/C1E084_FINAL_SAM.txt!
# Saved matches to LIAM/C1E084_FINAL_LIAM.txt!
# Saved matches to ASHLEY/C1E084_FINAL_ASHLEY.txt!
# Saved matches to TALIESIN/C1E084_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E085_FINAL.txt
# Saved matches to MATT/C1E085_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E085_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E085_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E085_FINAL_LAURA.txt!
# Saved matches to SAM/C1E085_FINAL_SAM.txt!
# Saved matches to LIAM/C1E085_FINAL_LIAM.txt!
# No matches for ASHLEY
# Saved matches to TALIESIN/C1E085_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E086_FINAL.txt
# Saved matches to MATT/C1E086_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E086_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E086_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E086_FINAL_LAURA.txt!
# Saved matches to SAM/C1E086_FINAL_SAM.txt!
# Saved matches to LIAM/C1E086_FINAL_LIAM.txt!
# No matches for ASHLEY
# Saved matches to TALIESIN/C1E086_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E087_FINAL.txt
# Saved matches to MATT/C1E087_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E087_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E087_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E087_FINAL_LAURA.txt!
# Saved matches to SAM/C1E087_FINAL_SAM.txt!
# Saved matches to LIAM/C1E087_FINAL_LIAM.txt!
# No matches for ASHLEY
# Saved matches to TALIESIN/C1E087_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E088_FINAL.txt
# Saved matches to MATT/C1E088_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E088_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E088_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E088_FINAL_LAURA.txt!
# Saved matches to SAM/C1E088_FINAL_SAM.txt!
# Saved matches to LIAM/C1E088_FINAL_LIAM.txt!
# No matches for ASHLEY
# Saved matches to TALIESIN/C1E088_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E089_FINAL.txt
# Saved matches to MATT/C1E089_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E089_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E089_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E089_FINAL_LAURA.txt!
# Saved matches to SAM/C1E089_FINAL_SAM.txt!
# Saved matches to LIAM/C1E089_FINAL_LIAM.txt!
# Saved matches to ASHLEY/C1E089_FINAL_ASHLEY.txt!
# Saved matches to TALIESIN/C1E089_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E090_FINAL.txt
# Saved matches to MATT/C1E090_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E090_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E090_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E090_FINAL_LAURA.txt!
# Saved matches to SAM/C1E090_FINAL_SAM.txt!
# Saved matches to LIAM/C1E090_FINAL_LIAM.txt!
# No matches for ASHLEY
# Saved matches to TALIESIN/C1E090_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E091_FINAL.txt
# Saved matches to MATT/C1E091_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E091_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E091_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E091_FINAL_LAURA.txt!
# No matches for SAM
# Saved matches to LIAM/C1E091_FINAL_LIAM.txt!
# No matches for ASHLEY
# Saved matches to TALIESIN/C1E091_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E092_FINAL.txt
# Saved matches to MATT/C1E092_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E092_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E092_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E092_FINAL_LAURA.txt!
# Saved matches to SAM/C1E092_FINAL_SAM.txt!
# Saved matches to LIAM/C1E092_FINAL_LIAM.txt!
# No matches for ASHLEY
# Saved matches to TALIESIN/C1E092_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E093_FINAL.txt
# Saved matches to MATT/C1E093_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E093_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E093_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E093_FINAL_LAURA.txt!
# Saved matches to SAM/C1E093_FINAL_SAM.txt!
# Saved matches to LIAM/C1E093_FINAL_LIAM.txt!
# No matches for ASHLEY
# Saved matches to TALIESIN/C1E093_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E094.5_FINAL.txt
# Saved matches to MATT/C1E094.5_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E094.5_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E094.5_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E094.5_FINAL_LAURA.txt!
# Saved matches to SAM/C1E094.5_FINAL_SAM.txt!
# Saved matches to LIAM/C1E094.5_FINAL_LIAM.txt!
# Saved matches to ASHLEY/C1E094.5_FINAL_ASHLEY.txt!
# Saved matches to TALIESIN/C1E094.5_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E094_FINAL.txt
# Saved matches to MATT/C1E094_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E094_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E094_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E094_FINAL_LAURA.txt!
# Saved matches to SAM/C1E094_FINAL_SAM.txt!
# Saved matches to LIAM/C1E094_FINAL_LIAM.txt!
# Saved matches to ASHLEY/C1E094_FINAL_ASHLEY.txt!
# Saved matches to TALIESIN/C1E094_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E095_FINAL.txt
# Saved matches to MATT/C1E095_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E095_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E095_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E095_FINAL_LAURA.txt!
# Saved matches to SAM/C1E095_FINAL_SAM.txt!
# Saved matches to LIAM/C1E095_FINAL_LIAM.txt!
# Saved matches to ASHLEY/C1E095_FINAL_ASHLEY.txt!
# Saved matches to TALIESIN/C1E095_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E096_FINAL.txt
# Saved matches to MATT/C1E096_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E096_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E096_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E096_FINAL_LAURA.txt!
# Saved matches to SAM/C1E096_FINAL_SAM.txt!
# Saved matches to LIAM/C1E096_FINAL_LIAM.txt!
# Saved matches to ASHLEY/C1E096_FINAL_ASHLEY.txt!
# Saved matches to TALIESIN/C1E096_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E097_FINAL.txt
# Saved matches to MATT/C1E097_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E097_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E097_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E097_FINAL_LAURA.txt!
# Saved matches to SAM/C1E097_FINAL_SAM.txt!
# Saved matches to LIAM/C1E097_FINAL_LIAM.txt!
# Saved matches to ASHLEY/C1E097_FINAL_ASHLEY.txt!
# Saved matches to TALIESIN/C1E097_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E098-5_FINAL.txt
# Saved matches to MATT/C1E098-5_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E098-5_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E098-5_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E098-5_FINAL_LAURA.txt!
# Saved matches to SAM/C1E098-5_FINAL_SAM.txt!
# No matches for LIAM
# No matches for ASHLEY
# Saved matches to TALIESIN/C1E098-5_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E098_FINAL.txt
# Saved matches to MATT/C1E098_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E098_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E098_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E098_FINAL_LAURA.txt!
# Saved matches to SAM/C1E098_FINAL_SAM.txt!
# Saved matches to LIAM/C1E098_FINAL_LIAM.txt!
# Saved matches to ASHLEY/C1E098_FINAL_ASHLEY.txt!
# Saved matches to TALIESIN/C1E098_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E099_FINAL.txt
# Saved matches to MATT/C1E099_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E099_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E099_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E099_FINAL_LAURA.txt!
# Saved matches to SAM/C1E099_FINAL_SAM.txt!
# Saved matches to LIAM/C1E099_FINAL_LIAM.txt!
# Saved matches to ASHLEY/C1E099_FINAL_ASHLEY.txt!
# Saved matches to TALIESIN/C1E099_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E100_FINAL.txt
# Saved matches to MATT/C1E100_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E100_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E100_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E100_FINAL_LAURA.txt!
# Saved matches to SAM/C1E100_FINAL_SAM.txt!
# Saved matches to LIAM/C1E100_FINAL_LIAM.txt!
# Saved matches to ASHLEY/C1E100_FINAL_ASHLEY.txt!
# Saved matches to TALIESIN/C1E100_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E101_FINAL.txt
# Saved matches to MATT/C1E101_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E101_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E101_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E101_FINAL_LAURA.txt!
# Saved matches to SAM/C1E101_FINAL_SAM.txt!
# Saved matches to LIAM/C1E101_FINAL_LIAM.txt!
# Saved matches to ASHLEY/C1E101_FINAL_ASHLEY.txt!
# Saved matches to TALIESIN/C1E101_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E102_FINAL.txt
# Saved matches to MATT/C1E102_FINAL_MATT.txt!
# Saved matches to MARISHA/C1E102_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/C1E102_FINAL_TRAVIS.txt!
# Saved matches to LAURA/C1E102_FINAL_LAURA.txt!
# Saved matches to SAM/C1E102_FINAL_SAM.txt!
# Saved matches to LIAM/C1E102_FINAL_LIAM.txt!
# Saved matches to ASHLEY/C1E102_FINAL_ASHLEY.txt!
# Saved matches to TALIESIN/C1E102_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\C1E103_FINAL.txt
# Saved matches to MATT/C1E103_FINAL_MATT.txt!
# ...
# No matches for ASHLEY
# No matches for TALIESIN
# No matches for ORION
#
# FINAL TEXT FILES\CR-Scope_Critical Role RPGs  Tabletop Renaissance w Matt Mercer  Paradise City Comic Con SPOILERS C2E1.en.txt
# Saved matches to MATT/CR-Scope_Critical Role RPGs  Tabletop Renaissance w Matt Mercer  Paradise City Comic Con SPOILERS C2E1.en_MATT.txt!
# No matches for MARISHA
# No matches for TRAVIS
# No matches for LAURA
# No matches for SAM
# No matches for LIAM
# No matches for ASHLEY
# No matches for TALIESIN
# No matches for ORION
#
# FINAL TEXT FILES\CR-Scope_Critical Role Talks Machina style w Matt Taliesin Laura Sam  GenCon2017 SPOILERS E108.en.txt
# Saved matches to MATT/CR-Scope_Critical Role Talks Machina style w Matt Taliesin Laura Sam  GenCon2017 SPOILERS E108.en_MATT.txt!
# Saved matches to MARISHA/CR-Scope_Critical Role Talks Machina style w Matt Taliesin Laura Sam  GenCon2017 SPOILERS E108.en_MARISHA.txt!
# Saved matches to TRAVIS/CR-Scope_Critical Role Talks Machina style w Matt Taliesin Laura Sam  GenCon2017 SPOILERS E108.en_TRAVIS.txt!
# Saved matches to LAURA/CR-Scope_Critical Role Talks Machina style w Matt Taliesin Laura Sam  GenCon2017 SPOILERS E108.en_LAURA.txt!
# Saved matches to SAM/CR-Scope_Critical Role Talks Machina style w Matt Taliesin Laura Sam  GenCon2017 SPOILERS E108.en_SAM.txt!
# Saved matches to LIAM/CR-Scope_Critical Role Talks Machina style w Matt Taliesin Laura Sam  GenCon2017 SPOILERS E108.en_LIAM.txt!
# Saved matches to ASHLEY/CR-Scope_Critical Role Talks Machina style w Matt Taliesin Laura Sam  GenCon2017 SPOILERS E108.en_ASHLEY.txt!
# Saved matches to TALIESIN/CR-Scope_Critical Role Talks Machina style w Matt Taliesin Laura Sam  GenCon2017 SPOILERS E108.en_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\CR-Scope_Critical Role Talks Machina Style with Matt Marisha Taliesin  Brian  MomoCon 2017 Spoilers E98.en.txt
# Saved matches to MATT/CR-Scope_Critical Role Talks Machina Style with Matt Marisha Taliesin  Brian  MomoCon 2017 Spoilers E98.en_MATT.txt!
# Saved matches to MARISHA/CR-Scope_Critical Role Talks Machina Style with Matt Marisha Taliesin  Brian  MomoCon 2017 Spoilers E98.en_MARISHA.txt!
# No matches for TRAVIS
# Saved matches to LAURA/CR-Scope_Critical Role Talks Machina Style with Matt Marisha Taliesin  Brian  MomoCon 2017 Spoilers E98.en_LAURA.txt!
# No matches for SAM
# Saved matches to LIAM/CR-Scope_Critical Role Talks Machina Style with Matt Marisha Taliesin  Brian  MomoCon 2017 Spoilers E98.en_LIAM.txt!
# No matches for ASHLEY
# Saved matches to TALIESIN/CR-Scope_Critical Role Talks Machina Style with Matt Marisha Taliesin  Brian  MomoCon 2017 Spoilers E98.en_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\CR-Scope_Critical Roles Critmas Talks Machina.en.txt
# Saved matches to MATT/CR-Scope_Critical Roles Critmas Talks Machina.en_MATT.txt!
# Saved matches to MARISHA/CR-Scope_Critical Roles Critmas Talks Machina.en_MARISHA.txt!
# Saved matches to TRAVIS/CR-Scope_Critical Roles Critmas Talks Machina.en_TRAVIS.txt!
# Saved matches to LAURA/CR-Scope_Critical Roles Critmas Talks Machina.en_LAURA.txt!
# Saved matches to SAM/CR-Scope_Critical Roles Critmas Talks Machina.en_SAM.txt!
# Saved matches to LIAM/CR-Scope_Critical Roles Critmas Talks Machina.en_LIAM.txt!
# No matches for ASHLEY
# Saved matches to TALIESIN/CR-Scope_Critical Roles Critmas Talks Machina.en_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\CR-Scope_Critical Roles Impromptu QA during technical difficulties at GeekSundry Spoilers E50.en.txt
# Saved matches to MATT/CR-Scope_Critical Roles Impromptu QA during technical difficulties at GeekSundry Spoilers E50.en_MATT.txt!
# Saved matches to MARISHA/CR-Scope_Critical Roles Impromptu QA during technical difficulties at GeekSundry Spoilers E50.en_MARISHA.txt!
# Saved matches to TRAVIS/CR-Scope_Critical Roles Impromptu QA during technical difficulties at GeekSundry Spoilers E50.en_TRAVIS.txt!
# Saved matches to LAURA/CR-Scope_Critical Roles Impromptu QA during technical difficulties at GeekSundry Spoilers E50.en_LAURA.txt!
# Saved matches to SAM/CR-Scope_Critical Roles Impromptu QA during technical difficulties at GeekSundry Spoilers E50.en_SAM.txt!
# Saved matches to LIAM/CR-Scope_Critical Roles Impromptu QA during technical difficulties at GeekSundry Spoilers E50.en_LIAM.txt!
# Saved matches to ASHLEY/CR-Scope_Critical Roles Impromptu QA during technical difficulties at GeekSundry Spoilers E50.en_ASHLEY.txt!
# Saved matches to TALIESIN/CR-Scope_Critical Roles Impromptu QA during technical difficulties at GeekSundry Spoilers E50.en_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\CR-Scope_Critical Roles Matthew Mercer  Marisha Ray 2015 11 26 Part 1 of 4 SPOILERS E33.en.txt
# Saved matches to MATT/CR-Scope_Critical Roles Matthew Mercer  Marisha Ray 2015 11 26 Part 1 of 4 SPOILERS E33.en_MATT.txt!
# Saved matches to MARISHA/CR-Scope_Critical Roles Matthew Mercer  Marisha Ray 2015 11 26 Part 1 of 4 SPOILERS E33.en_MARISHA.txt!
# No matches for TRAVIS
# No matches for LAURA
# No matches for SAM
# No matches for LIAM
# No matches for ASHLEY
# No matches for TALIESIN
# No matches for ORION
#
# FINAL TEXT FILES\CR-Scope_Critical Roles Matthew Mercer  Marisha Ray 2015 11 26 Part 3 of 4 SPOILERS E33.en.txt
# Saved matches to MATT/CR-Scope_Critical Roles Matthew Mercer  Marisha Ray 2015 11 26 Part 3 of 4 SPOILERS E33.en_MATT.txt!
# Saved matches to MARISHA/CR-Scope_Critical Roles Matthew Mercer  Marisha Ray 2015 11 26 Part 3 of 4 SPOILERS E33.en_MARISHA.txt!
# No matches for TRAVIS
# No matches for LAURA
# No matches for SAM
# No matches for LIAM
# No matches for ASHLEY
# No matches for TALIESIN
# No matches for ORION
#
# FINAL TEXT FILES\CR-Scope_Critical Roles Matthew Mercer  Marisha Ray 2015 11 26 Part 4 of 4 SPOILERS E33.en.txt
# Saved matches to MATT/CR-Scope_Critical Roles Matthew Mercer  Marisha Ray 2015 11 26 Part 4 of 4 SPOILERS E33.en_MATT.txt!
# Saved matches to MARISHA/CR-Scope_Critical Roles Matthew Mercer  Marisha Ray 2015 11 26 Part 4 of 4 SPOILERS E33.en_MARISHA.txt!
# No matches for TRAVIS
# No matches for LAURA
# No matches for SAM
# No matches for LIAM
# No matches for ASHLEY
# No matches for TALIESIN
# No matches for ORION
#
# FINAL TEXT FILES\CR-Scope_Full Post 2016 Holiday Critmas gifts  hangout w Marisha Matt Taliesin  Brian SPOILERS E81.en.txt
# Saved matches to MATT/CR-Scope_Full Post 2016 Holiday Critmas gifts  hangout w Marisha Matt Taliesin  Brian SPOILERS E81.en_MATT.txt!
# Saved matches to MARISHA/CR-Scope_Full Post 2016 Holiday Critmas gifts  hangout w Marisha Matt Taliesin  Brian SPOILERS E81.en_MARISHA.txt!
# No matches for TRAVIS
# No matches for LAURA
# No matches for SAM
# No matches for LIAM
# No matches for ASHLEY
# Saved matches to TALIESIN/CR-Scope_Full Post 2016 Holiday Critmas gifts  hangout w Marisha Matt Taliesin  Brian SPOILERS E81.en_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\CR-Scope_Liam  Travis secret plan to win the fight in E52 Spoilers E52.en.txt
# Saved matches to MATT/CR-Scope_Liam  Travis secret plan to win the fight in E52 Spoilers E52.en_MATT.txt!
# No matches for MARISHA
# Saved matches to TRAVIS/CR-Scope_Liam  Travis secret plan to win the fight in E52 Spoilers E52.en_TRAVIS.txt!
# Saved matches to LAURA/CR-Scope_Liam  Travis secret plan to win the fight in E52 Spoilers E52.en_LAURA.txt!
# No matches for SAM
# Saved matches to LIAM/CR-Scope_Liam  Travis secret plan to win the fight in E52 Spoilers E52.en_LIAM.txt!
# Saved matches to ASHLEY/CR-Scope_Liam  Travis secret plan to win the fight in E52 Spoilers E52.en_ASHLEY.txt!
# No matches for TALIESIN
# No matches for ORION
#
# FINAL TEXT FILES\CR-Scope_Liam Obriens first time on Periscope - QA SPOILERS E37.en.txt
# No matches for MATT
# No matches for MARISHA
# No matches for TRAVIS
# No matches for LAURA
# No matches for SAM
# No matches for LIAM
# No matches for ASHLEY
# No matches for TALIESIN
# No matches for ORION
#
# FINAL TEXT FILES\CR-Scope_Liam OBriens missing Periscope  QA 2016-04-27 Spoilers E50.en.txt
# No matches for MATT
# No matches for MARISHA
# No matches for TRAVIS
# No matches for LAURA
# No matches for SAM
# No matches for LIAM
# No matches for ASHLEY
# No matches for TALIESIN
# No matches for ORION
#
# FINAL TEXT FILES\CR-Scope_Matt  Marisha at MAGfest 2017 Maryland Spoilers E80.en.txt
# Saved matches to MATT/CR-Scope_Matt  Marisha at MAGfest 2017 Maryland Spoilers E80.en_MATT.txt!
# Saved matches to MARISHA/CR-Scope_Matt  Marisha at MAGfest 2017 Maryland Spoilers E80.en_MARISHA.txt!
# No matches for TRAVIS
# No matches for LAURA
# No matches for SAM
# No matches for LIAM
# No matches for ASHLEY
# No matches for TALIESIN
# No matches for ORION
#
# FINAL TEXT FILES\CR-Scope_Matthew Mercer  Marisha Ray - The Vestiges of Critmas Unpacking  QA  Home Spoilers E51.en.txt
# Saved matches to MATT/CR-Scope_Matthew Mercer  Marisha Ray - The Vestiges of Critmas Unpacking  QA  Home Spoilers E51.en_MATT.txt!
# Saved matches to MARISHA/CR-Scope_Matthew Mercer  Marisha Ray - The Vestiges of Critmas Unpacking  QA  Home Spoilers E51.en_MARISHA.txt!
# No matches for TRAVIS
# No matches for LAURA
# No matches for SAM
# No matches for LIAM
# No matches for ASHLEY
# No matches for TALIESIN
# No matches for ORION
#
# FINAL TEXT FILES\CR-Scope_Matthew Mercer E52 Impromptu Post-game discussion Spoilers E52.en.txt
# No matches for MATT
# No matches for MARISHA
# No matches for TRAVIS
# No matches for LAURA
# No matches for SAM
# No matches for LIAM
# No matches for ASHLEY
# No matches for TALIESIN
# No matches for ORION
#
# FINAL TEXT FILES\CR-Scope_momocon.txt
# Saved matches to MATT/CR-Scope_momocon_MATT.txt!
# No matches for MARISHA
# No matches for TRAVIS
# No matches for LAURA
# No matches for SAM
# No matches for LIAM
# Saved matches to ASHLEY/CR-Scope_momocon_ASHLEY.txt!
# No matches for TALIESIN
# No matches for ORION
#
# FINAL TEXT FILES\CR-Scope_panel w Matt Marisha Laura  Travis  AnimeMilwaukee 2017 Spoilers E86.en.txt
# Saved matches to MATT/CR-Scope_panel w Matt Marisha Laura  Travis  AnimeMilwaukee 2017 Spoilers E86.en_MATT.txt!
# Saved matches to MARISHA/CR-Scope_panel w Matt Marisha Laura  Travis  AnimeMilwaukee 2017 Spoilers E86.en_MARISHA.txt!
# Saved matches to TRAVIS/CR-Scope_panel w Matt Marisha Laura  Travis  AnimeMilwaukee 2017 Spoilers E86.en_TRAVIS.txt!
# Saved matches to LAURA/CR-Scope_panel w Matt Marisha Laura  Travis  AnimeMilwaukee 2017 Spoilers E86.en_LAURA.txt!
# No matches for SAM
# No matches for LIAM
# No matches for ASHLEY
# No matches for TALIESIN
# No matches for ORION
#
# FINAL TEXT FILES\CR-Scope_Panel with Matt  Taliesin  Another Anime Con 2016 Manchester NH Spoilers E71.en.txt
# Saved matches to MATT/CR-Scope_Panel with Matt  Taliesin  Another Anime Con 2016 Manchester NH Spoilers E71.en_MATT.txt!
# No matches for MARISHA
# No matches for TRAVIS
# No matches for LAURA
# No matches for SAM
# No matches for LIAM
# No matches for ASHLEY
# Saved matches to TALIESIN/CR-Scope_Panel with Matt  Taliesin  Another Anime Con 2016 Manchester NH Spoilers E71.en_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\CR-Scope_Part 2 of Matthew Mercer  Marisha Rays Post-Critmas Mini Unboxing  Gen thank you Spoilers E41.en.txt
# Saved matches to MATT/CR-Scope_Part 2 of Matthew Mercer  Marisha Rays Post-Critmas Mini Unboxing  Gen thank you Spoilers E41.en_MATT.txt!
# Saved matches to MARISHA/CR-Scope_Part 2 of Matthew Mercer  Marisha Rays Post-Critmas Mini Unboxing  Gen thank you Spoilers E41.en_MARISHA.txt!
# No matches for TRAVIS
# No matches for LAURA
# No matches for SAM
# No matches for LIAM
# No matches for ASHLEY
# No matches for TALIESIN
# No matches for ORION
#
# FINAL TEXT FILES\CR-Scope_Percy  Taliesin Jaffes first Periscope - QA 2015-11-19 RE UPLOAD SPOILERS E32.en.txt
# No matches for MATT
# No matches for MARISHA
# No matches for TRAVIS
# No matches for LAURA
# No matches for SAM
# No matches for LIAM
# No matches for ASHLEY
# No matches for TALIESIN
# No matches for ORION
#
# FINAL TEXT FILES\CR-Scope_Short Periscope before the start of Critical Role E54 Spoilers E54.en.txt
# Saved matches to MATT/CR-Scope_Short Periscope before the start of Critical Role E54 Spoilers E54.en_MATT.txt!
# Saved matches to MARISHA/CR-Scope_Short Periscope before the start of Critical Role E54 Spoilers E54.en_MARISHA.txt!
# Saved matches to TRAVIS/CR-Scope_Short Periscope before the start of Critical Role E54 Spoilers E54.en_TRAVIS.txt!
# Saved matches to LAURA/CR-Scope_Short Periscope before the start of Critical Role E54 Spoilers E54.en_LAURA.txt!
# Saved matches to SAM/CR-Scope_Short Periscope before the start of Critical Role E54 Spoilers E54.en_SAM.txt!
# Saved matches to LIAM/CR-Scope_Short Periscope before the start of Critical Role E54 Spoilers E54.en_LIAM.txt!
# Saved matches to ASHLEY/CR-Scope_Short Periscope before the start of Critical Role E54 Spoilers E54.en_ASHLEY.txt!
# Saved matches to TALIESIN/CR-Scope_Short Periscope before the start of Critical Role E54 Spoilers E54.en_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\CR-Scope_UPDATED Critical Role Panel  WonderCon LA Full Length SPOILERS E46.en.txt
# Saved matches to MATT/CR-Scope_UPDATED Critical Role Panel  WonderCon LA Full Length SPOILERS E46.en_MATT.txt!
# Saved matches to MARISHA/CR-Scope_UPDATED Critical Role Panel  WonderCon LA Full Length SPOILERS E46.en_MARISHA.txt!
# Saved matches to TRAVIS/CR-Scope_UPDATED Critical Role Panel  WonderCon LA Full Length SPOILERS E46.en_TRAVIS.txt!
# Saved matches to LAURA/CR-Scope_UPDATED Critical Role Panel  WonderCon LA Full Length SPOILERS E46.en_LAURA.txt!
# No matches for SAM
# No matches for LIAM
# No matches for ASHLEY
# Saved matches to TALIESIN/CR-Scope_UPDATED Critical Role Panel  WonderCon LA Full Length SPOILERS E46.en_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\CR-Scope_Wizard World Portland Day 1.en.txt
# Saved matches to MATT/CR-Scope_Wizard World Portland Day 1.en_MATT.txt!
# Saved matches to MARISHA/CR-Scope_Wizard World Portland Day 1.en_MARISHA.txt!
# Saved matches to TRAVIS/CR-Scope_Wizard World Portland Day 1.en_TRAVIS.txt!
# Saved matches to LAURA/CR-Scope_Wizard World Portland Day 1.en_LAURA.txt!
# Saved matches to SAM/CR-Scope_Wizard World Portland Day 1.en_SAM.txt!
# No matches for LIAM
# No matches for ASHLEY
# Saved matches to TALIESIN/CR-Scope_Wizard World Portland Day 1.en_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\Honey Heist 3 Tovas Honeys.en.txt
# No matches for MATT
# Saved matches to MARISHA/Honey Heist 3 Tovas Honeys.en_MARISHA.txt!
# No matches for TRAVIS
# Saved matches to LAURA/Honey Heist 3 Tovas Honeys.en_LAURA.txt!
# No matches for SAM
# No matches for LIAM
# No matches for ASHLEY
# No matches for TALIESIN
# No matches for ORION
#
# FINAL TEXT FILES\zcharacter-backgrounds_FINAL.txt
# No matches for MATT
# Saved matches to MARISHA/zcharacter-backgrounds_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/zcharacter-backgrounds_FINAL_TRAVIS.txt!
# No matches for LAURA
# Saved matches to SAM/zcharacter-backgrounds_FINAL_SAM.txt!
# Saved matches to LIAM/zcharacter-backgrounds_FINAL_LIAM.txt!
# Saved matches to ASHLEY/zcharacter-backgrounds_FINAL_ASHLEY.txt!
# Saved matches to TALIESIN/zcharacter-backgrounds_FINAL_TALIESIN.txt!
# Saved matches to ORION/zcharacter-backgrounds_FINAL_ORION.txt!
#
# FINAL TEXT FILES\zEP125_FINAL.txt
# Saved matches to MATT/zEP125_FINAL_MATT.txt!
# Saved matches to MARISHA/zEP125_FINAL_MARISHA.txt!
# Saved matches to TRAVIS/zEP125_FINAL_TRAVIS.txt!
# Saved matches to LAURA/zEP125_FINAL_LAURA.txt!
# Saved matches to SAM/zEP125_FINAL_SAM.txt!
# Saved matches to LIAM/zEP125_FINAL_LIAM.txt!
# Saved matches to ASHLEY/zEP125_FINAL_ASHLEY.txt!
# Saved matches to TALIESIN/zEP125_FINAL_TALIESIN.txt!
# No matches for ORION
#
# FINAL TEXT FILES\zGM-TIPS_1.txt
# No matches for MATT
# No matches for MARISHA
# No matches for TRAVIS
# No matches for LAURA
# No matches for SAM
# No matches for LIAM
# No matches for ASHLEY
# No matches for TALIESIN
# No matches for ORION
#
# FINAL TEXT FILES\zstory-of-VM_captions.txt
# No matches for MATT
# No matches for MARISHA
# No matches for TRAVIS
# No matches for LAURA
# No matches for SAM
# No matches for LIAM
# No matches for ASHLEY
# No matches for TALIESIN
# No matches for ORION
#
# FINAL TEXT FILES\ztwitter_description.txt
# No matches for MATT
# No matches for MARISHA
# No matches for TRAVIS
# No matches for LAURA
# No matches for SAM
# No matches for LIAM
# No matches for ASHLEY
# No matches for TALIESIN
# No matches for ORION

# %%
folder = 'FINAL TEXT FILES'



current_file = open('FINAL TEXT FILES\C1E065_FINAL.txt', "r", encoding = 'utf8')
content = current_file.read()
current_file.close()

content_noBreaks =  content.replace("\n", " ")
content_noBreaks = content_noBreaks.replace("  ", " ")

matches = re.findall(pattern, content_noBreaks)
matches
# Out:
# [("MATT: Hello, everyone, and welcome to tonight's episode of Critical Role, where Taliesin jumps the gun and says his phrase too late. TRAVIS:",
#   '',
#   ''),
#  ("MATT: Welcome. Happy to be back. Very emotional episode last week. We're going to kick it into the next step of Vox Machina's adventure this week, and then, me, Marisha, and Taliesin will be gone next week, so there will not be progression in this current storyline. However, Liam O'Brien over there has been cracking up an awesome one-shot adventure for our remaining players and a few guests. Liam, if you want to talk a little about it? LIAM:",
#   '',
#   ''),
#  ("MATT: Yeah, it's going to be fun. This is Liam's brainchild, and I'm excited to see them play through it. LIAM:",
#   '',
#   ''),
#  ("MATT: I think you'll be fine. If the last game was any indication, I think you'll be fine. All right, other announcements: once again, we have our wonderful sponsor with a new theme kicking in. Sam, you want to take this away? SAM:",
#   '',
#   ''),
#  ('MATT: All right, thank you, Sam. SAM:', '', ''),
#  ("MATT: Perfect. (laughs) All right, other announcements that we have. Let's see. Projects that have come up. They recently announced and put up the English cast video for Final Fantasy XV. I have the pleasure of playing Cor Leonis. It's a lot of fun. As a longtime Final Fantasy fan, being a part of this means a great deal, and I'm excited for the game that comes out in November. So if you haven't checked out the video, do so and you can watch me wax poetic briefly about my love of the series. Look forward to that. MARISHA:",
#   '',
#   ''),
#  ('MATT: Yeah, man! They chose my soundbite for the end of it. I was like (explosion). Felt cool about that. MARISHA:',
#   '',
#   ''),
#  ("MATT: It's like I played a bunch of them. Also, Deus Ex came out. Mankind Divided. I am scattered throughout the game with a very harsh Russian, Eastern European dialect, as many characters, probably yelling at you or being shot in the face. So enjoy that, as well. TRAVIS:",
#   '',
#   ''),
#  ("MATT: Hey, you know? Everyone's got a skillset. Anybody else have anything they want to announce? SAM:",
#   '',
#   ''),
#  ("MATT: That's right! We just got nominated for a Streamy. A Streamy award under gaming. Games. It's awesome! SAM:",
#   '',
#   ''),
#  ('MATT: It is now decided by whatever the Illuminati Streamy committee is. SAM:',
#   '',
#   ''),
#  ("MATT: Love you, Mark. We're just excited to be in that ring. Thank you guys for being so awesome and supporting us, and hopefully some of us will get to dress up fancy and show up and go home proud that we went. TALIESIN:",
#   '',
#   ''),
#  ("MATT: And Muzzled the Musical, which I co-created, which Ashly Burch stars in, who you'll see next week, that got nominated for best indie. MARISHA:",
#   '',
#   ''),
#  ("MATT: It's good. Awesome. Anything else you guys want to talk about? TRAVIS:",
#   '',
#   ''),
#  ('MATT: Anyone else have anything they want to talk about before we jump into the game? TALIESIN:',
#   '',
#   ''),
#  ("MATT: All righty. That being the case, then let's go ahead and hop into tonight's episode of Critical Role. [dramatic music] MATT:",
#   '',
#   ''),
#  ('MATT: All right, so. Vox Machina. Taking your time to mourn in your own interesting ways. What is your path of action? What is your course, going forward? LIAM:',
#   '',
#   ''),
#  ('MATT: Okay. So you\'ve all spent the majority of it in your respective rooms-- most of you in your respective rooms-- figuring out where you are as a person and where this story leads you. After an evening\'s rest, the next morning comes around, breakfast is already prepared by the servants in the castle, though maybe not the amount of bacon you were hoping, and easily rectified upon request. It\'s at your disposal. There is a tension in the city; the barrier remains up. As you\'re having breakfast, you can see Zahra wander in at the smell of bacon, glances over the rest of you, still holding a book at her side that she slams closed. "Oh. I\'m glad to see you\'re all "right, and you\'re safe. Please tell me there\'s more bacon." TRAVIS:',
#   '',
#   ''),
#  ('MATT: She comes and sits down and spends breakfast with you guys, catching up on what has transpired and what your current plan of action is. TALIESIN:',
#   '',
#   ''),
#  ('MATT: "Kind of. Let\'s just say we\'re estranged at the moment." TALIESIN:',
#   '',
#   ''),
#  ('MATT: "You will find no allies where you\'re asking. Believe me, I\'d be happy to offer if we "could, but no." TALIESIN:',
#   '',
#   ''),
#  ('MATT: "It\'s all right. I\'m going to continue with my research, since the rest of the ziggurat clan "are now scattered about or maintaining that barrier. Guess who has to do the research in the "meantime?" And she rolls her sleeves up; you can see the slightly smudged dirt across her reddish skin. She\'s been hard at work digging around trying to figure out what the basis of this enchantment beneath the city still is. LAURA:',
#   '',
#   ''),
#  ('MATT: "I\'m certain time will allow me at some point. It better. I\'m going a little stir-crazy." She grabs the bacon from the table and walks out of the room. TALIESIN:',
#   '',
#   ''),
#  ('MATT: "I\'m sorry, what?" TALIESIN:', '', ''),
#  ('MATT: "I haven\'t seen him for a couple days. I\'ve been underground most of the time." TALIESIN:',
#   '',
#   ''),
#  ("MATT: It's actually a sigil by memory that he has, and it's a spell that he casts. It's not a permanent fixture in the city. TALIESIN:",
#   '',
#   ''),
#  ("MATT: It's a renewal feature. He has to spend some time each day maintaining it. He's not stuck there the whole time. SAM:",
#   '',
#   ''),
#  ('MATT: Roll an intelligence check. MARISHA:', '', ''),
#  ("MATT: That's what they look like. LAURA:", '', ''),
#  ("MATT: They're huge. Most definitely. They're nasty; they burrow. The actual blood within their body is heated to such a degree that even to be in a scuffle with it is to scar yourself with flame and heat. SAM:",
#   '',
#   ''),
#  ("MATT: You guys head outside of Castle Whitestone. Not far from the base of the pathway into the actual city, you can see there is a series of newer-outfitted guards. They are people being trained in the force of combat. You can see that there's definitely a ramping-up of the defense force for Whitestone as a precaution. MARISHA:",
#   '',
#   ''),
#  ('MATT: Many of them look able-bodied and people that are strong and fit, but they do appear to be civilians that have had to take up the cause just in case. MARISHA:',
#   '',
#   ''),
#  ('MATT: No kids, no. They all look to be at least of strapping age, to be carrying a weapon. SAM:',
#   '',
#   ''),
#  ("MATT: As you are watching the group go through their different weapon practice moments, they're breaking off into small sparring groups and they're going up against ramshackle built training dummies. There are a few that are doing forms in succession. (grunts) You know the deal. You do see on the opposite end that the person who is currently helming one section of the training is Kashaw. You can see a bunch of shield and spear fighters right now, and he's basically giving them instruction on how to use a shield defensively and the spear offensively simultaneously. LAURA:",
#   '',
#   ''),
#  ('MATT: As you approach, you see him leaning in with younger, early twenties-looking men. A bit scrawny; they\'re still armored; the helmet looks a little lopsided. Kashaw\'s like, "You\'re not "supposed to put the shield away. (sighs) Oh, wonderful. Take five. Take 30. So. You\'re alive. "That\'s great. I\'m excited. What can I do for you?" TALIESIN:',
#   '',
#   ''),
#  ('MATT: "Depends on where and what you\'d have me doing." TALIESIN:', '', ''),
#  ('MATT: "So you\'re saying that I go back to frozen-ass Vasselheim to deliver a paper message "to the headmistress, whom already I am so happy to be away from." MARISHA:',
#   '',
#   ''),
#  ('MATT: He glances over at the rest of the soldiers. "Yeah, I\'ll take it." (laughter) LAURA:',
#   '',
#   ''),
#  ('MATT: "I\'ll do my best to muster some semblance of emphasis." TALIESIN:',
#   '',
#   ''),
#  ('MATT: "All right. Give me a list of what you\'ve got to offer. I\'ll bring it to them." TALIESIN:',
#   '',
#   ''),
#  ('MATT: Make a check. LIAM:', '', ''),
#  ("MATT: As you're having this conversation, (whack) right in the knee cap, a surprisingly painful and forceful blow. It's less the strength behind it and more the precision in which it strikes you right between the kneecap and the rest of the lower half of your knee. TRAVIS:",
#   '',
#   ''),
#  ("MATT: Yeah, and you're like (grunts) and you glance over and you see Vax hide a wooden sword quickly behind him as he backs away. LIAM:",
#   '',
#   ''),
#  ("MATT: Roll a strength check. Actually, this time it's an attack roll, as well. MARISHA:",
#   '',
#   ''),
#  ("MATT: You're not proficient with a sword. LIAM:", '', ''),
#  ('MATT: (laughs) You whack him. This time, it hits the meat of his thigh and has no effect. LIAM:',
#   '',
#   ''),
#  ('MATT: Okay, roll an attack roll. LIAM:', '', ''),
#  ("MATT: Before this happens, as you're getting up, you watch as Vax rears back, and as he throws it, (yelps) he pulls a muscle in his shoulder and it drops to the ground, and you're like (pained noises). LAURA:",
#   '',
#   ''),
#  ('MATT: Make a persuasion check. TALIESIN:', '', ''),
#  ('MATT: You watch as roughly 45 armored soldiers all turn towards you with their shields and spears... and freeze. They all slowly look towards Scanlan and whisper among themselves, then look back at Grog and stay frozen and two creep forward for a minute. Get a little closer. TRAVIS:',
#   '',
#   ''),
#  ('MATT: As your form swells into your now enlarged goliath battle-ready form, you notice a few of them start giving off this rattling metal sound as their armored knees (clanging) together. Many of them step back about ten feet, and Kashaw, who hasn\'t left entirely, spins around and goes: "The "gnome\'s fucking with you. It\'s fine!" He walks up to you, Scanlan, pats your arm and goes, "That was "pretty funny." SAM:',
#   '',
#   ''),
#  ('MATT: "Don\'t get the people killed. I\'ve been working on them for four days." SAM:',
#   '',
#   ''),
#  ("MATT: Well, we'll see. Go ahead and roll an attack roll. TRAVIS:", '', ''),
#  ('MATT: Roll a strength check. LIAM:', '', ''),
#  ('MATT: Okay. TRAVIS:', '', ''),
#  ('MATT: Roll again because he used a Luck point to force you to reroll your attack roll. TRAVIS:',
#   '',
#   ''),
#  ('MATT: What was the strength roll again? TRAVIS:', '', ''),
#  ('MATT: Strength check was 24. So as you peek out of the corner of your eye you hear this (heavy steps) and as you try and spin and dodge out of the way instinctually-- LIAM:',
#   '',
#   ''),
#  ("MATT: I know and we'll get to that. Instinctually, you turn to dodge out of something Grog-sized, not giant-sized. And in that brief minute that you remember that he grew, you pause just long enough to (whack) feel the force of what feels like a giant battering ram slam into your side, sending you off your feet and arcing a good 30 feet before you (impact) tumble and skid to the ground. What's your strength modifier? TRAVIS:",
#   '',
#   ''),
#  ("MATT: Seven. You take 14 points of bludgeoning damage, reduced to half because you're taking Uncanny Dodge. So only seven points bludgeoning damage. You stay there for a second, stunned. You feel a bit of bile and iron taste in the back of your throat. LIAM:",
#   '',
#   ''),
#  ('MATT: (laughing) Make an investigation check. TRAVIS:', '', ''),
#  ('MATT: They appear to have maintained their composure as gauntlets. LIAM:',
#   '',
#   ''),
#  ('MATT: You watch as a lot of the soldiers who had been watching this endeavor step even further away from Grog, and some of them begin walking off, taking their helmets off. "All right, we\'re done." LAURA:',
#   '',
#   ''),
#  ('MATT: They all nod their heads. "Yeah, I know that. Thank god!" But they\'re all doing this while still locking eyes with him. "That\'s great." And slowly walk off. TRAVIS:',
#   '',
#   ''),
#  ('MATT: A portable writing desk? TALIESIN:', '', ''),
#  ('MATT: You have access to a quill and ink, you have access to parchment. LIAM:',
#   '',
#   ''),
#  ('MATT: You have access to that, yes. LIAM:', '', ''),
#  ('MATT: All right. Yes, you have access to that. SAM:', '', ''),
#  ('MATT: He has a spell for that. (laughter) TALIESIN:', '', ''),
#  ('MATT: As you finish penning the letter, you read over it once, twice, make sure all the information is contained. You go ahead and grab the little bit of your offering of dragon scales and teeth. Present them to Kashaw. He takes the letter and reads it over. "Sure." SAM:',
#   '',
#   ''),
#  ('MATT: "Are you going to do your tree thing for me? Otherwise, I can walk, but it\'ll be a month and a "half before I get to shore." MARISHA:',
#   '',
#   ''),
#  ('MATT: "I\'m can figure something out." LAURA:', '', ''),
#  ('MATT: (chuckles) "No." MARISHA:', '', ''),
#  ('MATT: "All right." Gets his shield and his spear and walks down with Keyleth towards the Sun Tree. As he\'s walking down, at your side. LAURA:',
#   '',
#   ''),
#  ('MATT: As he walks with you down the pathway, having this conversation. It\'s that awkward, quiet about three, four minutes of walking before he goes. (sniffs) "Ugh. So when all this is over--" MARISHA:',
#   '',
#   ''),
#  ('MATT: "If we survive all this dragon business--" MARISHA:', '', ''),
#  ('MATT: "Do you want to get a drink?" MARISHA:', '', ''),
#  ('MATT: "Good." MARISHA:', '', ''),
#  ('MATT: "Great." MARISHA:', '', ''),
#  ('MATT: You guys begin to approach the edge of the tree. He goes: "I think you answered your own question." MARISHA:',
#   '',
#   ''),
#  ('MATT: "Is that a yes?" MARISHA:', '', ''),
#  ('MATT: "Open the damn tree." MARISHA:', '', ''),
#  ('MATT: "Yeah. It doesn\'t work out for anybody. Trust me." MARISHA:',
#   '',
#   ''),
#  ('MATT: "All right, then. We\'ll just-- hey!" And you push him through the tree. Shuts behind him. You\'re left there alone, standing in the cold Whitestone air outside of the Sun Tree. Around mid-morning. SAM:',
#   '',
#   ''),
#  ("MATT: All right. You guys make your way towards the building that has recently been essentially given to and is acting as the abode for Shaun Gilmore while he's here in Whitestone. As you come to the front door, the door's closed. You knock. (knocking) No response. LIAM:",
#   '',
#   ''),
#  ('MATT: You hear a muffled voice in the distance within the building go, "Yeah, hold on." LAURA:',
#   '',
#   ''),
#  ("MATT: It sounded like Gilmore. He's under some sort of duress. MARISHA:",
#   '',
#   ''),
#  ('MATT: Slightly. LAURA:', '', ''),
#  ('MATT: "Yes. Hold on, please." And you watch as the barrier flickers for a second and restores itself, almost like a wave of energy brought what was a slowly dwindling bit of the blue energy, now restored to its full strength. TRAVIS:',
#   '',
#   ''),
#  ('MATT: A moment passes before the door opens again and you see Gilmore there, beads of sweat down the front of his face. He\'s got his fuzzy purple-blue robe wrapped around him. "My sincerest apologies, "I had to take care of the now morning ritual." LAURA:',
#   '',
#   ''),
#  ('MATT: "I\'m fine. This is child\'s play compared to what you\'re having to deal with on a daily basis, "I\'m sure." MARISHA:',
#   '',
#   ''),
#  ('MATT: Go for it. MARISHA:', '', ''),
#  ('MATT: 15. LAURA:', '', ''),
#  ('MATT: "What can I do for you?" LAURA:', '', ''),
#  ('MATT: "Well, at the very least, that gives us a series of days to make the best of the time we "have. So Marquet it is. All right. Come in." He closes his robe a little bit and walks in, and you enter. You can see there\'s a half-drunken tea set, and he begins to walk past. "Tea, anyone?" SAM:',
#   '',
#   ''),
#  ('MATT: "I\'ll do what I can." TALIESIN:', '', ''),
#  ('MATT: Currently, there is one cup, but as he walks by, he does this with his fingers and you watch as multiple cups drift off the shelf and find their way (cups landing) on the table. LAURA:',
#   '',
#   ''),
#  ('MATT: It looks a little disheveled, but also it hasn\'t been too long since the assassination attempt on him and he threw his attacker into the far wall, but it looks like the furniture has been placed up. There are still some bits and pieces of broken things here and there, but for the most part it doesn\'t look like he\'s had lot of time to clean up other than just making it functional. It seems livable; it\'s not too bad. He goes into the kitchen. He comes back out a moment later with a fresh pot of hot tea and sets it down. "All right. So this isn\'t going to send you to where you\'re going--" SAM:',
#   '',
#   ''),
#  ('MATT: "It\'s hot. It\'s dry. Bring some water if you can." LIAM:', '', ''),
#  ('MATT: "I should not. Got to keep this going until Allura comes back." SAM:',
#   '',
#   ''),
#  ('MATT: "Best I can tell you, because I haven\'t been there since I was very young, one: this going to "send you not to Ank\'Harel itself, it\'s going to send you to Shandal, which is a small oasis "village a little ways south of Ank\'Harel. It\'s where I grew up." LIAM:',
#   '',
#   ''),
#  ('MATT: "Shandal." LIAM:', '', ''),
#  ('MATT: "I will say that it has been about 15 years, so I don\'t quite know what to expect there. I "apologize in advance for any ensuing chaos, but it\'s a nice town. It\'s small, it\'s sleepy. It\'s "not my speed. Hence why I came here. However, in Marquet, it\'s mostly music, culture, fun people, "good food. Don\'t break the laws. Don\'t drink the water freely from the various channels you may "stumble across. Water there is a commodity. It is controlled and sold throughout the city." LIAM:',
#   '',
#   ''),
#  ('MATT: "Those are the main things I can think of. I don\'t know what else you\'re really looking for there." SAM:',
#   '',
#   ''),
#  ('MATT: "I don\'t know anything about that, unfortunately, but most folks that have "information are eager to give what they know with a little coin to grease the palm." TALIESIN:',
#   '',
#   ''),
#  ('MATT: "Depends on who you\'re talking to. Anything else?" LIAM:', '', ''),
#  ('MATT: He pours tea for everyone else who asked for it. And for each person that asked for a different flavor of tea, he begins to snap his fingers and the tea color changes. LAURA:',
#   '',
#   ''),
#  ('MATT: "There are many." LAURA:', '', ''),
#  ('MATT: "That would definitely probably narrow it down, but none that I can remember off the top of my head." SAM:',
#   '',
#   ''),
#  ('MATT: "When you meet them, and you\'ll know who they are, tell them I say hello. And actually--" He thinks to himself for a second. Rushes off. Comes back with a small backpack made of leather and thick, light tan wool. He opens it up and reaches inside. Pulls out a small silver locket and takes it and puts it in your hand, Vex. He goes, "Just give that to them." LAURA:',
#   '',
#   ''),
#  ('MATT: He closes the bag and places it back in the other room. MARISHA:',
#   '',
#   ''),
#  ('MATT: (sighs) "We do what we must." MARISHA:', '', ''),
#  ('MATT: "Yes. I guess if I had one request of all of you, this goes universally, can we end this dragon "business soon? Please? I really just want to set up shop again." LIAM:',
#   '',
#   ''),
#  ('MATT: "Great." LAURA:', '', ''),
#  ('MATT: "Good. Because I\'ve been keeping a tally. I don\'t know about you guys, but the tab is running "very deep." LAURA:',
#   '',
#   ''),
#  ('MATT: "Fantastic. I love it." LIAM:', '', ''),
#  ('MATT: "I\'ll be here if you need me." LAURA:', '', ''),
#  ('MATT: "All right. You don\'t want the rest of your tea?" SAM:', '', ''),
#  ('MATT: "These didn\'t belong to me, so please, take them if you want." (laughter) MATT:',
#   '',
#   ''),
#  ('MATT: "Not that he\'d tell me anything, but he doesn\'t have a very lengthy period of keeping this "up without him probably collapsing like he did back in the city. Just please, try to do your best to "get this over with. I\'m worried. At the very least, until Allura comes back. At least they can "share the load. All right." She knocks on the door and opens it. "Gilmore? Gilmore, breakfast." The door closes behind her. TRAVIS:',
#   '',
#   ''),
#  ('MATT: It doesn\'t take you long. He is still stationed as one of the central figures guarding the actual castle of Whitestone itself. Similar to the place you saw him last time you guys had a conversation walking up to the castle. He stands there with his crossbow at the ready, giving a long view over the surrounding valley before he watches you approach. "Friends, you have returned. "I hope all is well on your end. Can I be of service?" LAURA:',
#   '',
#   ''),
#  ('MATT: "It was maybe ten, nine years ago, "and it was not under the best terms. Probably would be in jail had I not got away." LAURA:',
#   '',
#   ''),
#  ('MATT: "They are not very forgiving of broken laws there, and based on certain judgments... let\'s "just say a slap on the wrist usually takes the wrist with it." LAURA:',
#   '',
#   ''),
#  ('MATT: (sighs) "Whatever was needed for survival." LIAM:', '', ''),
#  ('MATT: "To Ank\'Harel?" LIAM:', '', ''),
#  ('MATT: "No!" (laughter) MATT:', '', ''),
#  ('MATT: "The Cerulean Palace. The Cerulean Palace is where the Hand of Ord generally keeps most "justice, where most of the courts are kept. It is also where the Tower of J\'mon Sa Ord is maintained "for watching over the entire city, and most of that eastern side of Marquet. The Scarlet Prison "is where people go to disappear. It is also referred to as the Scarlet Oubliette. People are "placed there to go away; people are placed there to be tortured; people are placed there, rumors "say, to be part of various experiments. Regardless, I would highly recommend--" He looks to you. "Don\'t steal anything unless you are damn sure nobody knows of it." LIAM:',
#   '',
#   ''),
#  ('MATT: He closes his eyes a second. "That was... a very, very--" LAURA:',
#   '',
#   ''),
#  ('MATT: "Not any merchant I know, but this Den you speak of, they were a rather serious gang running "rather violent activities in the city maybe 70, 80 years ago." TALIESIN:',
#   '',
#   ''),
#  ('MATT: "In the outer walls? The outer walls are solid. They are thick; they are meant for defense "only. I did not run with them. I do not know anything. It was before my time, but they have not "been around for at the very least 50 years." LAURA:',
#   '',
#   ''),
#  ('MATT: "It is J\'mon Sa Ord." LIAM:', '', ''),
#  ('MATT: "J\'mon? I have not seen J\'mon, though I have heard the stories. J\'mon brought the city together "400 years before. When it began to grow, expand, when it became this great oasis, long ago, it went "into chaos, and there were many who wished to utilize those who lived within the center desert "to be abused, to be swindled, to be enslaved. "J\'mon started the Hand of Ord, which was the peacekeepers, and really brought the town of "Ank\'Harel into the grand city it is today. Not known to appear in public very often; there are many "rumors that circulate. Some say that perhaps J\'mon is some godling, an entity that has existed long "before Ank\'Harel and will exist long after. "There is also-- and this is my personal belief-- I think J\'mon Sa Ord is many people. I think J\'mon "is more of an office, a station, a title that\'s passed on from person to person, because I\'ve "heard referenced as a girl, I\'ve heard referenced as a boy." LAURA:',
#   '',
#   ''),
#  ('MATT: "They carry ornate armor of a deep blue sapphire color, and brass." LIAM:',
#   '',
#   ''),
#  ('MATT: "Shandal! Yes. (laughs) It\'s more of a podunk." LAURA:', '', ''),
#  ('MATT: "Comparatively, yes. Ank\'Harel is immense. Shandal is usually a small stop in case camels or "other horses have died in transit, as well as a small water stop on the way to the city." LAURA:',
#   '',
#   ''),
#  ('MATT: "I\'d say maybe a day\'s travel." SAM:', '', ''),
#  ('MATT: "It is to the south-southwest of Ank\'Harel." LIAM:', '', ''),
#  ('MATT: "Oh, Emon? Comparable. A bit bigger." LAURA:', '', ''),
#  ('MATT: "I don\'t recall. I\'ve met people missing many limbs and parts of their body. Kind of "happens; it\' a dangerous place, the deserts in Marquet. But there are also many people that live there." LIAM:',
#   '',
#   ''),
#  ('MATT: "I have no interest in titles. I just wish to stay alive. I\'m sorry. I am much more of use to "you here, I assure you. I would be a perpetually nervous paranoid wreck if I were to come with you." LAURA:',
#   '',
#   ''),
#  ('MATT: "Good. We\'ll keep it that way." MARISHA:', '', ''),
#  ('MATT: "Yes, for many long years, yes. The oasis is built around." MARISHA:',
#   '',
#   ''),
#  ('MATT: "Well, most of it\'s controlled in the River District. A number of canals begin in the River "District. This is where there is the spring, the perpetual oasis that fuels the city, and many of "the caravans that travel to and from." TRAVIS:',
#   '',
#   ''),
#  ('MATT: "Yes." TRAVIS:', '', ''),
#  ('MATT: "There is \'be pleased,\' with a small bow, preferably with the hand down towards the stomach, "with the hand out. Be pleased." LAURA:',
#   '',
#   ''),
#  ('MATT: "To be honest, anything you do will offend somebody in the right place, right time, but "people are pretty laid back in Ank\'Harel, as long as you follow the rules. It\'s a beautiful city. "I\'m actually excited for you to see it. I\'m very proud of it, had I not made some mistakes." LIAM:',
#   '',
#   ''),
#  ('MATT: "You know what? If you can, there is a special spice that is harvested not far from the "city. If you could find me some fusaka spice? Bring me a small-- not a lot, just a bit." TRAVIS:',
#   '',
#   ''),
#  ('MATT: "It\'s for food, yes." LIAM:', '', ''),
#  ('MATT: "It\'s a bit pricey. I can give you some--" ALL:', '', ''),
#  ('MATT: "All right. Well, I appreciate it." LAURA:', '', ''),
#  ('MATT: (laughs) LAURA:', '', ''),
#  ('MATT: "Work on it for a bit, maybe watch some folks. You\'ll pick it up right quick, just pay "attention." SAM:',
#   '',
#   ''),
#  ('MATT: "All right, be safe, friends. Look forward to your return." LAURA:',
#   '',
#   ''),
#  ('MATT: "That is my purpose." MARISHA:', '', ''),
#  ('MATT: "Is he all right?" MARISHA:', '', ''),
#  ('MATT: "I may have noticed it myself. I will do this for you. Promise." MARISHA:',
#   '',
#   ''),
#  ('MATT: "My pleasure." SAM:', '', ''),
#  ("MATT: All right, you guys head back to Gilmore's place? LAURA:", '', ''),
#  ("MATT: You can pick up a few. We'll say for about five gold pieces here, you can acquire some jugs that are compact enough that they'll actually fit within the Bag of Holding, should you place them. LIAM:",
#   '',
#   ''),
#  ('MATT: The healing potions that were available in the city you guys have already taken. MARISHA:',
#   '',
#   ''),
#  ('MATT: Five jugs. MARISHA:', '', ''),
#  ("MATT: She's so busy getting married or something. TALIESIN:", '', ''),
#  ('MATT: Percival presents you with a nice, flowing, light whitish-gray cloak. Ceremonial, within older Whitestone gatherings. It seems nice; it seems light. LIAM:',
#   '',
#   ''),
#  ('MATT: You can totally place it over your Displacer Cloak. TALIESIN:',
#   '',
#   ''),
#  ("MATT: All right. What's the plan? SAM:", '', ''),
#  ('MATT: You close your eyes and concentrate, and you see, peeking out from the metallic rim of the sword which you gave her, the Aberration\'s Bane longsword, you look up and you can see the edge of a wooden table. You hear faint music in the distance; it sounds like some sort of a piano being played. No accompaniment, just a straight piano. You hear distant whispers of conversation, the occasional burst of laughter, and you can see the edge of Kaylie\'s elbow, leaning against the edge of the table. There\'s a long pause, no movement. Then all of a sudden, she shifts back from the table and goes, "That\'s right, all the money on the table\'s mine. Nice try." Scoops down, throwing her hand of cards on the table. You hear a couple voices go (groaning). You see her scoop the coins over and go place them into a coin bag. "All right, so perhaps another round, then?" SAM:',
#   '',
#   ''),
#  ('MATT: "Where are you going? Are you a coward or something?" Shouting this in the distance, as apparently the previous people she card sharked walk off, frustrated and growling. You see one of them comes up to the edge of the table and goes, "Best be giving that money back, little girl or you\'re--" Before that happens, you see a large, meaty hand grab the back of his neck and pick up him by the scruff. You see appear into view the very edge of Dr. Dranzel\'s chin and hat and he goes, "I\'m "sorry, were you talking to my lady friend that way? That\'s poor manners." And drops him there at the table. The guy adjusts himself. "Better not see you guys in the street." He walks off. She reaches her hand up, watching the guy leave, and fist-bumps Dranzel. Your vision fades back and your consciousness comes back to you. SAM:',
#   '',
#   ''),
#  ('MATT: All right. You guys make your way back towards Gilmore\'s home. At this point in time, you come in and find there are a couple of plates, crumbs to the side. Gilmore\'s sitting in the chair with his tea, eyes closed in a meditative stance. As soon as you enter the room, he jolts back to momentary awareness. "All right! Gathered your things? Are you ready to go?" LIAM:',
#   '',
#   ''),
#  ('MATT: "If you don\'t mind." He grabs the edge of the central table in the center of the room with the tea on it. He looks towards you. TRAVIS:',
#   '',
#   ''),
#  ('MATT: You guys shift it, move it to the side, leaving an open space on the ground. He kneels down and places one hand in the center of the floor. The other hand he reaches back into a small pouch on his side and pulls out a small amount of shimmering, glassy sand material you recognize as a hint of residuum processed into its dust crystallized form. He scatters it around while he\'s muttering under his breath. As he does, with his hand in the center, you see the dust pull together into these small symbols on their own, almost like magnets to iron filings. They\'re forming into these rigid structures. As they do, they begin to flare up and glow, and he takes a step back, his eyes still closed, brings his fist together into a grip. As he does, they light up, and you recognize this as a teleportation circle. He goes, "All right, it won\'t last long. In you go!" TRAVIS:',
#   '',
#   ''),
#  ('MATT: "My pleasure!" is the last thing you hear before you dive in as it begins to fade. Each of you guys step into and transition past, immediately piling up into each other as you come out the other side, as you\'re in a dark and enclosed cupboard or closet-type circumstance. TALIESIN:',
#   '',
#   ''),
#  ("MATT: It looks like there is a set of doors to it. It's a giant armoire. You guys are pushed into it, but it is latched over. LIAM:",
#   '',
#   ''),
#  ('MATT: Flick it up. It bursts open, and you all come stumbling out. LIAM:',
#   '',
#   ''),
#  ("MATT: As you all stop, Vex, you look back around. This is a very large dresser-like armoire. It's empty. It looks like there are a number of hangers inside, like it was a place for various outfits to be kept and stored. On the floor of the wood, you can see carved into it a small symbol or a sigil, if you will. SAM and LAURA:",
#   '',
#   ''),
#  ('MATT: Marked as the symbol he put. LAURA:', '', ''),
#  ("MATT: Glancing around, you can see a small dark wood room atop a wine-red circular carpet in the center. Empty shelves and cobwebs fill the corners. There's a bit of dust and sand coating over where the bed rests against the wall. A closed window hides behind a drawn curtain, with a little bit of peeking sunlight making its way through. There is one single door that sees you out, though it is currently closed. TALIESIN:",
#   '',
#   ''),
#  ('MATT: Step onto the carpet, close your eyes. How do you will it? TALIESIN:',
#   '',
#   ''),
#  ('MATT: Moments pass, no effect. LIAM:', '', ''),
#  ("MATT: The door is locked. It is not trapped. You're peeking out the window, you said? TALIESIN:",
#   '',
#   ''),
#  ("MATT: You glance through the cloth, and it looks like it is a glass window, but it is partially opened and looks like there's a little cluster of sand that's gathered over time underneath the sill, from what little bit the wind's pushed through. Glancing out as soon as you push out, the light is very bright, and you have to take a moment for your eyes to adjust. Looking out, you see a simple street. There are some small buildings built of fine wood; nothing too extravagant. You can see a number of trees that protrude from the sand: long, tall, thin, palm frond-type tops to them, bearing some sort of large nut-like fruit. You can see what look to be small troughs of gathered water, whether it be from rain or them placed there intentionally, but they're currently locked with some semi-translucent top and chained shut, on the outside of two of the buildings. You do see a few people walking back up and down the street. General civilians, all dressed in longer, full-body robes, some of them with scarves around their neck. I wouldn't say peasants, per se, but definitely not well-off in their appearance. Casual civilians. Darker skin, looks like they've definitely been living in the desert for a long time. That is what you can see from the window's point of view. TALIESIN:",
#   '',
#   ''),
#  ("MATT: Currently, you're on the first floor. SAM:", '', ''),
#  ("MATT: You don't know. SAM:", '', ''),
#  ('MATT: Looking under the bed, you see what appears to be a small wooden box that is closed and hidden toward the very back, and what appears to be a small series of shirts that have been folded up and have gathered a lot of dust over the top of them. LAURA:',
#   '',
#   ''),
#  ('MATT: Yeah. Pull them out. Really nice, high-quality silk and cotton based, embroidered shirts. Look more ceremonial, special event type, long, maybe knee-length. MARISHA:',
#   '',
#   ''),
#  ("MATT: Currently, it's pretty bland. You can see a couple of colored tapestries similar to the center of the floor rug that are hanging, but there are a lot of blank areas. It looks like decorations have been removed, or at least haven't been there for a long time. The room, for the most part, seems to be abandoned. LAURA:",
#   '',
#   ''),
#  ('MATT: Make an investigation check. LAURA:', '', ''),
#  ('MATT: 14? It does not appear to be trapped. LAURA:', '', ''),
#  ('MATT: You do. Open it up, glance inside. It looks to be a series of folded papers. LAURA:',
#   '',
#   ''),
#  ("MATT: It's easy enough, like butter. (creaking door) The door opens. MARISHA:",
#   '',
#   ''),
#  ('MATT: As the door opens up, immediately, your nose catches the smell of sage and cooked meats. As the door opens, you look into a large room to your left with some furniture, not too extravagant, but nice, and a humble living space. As the door opens the other way, you look to the right, and you see two figures sitting at a table, seemingly eating. An older couple, with dark sun-weathered skin, graying hair, and bright eyes. They look confused and slightly scared at their table, staring back at people wandering into the middle of the room. TRAVIS:',
#   '',
#   ''),
#  ('MATT: They both look at each other. SAM:', '', ''),
#  ('MATT: They both look to each other and then immediately begin, mouths filled with food, laughing. (laughs) "This is unexpected. Friends of Shaun\'s, you say?" ALL:',
#   '',
#   ''),
#  ('MATT: The man himself stands up and begins to walk over, wiping the edge of his mouth with a small piece of cloth, finishing chewing and swallowing the food he has currently. As he walks up, the man has thinning white hair that grows long, straight down towards his back, simple long robe-like dress with simple cloth pants that go round these slipper-like shoes on his feet. He approaches. Which one said Shaun? SAM:',
#   '',
#   ''),
#  ('MATT: Gilmore and Shaun. Approaches you, as you, stepping forward as one of the more, you know, assertive members of the party, and goes, "How is he? If you could please tell me?" LAURA:',
#   '',
#   ''),
#  ('MATT: "Opesa. Opesa, come." And the woman gets up from the table. "Yes, I\'m sorry. It has been a while since we\'ve had guests "from so strange and sudden arrivals!" She walks up and pulls these small glasses out from her pocket and puts them on. You can see her eyes open up wide behind them, and she comes, leans to the side and puts her arm around him. They both hold each other. He goes, "I am sorry. Let me introduce. I am Soren Geddmore. This is Opesa Geddmore. You know our son?" LIAM:',
#   '',
#   ''),
#  ('MATT: "And you say he does well with his business?" LAURA:', '', ''),
#  ('MATT: "This is good." LAURA:', '', ''),
#  ('MATT: "He has always been a brave one." SAM:', '', ''),
#  ('MATT: "You don\'t have to embellish. That\'s okay. Would you like to eat with us? We can make more "food, yes?" LAURA:',
#   '',
#   ''),
#  ('MATT: "You are going to Ank\'Harel?" LAURA:', '', ''),
#  ('MATT: "Yes. Follow me." He takes her by the arm, and they both walk arm-in-arm, leading you guys to what looks to be a front door of this abode. As he pushes it open, revealing more of the street of this small oasis town, he goes, "Let\'s see, if you follow-- that is the sun." He looks up, and you see his eyes adjust to the brighter sky. "The sun is there. It will be setting... that direction. "Continue... what is the word you speak?" SAM:',
#   '',
#   ''),
#  ('MATT: "That is west. You want to north, so go that way. Yes. That is where you want to go." LAURA:',
#   '',
#   ''),
#  ('MATT: "I haven\'t been in many years. As far as I know, there are signs. There are not roads. There "are guides you could hire to bring you there." MARISHA:',
#   '',
#   ''),
#  ('MATT: You get the sense these are probably who he was referring to. LAURA:',
#   '',
#   ''),
#  ('MATT: "What--" And he looks to his wife. The woman steps forward adjusting her glasses. "Thank you so much!" She holds it and opens it up. Looks over to him and shows him. You get a bit of a glance, at that point. You can see it\'s a picture of Gilmore. He\'s happy. Jewel-encrusted rings. It\'s almost a promotional still, if there was one, for Gilmore\'s Glorious Goods. She takes it. She closes it and goes, "Gilmore is originally "Geddmore. He changed his name when he went for better business to the Tal\'Dorei place. Glad he\'s "doing well." TALIESIN:',
#   '',
#   ''),
#  ('MATT: "Give him our love and tell him he is more than welcome to visit. It has been many years." LIAM:',
#   '',
#   ''),
#  ('MATT: "Not a worry. Safe travels. You\'re sure you don\'t wish to have food?" LIAM:',
#   '',
#   ''),
#  ('MATT: They both look at each other. "I\'m not familiar with this spice you speak of. My apologies." She\'s like, "I\'m sorry. I do not know this fusaka you speak of." LIAM:',
#   '',
#   ''),
#  ('MATT: "We have, around this way--" He leads you towards the back of this small kitchen. It\'s very condensed. You can see there is a high metal fence, and there appears to be a rainwater receptacle there, like a well that is built into the homestead. It has chains over the top. He begins to pull keys out and lock to it, and as he pulls off the chains one by one, he pulls back the lid, this hard, dry wooden lid, and within it is a very deep well, though it looks like the water level\'s maybe ten feet down from the top of the well right now. TRAVIS:',
#   '',
#   ''),
#  ('MATT: "Hey, Opesa, do you see anything?" And she blinks a bit. "No, it\'s empty." TRAVIS:',
#   '',
#   ''),
#  ('MATT: "Nothing. You are a strange man." (laughter) TRAVIS:', '', ''),
#  ('MATT: How much water does it create? TRAVIS:', '', ''),
#  ('MATT: Oh wow. "You are still a very strange man, but I\'m very happy and appreciative." TRAVIS:',
#   '',
#   ''),
#  ('MATT: "All right. I can see, now. Gilmore has his work cut out for him." TRAVIS:',
#   '',
#   ''),
#  ('MATT: He pats your shoulder. "Geddmore, indeed." As you finish pouring the water out, they lead you guys back to the front. LAURA:',
#   '',
#   ''),
#  ('MATT: He pulls out a small sundial from his pocket, holds it up. "It would be closer to late afternoon." LAURA:',
#   '',
#   ''),
#  ('MATT: "Well, thank you so much for coming." TALIESIN:', '', ''),
#  ('MATT: "Be pleased." And they both, in a very rusty joints way, give you both a bow as you leave. LIAM:',
#   '',
#   ''),
#  ('MATT: That would be the saddest TPK ever. "Let\'s go, guys!" And so ends the journey of Vox Machina. (laughter) MARISHA:',
#   '',
#   ''),
#  ('MATT: All right. As you guys take a moment to concentrate, each one of you transforms into mist. As you begin to go one by the other, you do hear a couple of (gasps). You glance over your shoulder to see three kids, all looking up at you all with these big, scared smiles. MARISHA:',
#   '',
#   ''),
#  ('MATT: Make a deception check. MARISHA:', '', ''),
#  ('MATT: After you give your presentation, they, "Whoa!" As you begin transforming, you do that and they go, (terrified screaming) and go running indoors. TALIESIN:',
#   '',
#   ''),
#  ("MATT: That's what Vox Machina is all about. TALIESIN:", '', ''),
#  ("MATT: You are terrible people. You guys rise into the air as the sun begins to bring itself to set in the west. You shift up over the city. You look down. Probably maybe 150, 200 buildings make up the entirety of Shandal. It's not a very large town, but you can see little dots of moving caravans both to and from the city. It is a fairly lively stop for people traveling to and from Ank'Harel. TALIESIN:",
#   '',
#   ''),
#  ("MATT: Every now and then. As you follow the direction they're going, you're traveling much faster than they are. The hot air does feel a little uncomfortable against your cloud-based misty forms, but you do not feel like it's responsible for evaporating any of your form. MARISHA:",
#   '',
#   ''),
#  ('MATT: You\'re like, "oh this is uncomfortable." You continue to press forward as the sun slowly begins to set. The temperature begins to get colder and colder, and the sky grows darker. MARISHA:',
#   '',
#   ''),
#  ("MATT: If you'd like to. It's up to you entirely. The form is your choice. TRAVIS:",
#   '',
#   ''),
#  ('MATT: You continue to travel throughout the night? SAM:', '', ''),
#  ("MATT: Yes, you guys cruise. You guys push forward for another four to five hours post-dusk. You're now hitting the early hours of the morning before you begin to see in the distance hundreds of sparking lights begin to appear up above a distant sand dune. You can see the lit lights, lanterns, and general glowing night life of a massive city over the high walls that surround its exterior. This is a pretty amazing sight for those of you who have not been to such a large desert atmosphere, and it is pitch black below you, and at the height you're traveling-- How high are you traveling versus the ground? I guess I should ask. TALIESIN:",
#   '',
#   ''),
#  ("MATT: Okay. From this view, you can see a large queue about eight heavy caravan carts long of caravans that have camped for the night outside of the front main gates. You do see, along the line of the outer wall, there appear to be a number of small spires that open up like guard tower parapets that come to a pointed, what looks like a hand, cradling the outside of each section of the wall on the outside, but on the inside, you see a hundred or more of these long, multi-level spires that progress all throughout the city, and it goes on and on in its large oval-like shape. It's hard to make out much color other than the thousand small lights you see throughout the entire city. Orange, yellows, greens, blues. It is a beautiful view. What is your plan? TALIESIN:",
#   '',
#   ''),
#  ('MATT: Still night, yes. LAURA:', '', ''),
#  ("MATT: It's two in the morning, at this point. MARISHA:", '', ''),
#  ("MATT: You can't tell from this height, unfortunately. LAURA:", '', ''),
#  ('MATT: You scoot down around the outside of the city walls. The landscape here near the town appears to be more packed and hardened badland dust and sand. You can see where lots of it, from a recent rain, have caked and hardened and then broken in places. It leaves this soft, shale-type texture to it that breaks into sand upon crumbling underfoot. From what you can see, there are a number of various heights of dunes in the distance. This city is thrown right in the center of what appears to be hundreds of miles of desert from the view that you had as the sun was setting. LAURA:',
#   '',
#   ''),
#  ('MATT: The gates to the city are closed from this perspective, yes. LIAM:',
#   '',
#   ''),
#  ("MATT: You guys timed this, I didn't. LAURA:", '', ''),
#  ("MATT: The giant iron gates stand about 65 feet tall and about as wide from end to end. They have a very tight weave of iron bars between them, to where it's almost a very thick fencing that you can almost see through. You can just see the outline of things that walk back and forth behind it. However, on the front side, you can see a number of guards. LAURA:",
#   '',
#   ''),
#  ('MATT: Stop looking at my piece of paper on the screen! LIAM:', '', ''),
#  ("MATT: Not actually. Not anymore, it's not! It's gone! All right. Amongst the carved-out circle of caravan carts and people that are camping overnight before entering the city, you do see what appear to be a dozen guards, all dressed in dark blue and dark reddish metallic armor, many carrying heavy scimitars to their side or long pikes and shields. They're all wearing intricate helmets that crest down past the nose to the point where it looks like they just have eyes and a lower jaw. It flares out at the bottom and then curves to a point right across where the clavicle would be. The armor itself is designed in a very beautiful ornate fashion, but also looks very functional. You're at a distance; they don't seem to have noticed you as you've all crested down still in your cloud forms. LAURA:",
#   '',
#   ''),
#  ("MATT: The Hand of Ord isn't secret. MARISHA:", '', ''),
#  ("MATT: How far are you guys? How far did you decide to stop and transform? That's up to you. LIAM:",
#   '',
#   ''),
#  ("MATT: They're maybe 40 feet from the gates. TALIESIN:", '', ''),
#  ('MATT: Make a perception check LIAM:', '', ''),
#  ('MATT: At a safe distance, you can make out some detail, and there is some lantern light on top of some of these carts. It appears that a number of the folks have set up small tents, and most appear to be sleeping. There are a few guards that are set on top of the carts with crossbows resting over their lap, keeping an eye in case anyone decides to get too close to their wares throughout the evening. LAURA:',
#   '',
#   ''),
#  ('MATT: Yeah. It takes you a minute to transform. SAM:', '', ''),
#  ("MATT: The light radius beyond the wall itself is not very strong. It only low-lights maybe a 30- to 40-foot area around the gate itself, and there are a series of small torches that appear to be ever-burning on the outside of the wall. There are a few campfires that have been set up by the caravans that are waiting amongst the sand and broken ground there. They give a little more light. As you guys get to the outskirts of this, your shapes becoming visible to those that are keeping watch, you see a few individuals stand up on their carts with their crossbows at the ready. Just have a seat and keep an eye bead on those of you that are visible. Doesn't appear to be any aggressive action, just an acknowledgement of your presence and a show of readiness should any aggressive action be taken. LIAM:",
#   '',
#   ''),
#  ('MATT: Best you tell at this distance, the few that you can see-- because a lot of them appear to be in small tents encamped-- the few that you do make out appear to be dressed in a little more wealthy attire than the people you encountered in Shandal. You can see the gentlemen and ladies that are guarding the encampment are dressed in functional leathers with hints of hide and metal plates incorporated in the defense, but nothing that shows overt wealth or overt destitution. General mercenary guardians for a traveling caravan. MARISHA:',
#   '',
#   ''),
#  ('MATT: At this hour? No. You get the sense, looking at the surroundings of the campfires, it looks like some sort of party or gathering may have transpired earlier in the evening, but most everyone have passed out at this time. LAURA:',
#   '',
#   ''),
#  ('MATT: Scanlan? SAM:', '', ''),
# ...
#   '',
#   ''),
#  ('MATT: Except it just has this one frazzled-looking young woman standing there with long strands of curly dark brown hair. Red lips, dark eyeshadow. She\'s eagerly looking out with a sign in the front that reads, "Oddities and Eccentricities." TALIESIN:',
#   '',
#   ''),
#  ('MATT: "Good day." TALIESIN:', '', ''),
#  ('MATT: "Be pleased to you as well." TALIESIN:', '', ''),
#  ('MATT: "There are many oddities at my disposal. I\'m Nisaba." TALIESIN:',
#   '',
#   ''),
#  ('MATT: "What kind of oddities are you looking for?" TALIESIN:', '', ''),
#  ('MATT: "Well, let me show you." Over the next five minutes, she brings out all sorts of strange knickknacks. It\'s essentially a display from the most awkward of vintage Salvation Armies you\'ve ever come across. TALIESIN:',
#   '',
#   ''),
#  ('MATT: However, you do catch a quick flash of what appears to be some small crystalline vials that appear to be strapped to some sort of leather bandolier. TALIESIN:',
#   '',
#   ''),
#  ('MATT: "This is for, well, a gentleman who passed through many years ago, who claimed to be a great "alchemist, sold this off when he had come into a lot of debt within the city, so I made a good "price. No one has really showed much interest in it." TALIESIN:',
#   '',
#   ''),
#  ('MATT: "You may." TALIESIN:', '', ''),
#  ("MATT: The leather's finely made, if a little worn. The chemicals inside-- one of them does have a familiar color, a deep herbal red. This looks to be some sort of a low to medium level healing potion, most likely, from your experience in the use of that. The two others are grayish and murky and don't really draw your attention or anything you're familiar with. TALIESIN:",
#   '',
#   ''),
#  ('MATT: Make an intelligence check. MARISHA:', '', ''),
#  ("MATT: 15. They do appear to have been prepared in the way that you prepare magically enchanted vials for potions themselves, but you're not really able to make out just at a glance. You'd have to spend quite a time to make out what their nature is. MARISHA:",
#   '',
#   ''),
#  ('MATT: "Well, knowing that is now a magic potion of healing and two other magical potions, that is a "very valuable belt with its contents. I would sell you just the belt for five silver pieces. To "include the vials, and they do come as a set, unfortunately, that would run you 275 gold pieces." TALIESIN:',
#   '',
#   ''),
#  ('MATT: "We\'ve had it for a number of years." TALIESIN:', '', ''),
#  ('MATT: (chuckles) "That is not going to work." She reaches out and takes the belt away from you and sets it back down on the inside. TALIESIN:',
#   '',
#   ''),
#  ('MATT: "For the belt, maybe." TALIESIN:', '', ''),
#  ('MATT: "Right, but you\'re willing to have and to offer that 75 gold for it, please." TALIESIN:',
#   '',
#   ''),
#  ('MATT: "No, it\'s not going to work. I\'m sorry." TALIESIN:', '', ''),
#  ('MATT: Make a persuasion check. TALIESIN:', '', ''),
#  ('MATT: She goes, "225 gold for the set." TALIESIN:', '', ''),
#  ('MATT: Make a charisma check. TALIESIN:', '', ''),
#  ('MATT: Just a straight charisma modifier to your roll. LIAM:', '', ''),
#  ('MATT: She goes, "I appreciate your patronage, but I am a patient woman, and that is how I hold "business." (laughter) TRAVIS:',
#   '',
#   ''),
#  ('MATT: Maybe a 45-minute to an hour walk. LIAM:', '', ''),
#  ('MATT: You ask around. It looks to probably be about four hours from sunset. TALIESIN:',
#   '',
#   ''),
#  ('MATT: So you guys are making your way towards the Cerulean Palace. As you approach the large, extremely imposing palace, you come upon what looks to be an endless series of stairs that brings you to the upper platform that is the central portion of the city where the palace seems to reside, eventually peaking in the Sandherald district that you were referred to earlier as the location of the palace and where the Bowl of Judgment exists. You step up to the very top of the stairs to find yourself already breathless at the sight of the immense purple-blue-colored palace. A dozen towers reach for the clouds, the daylight peeking through their slightly translucent material, like glassy waters ever-frozen in a fall. The central tower, the one that caught your eye, that ends in a large cup-like position, rises above all of them with a slight spiral-type texture to the outside of the palace that is incredibly tall amongst the rest of the cityscape. As you get closer, you can see the main palace structure presents hundreds of arches pointed at their apex in its structure, smaller and smaller as it recesses further into the palace. Its very architectural build is a marvel, and seems to both have consistency and a chaotic feel to the placement of some of these arches too, in size. It\'s a very strange but fascinating structure. You can also see turquoise detailing and trim against many of the pillars and carvings and statues that adorn the exterior of the grounds of this palace. As you approach what appear to be the front gates that ascend, with a very bright blue turquoise exterior, close to 50 Hands of Ord patrol various elements of the grounds around it. It looks like there are actual pockets of grass and gardens that exist around the Cerulean Palace in here. The topography changes almost to feel like it belongs entirely anywhere but the middle of the desert. The guards do eye you suspiciously as you approach, and you watch as one armored woman, her dark hair hidden mostly beneath an ornate helmet of brass and blue, approaches you guys. "Welcome to the Cerulean Palace. I must ask "your business here." LAURA:',
#   '',
#   ''),
#  ('MATT: "Our emperor does not take meetings. My apologies, but I must ask you to leave." TALIESIN:',
#   '',
#   ''),
#  ('MATT: Make a persuasion check. MARISHA:', '', ''),
#  ('MATT: 24. "Let me inquire with the Grand Maven." She turns around, her armor clinking, and walks back to the palace, leaving you guys there amongst these courtyard grounds. A few moments pass before she returns, the doors opening. As she descends, next to her you see an older woman with these long, ceremonial robes that drag behind her, spilling across the stairs as she descends, seemingly dozens of gemmed bracelets that jingle as she walks with each step. She wears a tall headdress with what looks like brass quills that press behind her head and down her back. As she approaches you all, the woman earlier that you spoke to, the Hand that approached you, stays behind quietly and watches, weapon at the ready. The woman steps forward with a smile, and unlike the abrasive appearance that most of the Hand have given, she seems to be more welcoming, and gives, for the first time since you\'ve been here, a very formal welcoming bow with her hand before her, the other hand out. Says, "Be pleased, everyone." ALL:',
#   '',
#   ''),
#  ('MATT: "I must apologize. We were not aware of your arrival here. I am the Grand Maven Gameshega. "Please, enter and follow me." TRAVIS:',
#   '',
#   ''),
#  ('MATT: As she walks past you and the female Hand that saw you earlier steps aside and watches you as you pass, then ends up stepping behind you and flanking, keeping a watch from the back as you guys are led up the final staircase, through the front turquoise gates of the Cerulean Palace, and they close behind you with a resounding (impact), the impact echoing through these long halls. From the interior, massive pointed archways that lead down ornately decorated halls that echo with each footfall that hits across what looks like endless white and black bespeckled marble. She leads you through a series of hallways, more Hands walking past, as well as a number of other robed individuals. What appears to be a central chamber that has a number of steps and seats, where it looks like various philosophers are in mid-heated discussion in once again, this same language that you have not heard on your ears before. You are eventually brought to a very intricate and decorated waiting room, with some finely upholstered silk chairs, couches. The Grand Maven stops. "If you would not mind, please have a seat." TALIESIN:',
#   '',
#   ''),
#  ('MATT: She walks into a nearby doorway. It looks like a single door that leads into a small-looking room, from the brief moment you have to see it. The door closes and you hear a (magic sound). Two minutes pass. Five minutes pass. Ten eerie, quiet minutes pass. TRAVIS:',
#   '',
#   ''),
#  ("MATT: No windows in this particular room, but you notice as you take a close look, the roofs, while they are built of this deep blue, almost glass-like thick crystal, they're ever so slightly translucent, and it gives this general blue glow about the entire room. You can't make out any details from the outside, but there is this strange translucence to the entire structure. TRAVIS:",
#   '',
#   ''),
#  ('MATT: There is the hallway that you left behind, but there standing in the doorway is the same Hand that approached you guys and has been keeping an eye the entire time. LAURA:',
#   '',
#   ''),
#  ('MATT: Is away from you, standing in the large archway hall that led you into this waiting room. LAURA:',
#   '',
#   ''),
#  ('MATT: She glances at you. "You look like a strapping young man. Perhaps you can hold onto "that for a time." TRAVIS:',
#   '',
#   ''),
#  ('MATT: She leans behind the hallway. (foreign language) "Just a moment." Another guard walks up behind and kicks a bucket into the room. TRAVIS:',
#   '',
#   ''),
#  ('MATT: Make a perception check. TALIESIN:', '', ''),
#  ('MATT: You have your ear up against the wall. LAURA:', '', ''),
#  ('MATT: Well, you\'re subtly doing it, and there\'s nothing. You get closer and closer, and there\'s nothing. The rest of you hear (magic sounds), but you\'re still-- Eventually, the door opens again, and there the Grand Maven stands again. She looks up to the rest of you. "Come with me. You have "been granted an audience." She steps back into the chamber. LAURA:',
#   '',
#   ''),
#  ("MATT: You walk into what is a cylindrical chamber of smooth blue-purple quartz-like material with four strands of heavy chains taut between the ceiling and floor, about 15 feet above you. No other exit. You all enter and the door closes behind you, the Maven still relaxing, her arms to her side, her headdress still giving her this ominous presence. Looks up, and there's a (impact) shuddering sound. Suddenly, the bland, uncharacteristic walls, compared to the rest of the palace, begin to slide past the chains, now making this rattling sound as the floor itself seems to be lurching. You feel a bit of pressure in the room that wasn't there before. You're all being lifted, and the walls, now no longer walled in by the rest of the palace, you can now see this occasional traveling-down line as the spiral on the outside of the tower you once saw now surrounds you. The walls are much thinner than the rest of the palace, as you can see through this somewhat-translucent glass exterior the entirety of Emon surrounding you from upon high as it goes lower and lower as you're lifted higher and higher into this tower. LAURA:",
#   '',
#   ''),
#  ('MATT: It\'s very off-putting, but beautiful at the same time. Everything\'s seen through this shimmering, somewhat-refracted blue passage. As you go higher and higher, you can see the countless homes, walls, and towers getting smaller and smaller, other towers eventually ending as you go higher in the tower. The Maven says, "I request you do not touch the walls, please." SAM:',
#   '',
#   ''),
#  ('MATT: The view reveals the entirety of the city around you, and beyond that, the distant dunes and the desert that seems to have no end. You view a far-off mountainscape a little bit in the northern direction that just begins to peek past your view, then (boom) the floor ceases again. You all seem to lurch for a moment, yourself, an inch before you catch yourself on your feet. The Maven catches herself, very used to this transition. You now see behind her, where it has stopped, there is another set of doors, similar to the ones you entered from in the bottom portion of this tower. The door opens, (creak) and you can see the next room is a set of staircases of the same color that slowly curl off and disappear upward above you. "Please, follow me." She walks in, her robe dragging behind her. You guys give enough berth for it to follow. As you\'re led up the stairway, choosing right or left, they both lead to the upper platform in what is the top of the central tower of the Cerulean Palace. As you enter this room, you see close to a hundred dangling silk tapestries from 50 or 60 feet up of multitudes of different colors; rainbowscapes of beautiful translucent cloths and silks, gently flowing with breezes and mingling and mixing into each other around the outside of the wall. High arched windows on each side, and behind, what looks to be a large opening reveals passing clouds surrounding this height and obfuscating certain portions as they meet with the height of this tower\'s apex. You see a large balcony from the opposite side of the room that is opened from its own similar-sized arch that extends outward. It has a railing about four feet up that is an opening that overlooks in open air all above the city to see. In the center of the chamber, you see a series of step-like platforms, circular, that rise up upon each other, and in the center, you see what seems to be a tall throne of bronze and sapphire that probably sits ten feet up from the base. Thin, but extremely long and widens towards the top. You can see hundreds of sapphires put into and set into this shiny, ruddy metallic material that frames the entirety of the throne. And there sitting atop this throne, you see a slender, human-like entity wearing no jewelry, no ceremonial adornments, no crown, just a simple brown cotton shirt over simple, elegant pants. Bare feet, no shoes. Androgynous and beautiful; you\'re unable to make out the sex of this creature. It\'s not a man, nor elf. Not fey, but something somewhat alien, almost. The skin a deep-set reddish brown, smooth and impeccable. The features are extremely fine and delicate. The eyes are what catch you: black like night, but the pupils, burning points of molten metal. The entity smiles and stands off the throne. Now, at this height, seeing it standing almost as tall as Grog, by comparison. The limbs are elongated. Extends a hand towards you as you step into the chamber. "Welcome to Ank\'Harel, heroes of Tal\'Dorei. I am J\'mon Sa Ord, and it is my pleasure to greet you." And that is where we\'ll pick up our session in two weeks. LAURA:',
#   '',
#   ''),
#  ('MATT: Two weeks. MARISHA:', '', ''),
#  ('MATT: Yeah. We have two weeks until we pick up from that point in the story. Next week, look forward once again to Liam running his awesome one-shot. LIAM:',
#   '',
#   ''),
#  ("MATT: It's going to be awesome. It's been fun. But anyway, guys, thank you so much. Hope you had a fun time. Much love to all of you in the community. You're awesome; thank you so much for your support. Thank you for supporting our wonderful charities. 826 has been awesome, and they keep showing up. We saw recently in Target ads, actually, which is fantastic, so thank you guys so much for keeping up with them. You can still give them money. You can still support 826LA, as well as any of the other charities we have listed in our Guide to Critmas on the website. Those are great ways to give and great ways to support all of these wonderful people out there doing wonderful things. TRAVIS:",
#   '',
#   ''),
#  ('MATT: And thank you, Loot Crate, for your support of this show and support of our community, giving them an awesome discount. However, most of us will now adjourn to finish signing the posters forever. LAURA:',
#   '',
#   ''),
#  ('MATT: Finishing for a lot of us. TALIESIN:', '', ''),
#  ('MATT: Finishing this weekend, so they should be going out soon to you guys. Thank you for your patience. The first batch of posters are now out. This batch will go out soon. LIAM:',
#   '',
#   '')]

# %%
df.to_csv(r'data/critical_role_transcripts.csv',index = False)

# %%
df = pd.DataFrame.from_dict(transcriptDict, orient = 'index', columns = ['transcript'])
df.reset_index(inplace = True)
df.columns = ['file', 'transcript']

# %%
print(content)
# Out:
# TALIESIN: Pissblossom.
#
# MATT: Hello, everyone, and welcome to tonight's
# episode of Critical Role, where Taliesin jumps the
#
# gun and says his phrase too late.
#
# TRAVIS: Way too late, man! Way too late!
#
# MATT: Welcome. Happy to be back. Very emotional
# episode last week. We're going to kick it into the
#
# next step of Vox Machina's adventure this week,
# and then, me, Marisha, and Taliesin will be gone
#
# next week, so there will not be progression in
# this current storyline. However, Liam O'Brien over
#
# there has been cracking up an awesome one-shot
# adventure for our remaining players and a few
#
# guests. Liam, if you want to talk a little about
# it?
#
# LIAM: Yeah, I'll tell you who's coming on by.
# Sure, I'll say who's coming on by. Mary Elizabeth
#
# McGlynn and Ashly Burch. And I don't want to spoil
# it, but Matt knows. It's different.
#
# MATT: Yeah, it's going to be fun. This is Liam's
# brainchild, and I'm excited to see them play
#
# through it.
#
# LIAM: It could blow up in my face.
#
# MATT: I think you'll be fine. If the last game was
# any indication, I think you'll be fine. All right,
#
# other announcements: once again, we have our
# wonderful sponsor with a new theme kicking in.
#
# Sam, you want to take this away?
#
# SAM: Yes, I do, Matt Mercer. Guys: Loot Crate.
# Loot Crate has been such a great sponsor all year
#
# long, and we got another great week to share with
# you. Speed is this month's theme of the Loot
#
# Crate. I'm going to read this script first. Lace
# up your sneakers or rev your engines. September's
#
# all about speed. Feel the adrenaline with some of
# pop culture's quickest vehicles and characters.
#
# High-octane assortment of goodies from Batman, the
# Flash, the Arrow, the Battlestar Galactica, the
#
# Iron Man, the Gone in the Sixty the Seconds.
#
# (laughter)
#
# SAM: It includes two collectibles, a figure, and
# as always, a monthly t-shirt. I'm wearing a
#
# t-shirt. Not from this month, but from last
# month.
#
# LAURA: It's got Futurama stuff on it.
#
# SAM: Guys, I'm an actor. Why would you listen to
# me about this stuff? I'm a liar and a deceiver.
#
# But what you can listen to, and what you know in
# your heart, is hardcore facts. I'm talking
#
# statistics. I'm talking math. I've broken this
# down for you guys. If you use the promo-code
#
# CriticalRole, you'll get $3 off your first month.
# Doesn't sound like a lot, you think? Oh, that's
#
# 1.2 gallons of gas at the Quik Mart down the
# street. Regular, unleaded. Or let's say you're
#
# generous. You give Loot Crates to everyone in your
# family. That's four Loot Crates; that's $12. That
#
# is 25 and half Forever stamps that you've just
# gotten for free. For free! Let's say you're more
#
# generous than that. You give Loot Crates to
# everyone in your whole company. All 266 employees.
#
# You've just saved enough money to buy a 2002 Kia
# Sedona with 181,000 miles on it. The transmission
#
# is going out, and it doesn't shift in the higher
# gears, but it is for $800 on Craigslist. Go look
#
# for it right now, and it will be yours for free,
# essentially, if you buy 266 subscriptions to Loot
#
# Crate. 266.67. Okay, that is hardcore facts. You
# can't argue with that. Go out. Subscribe now. Save
#
# money. Get stamps and gas.
#
# LIAM: If you don't slow your roll, Loot Crate is
# going to poach you.
#
# MATT: All right, thank you, Sam.
#
# SAM: Don't forget to use the promo code
# CriticalRole.
#
# MATT: Perfect. (laughs) All right, other
# announcements that we have. Let's see. Projects
#
# that have come up. They recently announced and put
# up the English cast video for Final Fantasy XV. I
#
# have the pleasure of playing Cor Leonis. It's a
# lot of fun. As a longtime Final Fantasy fan, being
#
# a part of this means a great deal, and I'm excited
# for the game that comes out in November. So if you
#
# haven't checked out the video, do so and you can
# watch me wax poetic briefly about my love of the
#
# series. Look forward to that.
#
# MARISHA: Soundbiting it up in that.
#
# MATT: Yeah, man! They chose my soundbite for the
# end of it. I was like (explosion). Felt cool about that.
#
# MARISHA: It's like you're an actor.
#
# MATT: It's like I played a bunch of them. Also,
# Deus Ex came out. Mankind Divided. I am scattered
#
# throughout the game with a very harsh Russian,
# Eastern European dialect, as many characters,
#
# probably yelling at you or being shot in the face.
# So enjoy that, as well.
#
# TRAVIS: I love shooting you in the face.
#
# MATT: Hey, you know? Everyone's got a skillset.
# Anybody else have anything they want to announce?
#
# SAM: We're nominated for an award, Matt.
#
# MATT: That's right! We just got nominated for a
# Streamy. A Streamy award under gaming. Games. It's
#
# awesome!
#
# SAM: It's our first nomination.
#
# TALIESIN: It's like the Kids' Choice Awards for
# adults.
#
# LAURA: But it's not. Fans don't get to vote.
#
# MATT: It is now decided by whatever the Illuminati
# Streamy committee is.
#
# SAM: Wait, fans don't get to vote? I'm sure they
# can influence things.
#
# MARISHA: Well, they nominated us, so we got this
# far because of them, and now we lose to
#
# Markiplier.
#
# MATT: Love you, Mark. We're just excited to be in
# that ring. Thank you guys for being so awesome and
#
# supporting us, and hopefully some of us will get
# to dress up fancy and show up and go home proud
#
# that we went.
#
# TALIESIN: We'll plug our other friends who
# are also nominated.
#
# MATT: And Muzzled the Musical, which I co-created,
# which Ashly Burch stars in, who you'll see next
#
# week, that got nominated for best indie.
#
# MARISHA: And Sean Becker. Who's my director for
# Signal Boost. All in the fam.
#
# MATT: It's good. Awesome. Anything else you guys
# want to talk about?
#
# TRAVIS: Yes! In the world of sportsball, the 2016
# future Super Bowl champion Dallas Cowboys are
#
# playing the Seattle Seahawks right now! So if you
# see me looking down, it's not because I'm not
#
# paying attention. I'm watching football.
#
# TALIESIN: I have never cared so much about
# football in my entire life as I do right now.
#
# Which is saying, I don't necessarily care a lot.
# But definitely--
#
# LAURA: More than it was.
#
# TRAVIS: Everybody send Sam a tweet. He's going to
# be crying at the outset of his team. Sam, a moment
#
# of silence.
#
# TALIESIN: I think he's lighting the set on fire.
#
# LAURA: Sam walked away so he wouldn't be on the
# same set as you were saying that.
#
# MATT: Anyone else have anything they want to talk
# about before we jump into the game?
#
# TALIESIN: No announcements until I get back, I
# think.
#
# MATT: All righty. That being the case, then let's
# go ahead and hop into tonight's episode of
#
# Critical Role.
#
# [dramatic music]
#
# MATT: Hello, and welcome back. So to get you guys
# caught up: our band of adventurers, Vox Machina,
#
# in raising an army, hopefully, of allies and
# powerful artifacts to face the Chroma Conclave, a
#
# gathering of powerful, dangerous chromatic dragons
# that have been tearing through the countryside of
#
# Tal'Dorei and distant Wildemount. They have
# recently found some information, had a close call
#
# with the Frigid Doom known as Vorugal. The white
# dragon flyover did not pierce through the
#
# illusionary barrier that was placed with the help
# of Allura, Gilmore, and Pike, there in Whitestone.
#
# You then decided to go ahead and using that cue,
# before the dragon returned to its current roost
#
# that it has created over the ruins of the city of
# Draconia, you traveled across to the continent of
#
# Wildemount.
#
# You had a meeting with the Ravenites, a rather
# subverted, long-enslaved offshoot species of
#
# dragonborn kin, tailless and now surviving amongst
# a recent winter that seems to have come with the
#
# ruin the dragon brought. You also discovered
# that most of Draconia and its royal elite have
#
# been slaughtered as a means of the dragon
# establishing its dominance and the worship of the
#
# Ravenites that survived the fall of Draconia.
#
# You made a deal with Tooma, the current clan
# leader of the remaining Ravenites, that you would
#
# aid in destroying this dragon, basically the
# master that they replaced the Draconians with when
#
# it came. However, to ensure your help there was a
# two-week time limit, and if you do not return
#
# before then they would see you as not keeping your
# end of the deal, and they would then, instead,
#
# direct the dragon towards what was going to be
# Whitestone until you altered her memory, which she
#
# recalls now as Emon.
#
# Anyway, before you could be finding your way home,
# one of the corpses upon one of the ice spire
#
# spikes outside of the dragon's new nest, Percy saw
# to be the remains of your long-traveled friend,
#
# Tiberius Stormwind. The party had a fateful
# farewell; set him to rest within the ruins of the
#
# nearby library, fallen from the islands of
# Draconia; said your goodbyes; and then, upon
#
# prepping a bit, plotting, and planning, found your
# way back to Whitestone to continue the next leg of
#
# your adventure.
#
# And that is where we begin. You have now taken
# some time in your own respective rooms. It's still
#
# late afternoon, going into dusk. You all took some
# time to yourselves within Castle Whitestone to
#
# take a short rest and ruminate over these recent
# events and reveals. The evening sun draws close to
#
# dusk. It is your choice which you wish to do. If
# you wish to spend the evening resting here and
#
# then leaving first thing in the morning, that is
# up to you.
#
# LIAM: Taking the initiative. This one came to my
# room, then inside. I think we've probably been
#
# quiet for a while, staring at the ceiling, and
# after a while finally say: We've really fucked
#
# things up, haven't we?
#
# MARISHA: In which particular way do you mean,
# aside from all of them?
#
# LIAM: I need to tell you. I know with all that's
# happened, between my new patron and my sister
#
# pretending to gag literally every time we attempt
# to share a word together, and mostly my own being
#
# fucked up in the head for weeks now, that I've
# pushed all of you away. You most of all. Because
#
# I've been afraid you would-- I'm sorry. And you
# didn't deserve any of that. Keyleth, I need you to
#
# know, through all of that, everything, nothing has changed
# about how I-- We've had so many near-misses. And now,
#
# finding Tiberius. Death is unavoidable. And it's
# all the more reason for life to be lived. And it
#
# doesn't matter to me what this is. What we call
# it. If you are willing to spend some time, any
#
# time, with me, then I will simply count myself
# lucky to have it. You're very dear to me.
#
# MARISHA: You're talking too much. It's not like
# I've made myself very accessible either. It's not
#
# on you. It might be a little on you, but it's on
# both of us. Anyway, my point is: for the longest
#
# time, I was terrified that I was going to lose
# you. First to death and then to the Raven Queen,
#
# which is still kind of like death, and then ultimately to
# yourself. And then I had an interesting talk with
#
# Pike recently, and she said something that really
# stood out to me, and that was that some people
#
# just have more of themselves to give. And I
# realized this whole time that I was afraid of
#
# losing you to a future that ultimately has not yet
# been written, which is stupid.
#
# LIAM: Maybe so.
#
# MARISHA: But you're ultimately right. We have
# nothing to lose. I love you, Vax. And I'm sorry
#
# for being me, that it took me this long to say it.
#
# LIAM: (sniffles) I'm sorry.
#
# MARISHA: Yeah. Me, too.
#
# LIAM: I love you. That's pretty fucking great.
#
# MARISHA: That is pretty great, yeah. High five.
# Yeah!
#
# LIAM: I tackle her into a bit of a hug into the
# bed.
#
# LAURA: Oh!
#
# LIAM: We're already on the bed.
#
# MARISHA: And that's it for now.
#
# SAM: Pan to the fireplace.
#
# TRAVIS: (laughing) Pan to the fireplace!
#
# MATT: All right, so. Vox Machina. Taking your time
# to mourn in your own interesting ways. What is
#
# your path of action? What is your course, going
# forward?
#
# LIAM: Sleeping in.
#
# MARISHA: Bacon.
#
# LAURA: Yeah, I think we need to spend at least the
# night in Whitestone and get up in the morning.
#
# MATT: Okay. So you've all spent the majority of it
# in your respective rooms-- most of you in your
#
# respective rooms-- figuring out where you are as a
# person and where this story leads you. After an
#
# evening's rest, the next morning comes around,
# breakfast is already prepared by the servants in
#
# the castle, though maybe not the amount of bacon
# you were hoping, and easily rectified upon
#
# request. It's at your disposal. There is a tension
# in the city; the barrier remains up.
#
# As you're having breakfast, you can see Zahra
# wander in at the smell of bacon, glances over the
#
# rest of you, still holding a book at her side that
# she slams closed. "Oh. I'm glad to see you're all
#
# "right, and you're safe. Please tell me there's
# more bacon."
#
# TRAVIS: Not for long.
#
# LAURA: There's more coming, dear.
#
# TRAVIS: What she said.
#
# MATT: She comes and sits down and spends breakfast
# with you guys, catching up on what has transpired
#
# and what your current plan of action is.
#
# TALIESIN: Zahra, it occurs to me, you come from a
# family with power, connections.
#
# MATT: "Kind of. Let's just say we're estranged at
# the moment."
#
# TALIESIN: Well, we're looking for any ally we
# could, and we were curious if--
#
# MATT: "You will find no allies where you're
# asking. Believe me, I'd be happy to offer if we
#
# "could, but no."
#
# TALIESIN: I had a feeling. It just felt worth
# asking.
#
# MATT: "It's all right. I'm going to continue with
# my research, since the rest of the ziggurat clan
#
# "are now scattered about or maintaining that
# barrier. Guess who has to do the research in the
#
# "meantime?" And she rolls her sleeves up; you can
# see the slightly smudged dirt across her reddish
#
# skin. She's been hard at work digging around
# trying to figure out what the basis of this
#
# enchantment beneath the city still is.
#
# LAURA: Sorry you can't be out having your fun,
# dear.
#
# MATT: "I'm certain time will allow me at some
# point. It better. I'm going a little stir-crazy."
#
# She grabs the bacon from the table and walks out
# of the room.
#
# TALIESIN: Is Kashaw around by any chance, as
# well?
#
# MATT: "I'm sorry, what?"
#
# TALIESIN: Kashaw. Is Kashaw around?
#
# MATT: "I haven't seen him for a couple days. I've
# been underground most of the time."
#
# TALIESIN: Yes, of course. We have to send a letter
# to the Slayer's Take at some point. That should
#
# happen sooner rather than later.
#
# MARISHA: Trying to wrangle a beast?
#
# TALIESIN: Trying to wrangle a beast or seeing if
# they know of anything that's in the vicinity that
#
# we can at least feed to it in the meantime.
#
# LAURA: Maybe we can stop through on our way back.
# We are going to Marquet, aren't we?
#
# TALIESIN: I would hope so.
#
# MARISHA: And what's our intent in Marquet? To get
# the next Vestige?
#
# TALIESIN: To get to the next Vestige and to
# perhaps make some friends. The more the merrier.
#
# LIAM: And the means of travel is?
#
# TALIESIN: We have a sigil. We can teleport.
#
# LAURA: Gilmore. Gilmore's from Marquet.
#
# TALIESIN: This is a teleport sigil. This is not
# going to require his attention.
#
# MARISHA: Yeah, it's located in Whitestone Castle,
# correct? The teleport sigil?
#
# MATT: It's actually a sigil by memory that he has,
# and it's a spell that he casts. It's not a
#
# permanent fixture in the city.
#
# TALIESIN: So we need him, but he can do it.
#
# SAM: Yeah, but he's concentrating on the defensive
# wall right now.
#
# LAURA: It's up. As long as the dragon's not here
# and attacking.
#
# MATT: It's a renewal feature. He has to spend some
# time each day maintaining it. He's not stuck there
#
# the whole time.
#
# SAM: That would be awesome.
#
# TALIESIN: The worst job in Whitestone.
#
# SAM: Before we go to Marquet. Let's say Marquet
# takes 13 days.
#
# TALIESIN: That's an awful long time.
#
# SAM: I agree, but let's say it does. Do we know
# what we're doing with regards to Draconia when we
#
# come back? Do we have some sort of a plan? We're
# getting a beast. That's all we know.
#
# TRAVIS: Yep, we've got it covered. It's planned
# out to a T.
#
# LAURA: How are we even going to get a beast?
#
# TALIESIN: Talk to the Slayer's Take and see what
# is already on the continent.
#
# SAM: What constitutes a beast? Because me and
# Keyleth can make some beasts.
#
# LAURA: I think a large enough beast to attract
# Vorugal.
#
# SAM: Like a triceratops?
#
# TALIESIN: No.
#
# MARISHA: They said it hunted something really
# intense recently.
#
# LAURA: He said they hunted remorhaz?
#
# MARISHA: Yeah, they went to the ocean.
#
# SAM: What is that?
#
# MATT: Roll an intelligence check.
#
# MARISHA: But I wrote it down.
#
# SAM: For me. Ooh, a 19! Plus two.
#
# MATT: That's what they look like.
#
# LAURA: Oh. Those are big and scary.
#
# SAM: Is it a gargantuan monster?
#
# MATT: They're huge. Most definitely. They're
# nasty; they burrow. The actual blood within their
#
# body is heated to such a degree that even to be in
# a scuffle with it is to scar yourself with flame
#
# and heat.
#
# SAM: And it was bored with that?
#
# TALIESIN: We want to find a creature that would
# threaten a medium-sized city.
#
# MARISHA: So it wants competition.
#
# TALIESIN: We want to wear it down a bit before we
# go in for the attack. We want it to be breathing
#
# heavily.
#
# SAM: And how are we going to get this creature
# there?
#
# TALIESIN: We're going to find something that's
# already on the continent.
#
# LAURA: And Vorugal will go to the creature.
#
# TALIESIN: He will be happy to attack it.
#
# TRAVIS: Can you put it in your necklace?
#
# SAM: On the continent. What continent? The
# Draconian continent?
#
# TALIESIN: Yes.
#
# SAM: So we have to go back there to search!
#
# MARISHA: The Slayer's Take should know. They've
# got contracts everywhere.
#
# SAM: All right. This is slightly a better plan
# than I thought.
#
# MARISHA: We thought about it a little.
#
# TALIESIN: Six people cannot wage a war.
#
# SAM: Then we should go talk to the Slayer's Take
# now so they can get started on this hunt.
#
# TALIESIN: We're going to send them a letter.
#
# SAM: A letter?!
#
# TALIESIN: Yes.
#
# SAM: Who's the letter carrier and how's he going
# to get out of this city that's protected by an
#
# invisible wall?
#
# TALIESIN: We're going to make Kashaw take the
# letter.
#
# LIAM: When we were last there, hadn't they talked
# about a brass or bronze dragon? But there are
#
# brass dragons, as you well know.
#
# LAURA: I know, because I'm an expert.
#
# LIAM: Is that overkill? We'd have to convince a
# dragon, not capture a dragon.
#
# TALIESIN: It would probably kill the dragon.
#
# MARISHA: Wait, are we talking about capturing
# another dragon to fight another dragon?
#
# SAM: No, we're talking about convincing a dragon
# to go fight this dragon that would clearly kill it.
#
# TALIESIN: I was going to find Kashaw and see if he
# would run the letter to the Slayer's Take and be
#
# our emissary and convince them to do this so that
# we're not doing everything ourselves.
#
# SAM: Wait, is there anyone else who can make this
# message delivery faster or safer?
#
# TALIESIN: Literally everyone. If we could find a
# child in a pub who could take it.
#
# SAM: No, but faster and safer.
#
# TALIESIN: Kashaw is possibly slower than a child.
#
# MARISHA: No more small boys, Percy. No more.
#
# LAURA: We could ask Zahra, but she's busy with
# research.
#
# TRAVIS: I think Kashaw is a great people-person.
#
# TALIESIN: Just to get rid of him, they would say
# yes.
#
# SAM: All right.
#
# LIAM: He wants to help. He does.
#
# LAURA: Yeah. Let's go find Kashaw.
#
# MATT: You guys head outside of Castle Whitestone.
# Not far from the base of the pathway into the
#
# actual city, you can see there is a series of
# newer-outfitted guards. They are people being
#
# trained in the force of combat. You can see that
# there's definitely a ramping-up of the defense
#
# force for Whitestone as a precaution.
#
# MARISHA: Do they look like townspeople?
#
# MATT: Many of them look able-bodied and people
# that are strong and fit, but they do appear to be
#
# civilians that have had to take up the cause just
# in case.
#
# MARISHA: Any kids?
#
# MATT: No kids, no. They all look to be at least of
# strapping age, to be carrying a weapon.
#
# SAM: Strapping boys?
#
# TALIESIN: Strapping. The strapping age.
#
# LAURA: Did we ever talk to Cassandra or anyone
# else about starting an alarm system here?
#
# SAM: Yeah, and they were working on it already,
# weren't they?
#
# TALIESIN: No, they started. They are working on it
# now.
#
# SAM: I think it's done.
# TALIESIN: I'd buy that. Yes, it was proposed.
#
# MARISHA: I do want to maybe talk to Gilmore,
# though.
#
# TALIESIN: Well, we're going to have to if we
# leave the city, anyway.
#
# MATT: As you are watching the group go through
# their different weapon practice moments, they're
#
# breaking off into small sparring groups and
# they're going up against ramshackle built
#
# training dummies. There are a few that are doing
# forms in succession. (grunts) You know the deal.
#
# You do see on the opposite end that the person who
# is currently helming one section of the training
#
# is Kashaw. You can see a bunch of shield and spear
# fighters right now, and he's basically giving them
#
# instruction on how to use a shield defensively and
# the spear offensively simultaneously.
#
# LAURA: Maybe he's not the best messenger if he's
# training our armies.
#
# TALIESIN: This is not an army. This is something
# for the population to do while they pass time. The
#
# dragon shows up, they're all going to die, no
# matter how many times they learn how to put the
#
# spear forward.
#
# MARISHA: As cynical as Percy is being right now,
# he's right.
#
# LAURA: All right.
#
# MARISHA: But it doesn't mean that Kashaw is going
# to think that it's any less important, and I'm
#
# sure he might not take it as a compliment if we
# ask him to be the messenger boy.
#
# SAM: It's an incredibly important mission!
#
# LAURA: It's not just a messenger, it's defeating a
# dragon.
#
# TALIESIN: And it's convincing the Slayer's Take to
# join.
#
# SAM: The Slayer's Take, if I recall, doesn't do
# things for free. We're going to have to pay for
#
# this, even though we're members.
#
# TALIESIN: We're going to have to bring them some
# dragon parts.
#
# LAURA: No, we take a contract on a really large
# creature, and then we let the dragon do the work
#
# for us. We get the best of both worlds.
#
# TALIESIN: Ooh, that's very clever.
#
# SAM: We take a contract on an existing creature
# that we have to somehow find in Draconia.
#
# TRAVIS: No, we bring the dragon to the creature.
#
# SAM: How?
#
# LAURA: He hunts them. That's what he does.
#
# SAM: Not transcontinentally.
#
# TRAVIS: You can't broker a fight between a huge
# beast and a white dragon?
#
# TALIESIN: We could sell tickets.
#
# TRAVIS: I think you've done better.
#
# LIAM: We don't necessarily have to sacrifice a
# dragon. We're fighting a war here. They're fuckers.
#
# SAM: No, we're not talking about sacrificing a
# dragon. We're talking about finding a beast.
#
# LIAM: Well, I'm talking about a dragon. Couldn't
# we try to talk a dragon into helping us do what
#
# we're doing? They're not all evil, are they?
# They're not!
#
# MARISHA: Yeah, but do we know of any other dragons
# here?
#
# LAURA: Well, then we're going to have to fucking
# go to the Slayer's Take.
#
# TRAVIS: Can we go somewhere in the next 60
# seconds?
#
# LAURA: This'll be great.
#
# MARISHA: Let's talk to Kashaw. We go up and we
# talk to Kashaw.
#
# MATT: As you approach, you see him leaning in with
# younger, early twenties-looking men. A bit
#
# scrawny; they're still armored; the helmet looks a
# little lopsided. Kashaw's like, "You're not
#
# "supposed to put the shield away. (sighs) Oh,
# wonderful. Take five. Take 30. So. You're alive.
#
# "That's great. I'm excited. What can I do for
# you?"
#
# TALIESIN: Kashaw, how would you like to be
# anywhere else other than here right now?
#
# MATT: "Depends on where and what you'd have me
# doing."
#
# TALIESIN: That's exactly the sort of enthusiasm I
# was hoping for. We have need of an emissary to the
#
# Slayer's Take. We need to convince them to help us
# kill the next dragon.
#
# LAURA: And Vanessa really likes you.
#
# TALIESIN: She does.
#
# MARISHA: We need a big beast on Draconia.
#
# MATT: "So you're saying that I go back to
# frozen-ass Vasselheim to deliver a paper message
#
# "to the headmistress, whom already I am so happy to
# be away from."
#
# MARISHA: Yeah. See?
#
# MATT: He glances over at the rest of the soldiers.
# "Yeah, I'll take it."
#
# (laughter)
#
# LAURA: Thank you.
#
# TALIESIN: We are in your debt. I'll have the paper
# drawn up, and anything you can do to put the
#
# weight of the situation behind us and make sure
# they know how clear it is and how necessary this
#
# is and how desperate we are.
#
# MATT: "I'll do my best to muster some semblance of
# emphasis."
#
# TALIESIN: And we'll figure out ways to make sure
# there's money in it for them, or at least dragon parts.
#
# MATT: "All right. Give me a list of what you've
# got to offer. I'll bring it to them."
#
# TALIESIN: Excellent.
#
# SAM: What do we got to offer?
#
# LIAM: We don't have the troll dick anymore. That's
# gone.
#
# LAURA: We have 40 pounds of dragonhide. Black
# dragonhide.
#
# TALIESIN: And white dragonhide.
#
# LAURA: We don't have white dragonhide.
#
# TALIESIN: We have white scales.
#
# TRAVIS: We have 64 pounds of scales from me. We have
# four claws left.
#
# SAM: I have a Tome of Leadership worth 30,000
# gold.
#
# LAURA: No, that's Keyleth's, remember? In the next
# century, when she's still living.
#
# SAM: We'll get it back before 100 years are up.
#
# MARISHA: I'll lend it to them for 100 years.
#
# SAM: A 99-year lease.
#
# TRAVIS: And we got umber hulk pieces, too.
#
# TALIESIN: Mostly, I was thinking of also offering
# them whatever we can take from the dragon itself
#
# once it's destroyed.
#
# LIAM: I was about to say, yeah, we put into the
# contract that it has the remains of the beast we
#
# take down, which we will take down.
#
# TALIESIN: We keep some scales, we keep some teeth;
# we split it.
#
# LIAM: Sure, as a souvenir, right. Yes.
#
# MARISHA: We're basically doing a contract for
# free.
#
# LIAM: It's a very large creature.
#
# SAM: That's provided we kill it. If we lose, they
# get nothing. I'm just saying, from their
#
# perspective, we're offering them literally
# nothing.
#
# MARISHA: If they lose, they don't lose anything
# either, right?
#
# LAURA: No, they do. They lose a contract.
#
# MARISHA: But wouldn't the contract just go right
# back into cycle?
#
# LAURA: No, if the dragon kills the creature and
# then we all die and we can't harvest it, the Slayer's
#
# Take doesn't have anything from its previous
# contract.
#
# LIAM: But that could happen with any contract. Any
# band of idiots could go die on the battlefield.
#
# MARISHA: They're used to having people die.
#
# LAURA: Well, fuck it.
#
# MARISHA: I think Grog's getting antsy.
#
# TALIESIN: I like this. I'm going to have it drawn
# up.
#
# LIAM: I look at Grog and see he's really bored. I
# pick up a wooden sword and I hit him as hard as I
#
# can on the small of his back.
#
# TRAVIS: Yes!
#
# MATT: Make a check.
#
# LIAM: It's not going to be that hard.
#
# LAURA: While all this is going on, Grog, you could
# be training these soldiers.
#
# LIAM: 17.
#
# TRAVIS: What, train them?
#
# MATT: As you're having this conversation, (whack)
# right in the knee cap, a surprisingly painful
#
# and forceful blow. It's less the strength behind
# it and more the precision in which it strikes you
#
# right between the kneecap and the rest of the
# lower half of your knee.
#
# TRAVIS: Like when a doctor hits you and your knee
# jumps?
#
# MATT: Yeah, and you're like (grunts) and you
# glance over and you see Vax hide a wooden sword
#
# quickly behind him as he backs away.
#
# LIAM: Come on, big guy! I know you're bored! Come
# on! I hit him again.
#
# MATT: Roll a strength check. Actually, this time
# it's an attack roll, as well.
#
# MARISHA: Hit him in the nuts.
#
# LIAM: Okay, cool. That's a 20. Oh! But it's with a
# stick! Just strength modifier?
#
# MATT: You're not proficient with a sword.
#
# LIAM: Oh dear. I'm going to use Luck. 14.
#
# MATT: (laughs) You whack him. This time, it hits
# the meat of his thigh and has no effect.
#
# LIAM: I missed the nut? Ugh. Come on!
#
# TRAVIS: Do you have a death wish?
#
# LIAM: Come on, take a swing! I'm trying to do you
# a favor! Come on, get it out!
#
# TRAVIS: What am I missing here?
#
# TALIESIN: I'm seeing this going down. I've walked
# away.
#
# LIAM: I see a gauntlet on a table, and I throw it
# at his face.
#
# MATT: Okay, roll an attack roll.
#
# LIAM: It's a one!
#
# (laughter)
#
# SAM: I see this going on, and I stand up on
# something, and I yell to the students--
#
# MATT: Before this happens, as you're getting up,
# you watch as Vax rears back, and as he throws it,
#
# (yelps) he pulls a muscle in his shoulder and it
# drops to the ground, and you're like
#
# (pained noises).
#
# LAURA: Seriously?
#
# SAM: I jump up on a chair and I yell to the
# students: Instructor Kashaw has instructed us that
#
# this is a drill! You are to attack that man right
# there, that large man, as a test of your strength
#
# and training. Now!
#
# LAURA: Don't kill them, Grog!
#
# MATT: Make a persuasion check.
#
# TALIESIN: Oh, this is going to be awful. Wow. That
# is cruel.
#
# SAM: 34.
#
# (laughter)
#
# MATT: You watch as roughly 45 armored soldiers all
# turn towards you with their shields and spears...
#
# and freeze. They all slowly look towards Scanlan
# and whisper among themselves, then look back at
#
# Grog and stay frozen and two creep forward for a
# minute. Get a little closer.
#
# TRAVIS: I take the Gauntlets and I smash them
# together, and I grow in size.
#
# (laughter)
#
# MATT: As your form swells into your now enlarged
# goliath battle-ready form, you notice a few of
#
# them start giving off this rattling metal sound as
# their armored knees (clanging) together. Many of
#
# them step back about ten feet, and Kashaw, who
# hasn't left entirely, spins around and goes: "The
#
# "gnome's fucking with you. It's fine!" He walks up
# to you, Scanlan, pats your arm and goes, "That was
#
# "pretty funny."
#
# SAM: I try.
#
# MATT: "Don't get the people killed. I've been
# working on them for four days."
#
# SAM: He wasn't going to kill-- Were you going to
# kill them, Grog?
#
# TRAVIS: Yes.
#
# SAM: Oh shit.
#
# TRAVIS: I look at Vax and I go, you were just
# playing around, right?
#
# LIAM: Yes.
#
# TRAVIS: And in my giant state, I'm going to kick
# him like a soccer ball.
#
# LIAM: I'm going to dodge. Uncanny Dodge, man.
#
# MATT: Well, we'll see. Go ahead and roll an attack
# roll.
#
# TRAVIS: That's good. 32.
#
# LIAM: Ooh. No, I didn't miss that.
#
# MATT: Roll a strength check.
#
# LIAM: Wait, I'm going to use another Luck and make
# him roll again and pick the lower of the two.
#
# MATT: Okay.
#
# TRAVIS: 15 on the strength check. 25.
#
# LIAM: Got to roll again for the hit.
#
# MATT: Roll again because he used a Luck point to
# force you to reroll your attack roll.
#
# TRAVIS: 24.
#
# LIAM: That hits.
#
# MATT: What was the strength roll again?
#
# TRAVIS: The strength was 24.
#
# MATT: Strength check was 24. So as you peek out of
# the corner of your eye you hear this (heavy steps)
#
# and as you try and spin and dodge out of the way
# instinctually--
#
# LIAM: Uncanny Dodge!
#
# MATT: I know and we'll get to that. Instinctually,
# you turn to dodge out of something Grog-sized, not
#
# giant-sized. And in that brief minute that you
# remember that he grew, you pause just long enough
#
# to (whack) feel the force of what feels like a
# giant battering ram slam into your side, sending
#
# you off your feet and arcing a good 30 feet before
# you (impact) tumble and skid to the ground. What's
#
# your strength modifier?
#
# TRAVIS: Seven.
#
# MATT: Seven. You take 14 points of bludgeoning
# damage, reduced to half because you're taking
#
# Uncanny Dodge. So only seven points bludgeoning
# damage. You stay there for a second, stunned. You
#
# feel a bit of bile and iron taste in the back of
# your throat.
#
# LIAM: And in the distance you hear: (strained) I
# feel so alive.
#
# (laughter)
#
# TALIESIN: First rule of Fight Club.
#
# TRAVIS: Can I check the Titanstone Knuckles? Have
# they changed now that I've kicked a friend in the face?
#
# MATT: (laughing) Make an investigation check.
#
# TRAVIS: Damn it! Eight.
#
# MATT: They appear to have maintained their
# composure as gauntlets.
#
# LIAM: There's some blood and five long, dark hairs
# on them.
#
# MATT: You watch as a lot of the soldiers who had
# been watching this endeavor step even further away
#
# from Grog, and some of them begin walking off,
# taking their helmets off. "All right, we're done."
#
# LAURA: Hey bonus, he's on our side. Eh? That's
# encouraging.
#
# MATT: They all nod their heads. "Yeah, I know
# that. Thank god!" But they're all doing this while
#
# still locking eyes with him. "That's great." And
# slowly walk off.
#
# TRAVIS: (chuckles)
#
# LIAM: Vex.
#
# LAURA: Yeah?
#
# LIAM: Help me up.
#
# LAURA: Don't you have wings?
#
# LIAM: Not going to use them right now. Just a
# hand. (groans) That's going to bruise. Worth it.
#
# TRAVIS: Thank you. I was getting so bored.
#
# LIAM: (sighs) I know.
#
# TRAVIS: Thanks, bubby.
#
# TALIESIN: What are the chances I would have at
# least a basic portable writing desk? They're not
#
# that complicated.
#
# MATT: A portable writing desk?
#
# TALIESIN: 16th century-style. Just something to
# write on.
#
# MARISHA: What do you need a writing desk for?
#
# TALIESIN: Just something with paper, pen, and
# something to write on.
#
# MATT: You have access to a quill and ink, you have
# access to parchment.
#
# LIAM: How about a fucking clipboard?
#
# TALIESIN: It's basically a fucking clipboard.
#
# MATT: You have access to that, yes.
#
# LIAM: Percival de Rolo, Inventor of Clipboard.
#
# TALIESIN: No, it was called a writing desk back
# then. It was called a writing desk. There's a
#
# thing. It was that big and you put it on your lap.
# It was a writing desk.
#
# MATT: All right. Yes, you have access to that.
#
# SAM: So wait, what is in this letter? What are we
# offering them?
#
# MARISHA: Yeah, how's the letter going?
#
# TALIESIN: I'm writing the letter up. I've
# basically gotten it together. I've explained the
#
# situation briefly. I assume they're aware of the
# war and the current reality.
#
# SAM: And to clarify for me. We're asking them--
#
# TALIESIN: I'm getting there. In this, I'm asking
# for their assistance in killing a dragon. For
#
# this assistance, they will get all bounty of
# biological remnants of the dragon, with a small
#
# percentage of scales and teeth kept for us. Asking
# for 20 percent, but negotiable. We want them to
#
# supply either a local or give some intel into
# where we can find a beast large enough for this
#
# dragon to attack. Information that we have on this
# dragon so that they actually help us strategize
#
# any ways of defeating it, and any other help that they
# could give in defeating this creature. And as a
#
# token of our goodwill, we are sending them a small
# package of black and white dragon scales and a
#
# dragon tooth.
#
# LAURA: Yes. And make sure to include that this
# must all be completed within 14 days.
#
# SAM: But wait.
#
# TRAVIS and TALIESIN: There's more.
#
# SAM: Asking them to help us kill a dragon?
#
# TALIESIN: For stuff.
#
# SAM: No, but that's not what we're asking them.
# We're asking them to find a beast.
#
# LAURA: Yes, that's what he said.
#
# TALIESIN: It's in the letter.
#
# LAURA: That's part of that listening thing,
# Scanlan.
#
# SAM: I'm sorry.
#
# LIAM: He did talk for quite a while.
#
# TALIESIN: Is there a way to enchant me so that I
# have his voice? And then he'll listen more closely?
#
# MARISHA: Yeah, actually.
#
# MATT: He has a spell for that.
#
# (laughter)
#
# TALIESIN: Don't answer that.
#
# MATT: As you finish penning the letter, you read
# over it once, twice, make sure all the
#
# information is contained. You go ahead and grab
# the little bit of your offering of dragon scales
#
# and teeth. Present them to Kashaw. He takes the
# letter and reads it over. "Sure."
#
# SAM: Should we add an NDA?
#
# TALIESIN: There's a rider at the end of everything
# I send.
#
# LAURA: Kashaw. No mention of Whitestone at all.
# Anywhere you go. Very important.
#
# TRAVIS: Good addendum. Whatever that word is.
#
# LIAM: Again, please?
#
# LAURA and TALIESIN: No mention of Whitestone.
#
# LAURA: Do we have a way to get him there very
# quickly?
#
# MARISHA: What? Kashaw?
#
# MATT: "Are you going to do your tree thing for me?
# Otherwise, I can walk, but it'll be a month and a
#
# "half before I get to shore."
#
# MARISHA: Yeah. We're going to be here the rest of
# the day, right?
#
# SAM: How will he get back?
#
# MARISHA: Druids. People. Wizards. Sorcerers.
#
# SAM: Wait! We got those rocks.
#
# LAURA: He's a really smart man.
#
# TALIESIN: Oh, the rock. That's a really good
# idea.
#
# LAURA: Yeah, but then he'll pop where we are.
#
# TALIESIN: No, we'll leave the rock here.
#
# SAM: We're going to stay here at least a day.
#
# LIAM: Well, you've got friends, don't you?
#
# MATT: "I'm can figure something out."
#
# LAURA: Don't worry about it.
#
# SAM: Steal an airship on your way back.
#
# MATT: (chuckles) "No."
#
# MARISHA: All right. Let's go to the Sun Tree.
#
# MATT: "All right." Gets his shield and his spear
# and walks down with Keyleth towards the Sun Tree.
#
# As he's walking down, at your side.
#
# LAURA: Don't you want to walk with them?
#
# LIAM: No. Where is that coming from?
#
# SAM: No, he definitely has a thing for you, Vax. I
# have a keen eye for these things.
#
# LIAM: But you can't address it. You just have to
# let it be. I'm not going to encourage it. I'm not
#
# interested in him.
#
# TALIESIN: I see it every time. He does. He
# smolders.
#
# MATT: As he walks with you down the pathway,
# having this conversation. It's that awkward, quiet
#
# about three, four minutes of walking before he
# goes. (sniffs) "Ugh. So when all this is over--"
#
# MARISHA: Oh, come on, man. Why are you doing this
# to me?
#
# (laughter)
#
# TRAVIS: Hold on, it's going to happen. Let it
# happen.
#
# MATT: "If we survive all this dragon business--"
#
# MARISHA: Fuck you, I hate you so much right now.
# (laughs) Uh-huh?
#
# MATT: "Do you want to get a drink?"
#
# MARISHA: I love drinks.
#
# MATT: "Good."
#
# MARISHA: So much.
#
# MATT: "Great."
#
# MARISHA: What kind of a drink?
#
# MATT: You guys begin to approach the edge of the
# tree. He goes: "I think you answered your own question."
#
# MARISHA: Yeah.
#
# MATT: "Is that a yes?"
#
# MARISHA: Well...
#
# MATT: "Open the damn tree."
#
# MARISHA: Look. You know. It's really complicated
# right now, and I'm trying this whole
#
# "allowing myself to feel things" thing.
#
# MATT: "Yeah. It doesn't work out for anybody.
# Trust me."
#
# MARISHA: Oh man. I don't know how to respond to
# that.
#
# I'll see you on the other side. We'll put a pin on
# this one. Bye, Kash. And I cast it through the
#
# tree and I push him in.
#
# MATT: "All right, then. We'll just-- hey!" And you
# push him through the tree. Shuts behind him.
#
# You're left there alone, standing in the cold
# Whitestone air outside of the Sun Tree. Around
#
# mid-morning.
#
# SAM: Did Kash leave already?
#
# MARISHA: Yeah, he's gone.
#
# SAM: Aw, Vax, you didn't get a chance to say
# anything to him. I've talked to him about this. He
#
# has his eyes out on you.
#
# LIAM: I've got enough complications around me as
# it is.
#
# SAM: I'm a really good reader of people.
#
# LIAM: It's true.
#
# SAM: The dark eyeliner--
#
# LAURA: So now that that's handled, are we leaving
# today?
#
# TALIESIN: Oh, we're leaving today.
#
# SAM: Well, one of us doesn't have any luck left,
# so maybe we should spend the night.
#
# LIAM: I've got a little bit of luck. I'm a lucky
# guy.
#
# TALIESIN: We'll get our luck back tomorrow.
#
# LAURA: We've got a limited amount of time on
# this.
#
# MATT: All right. You guys make your way towards
# the building that has recently been essentially
#
# given to and is acting as the abode for Shaun
# Gilmore while he's here in Whitestone. As you come
#
# to the front door, the door's closed. You knock.
# (knocking) No response.
#
# LIAM: Shaun? Shaun! It's us. Are you home?
#
# MATT: You hear a muffled voice in the distance
# within the building go, "Yeah, hold on."
#
# LAURA: Did it sound like anyone we knew?
#
# MATT: It sounded like Gilmore. He's under some
# sort of duress.
#
# MARISHA: Sounded like he was under duress?
#
# MATT: Slightly.
#
# LAURA: Is everything okay?
#
# MATT: "Yes. Hold on, please." And you watch as the
# barrier flickers for a second and restores itself,
#
# almost like a wave of energy brought what was a
# slowly dwindling bit of the blue energy, now
#
# restored to its full strength.
#
# TRAVIS: He's got to use the privy at some point.
#
# SAM: Yeah, he's probably squeezing one out. It's
# okay.
#
# MATT: A moment passes before the door opens again
# and you see Gilmore there, beads of sweat down the
#
# front of his face. He's got his fuzzy purple-blue
# robe wrapped around him. "My sincerest apologies,
#
# "I had to take care of the now morning ritual."
#
# LAURA: How are you holding up, Gilmore?
#
# MATT: "I'm fine. This is child's play compared to
# what you're having to deal with on a daily basis,
#
# "I'm sure."
#
# MARISHA: Can I do an insight check?
#
# MATT: Go for it.
#
# MARISHA: 15.
#
# MATT: 15.
#
# LAURA: Oh! You got a whisper on a 15.
#
# SAM: This is an early whisper. A first-hour
# whisper is rare.
#
# TALIESIN: It came at such a high speed. I wish it
# came so quickly.
#
# LIAM: I wish I knew more about Loot Crate right
# now.
#
# SAM: Well, it's not just Loot Crate, Liam. It's
# Loot Wear. Those come in a separate bag.
#
# LIAM: Different than Loot Crate?
#
# SAM: Yeah, it's different. You can find out all
# about it at lootcrate.com/criticalrole.
#
# LAURA: Actually, the shirt you're wearing, Sam, is
# from Loot Wear.
#
# SAM: What? It is? Oh my god! And I'm so handsome.
#
# TALIESIN: Anyway, back to the game.
#
# MATT: "What can I do for you?"
#
# LAURA: Well, we plan to go to Marquet.
#
# Things have progressed much quicker than we
# expected it to, and unfortunately we are on a
#
# two-week time crunch before all hell breaks
# loose.
#
# MATT: "Well, at the very least, that gives us a
# series of days to make the best of the time we
#
# "have. So Marquet it is. All right. Come in." He
# closes his robe a little bit and walks in, and you
#
# enter. You can see there's a half-drunken tea set,
# and he begins to walk past. "Tea, anyone?"
#
# SAM: I'd like a loose-leaf oolong, please.
#
# MATT: "I'll do what I can."
#
# TALIESIN: How many cups are currently sitting with
# the teapot?
#
# MATT: Currently, there is one cup, but as he walks
# by, he does this with his fingers and you watch as
#
# multiple cups drift off the shelf and find their
# way (cups landing) on the table.
#
# LAURA: How does his house look? Does it look
# together like it would normally be, or does it
#
# look disheveled at all?
#
# MATT: It looks a little disheveled, but also it
# hasn't been too long since the assassination
#
# attempt on him and he threw his attacker into the
# far wall, but it looks like the furniture has been
#
# placed up. There are still some bits and pieces of
# broken things here and there, but for the most
#
# part it doesn't look like he's had lot of time to
# clean up other than just making it functional. It
#
# seems livable; it's not too bad.
#
# He goes into the kitchen. He comes back out a
# moment later with a fresh pot of hot tea and sets it
#
# down. "All right. So this isn't going to send you
# to where you're going--"
#
# SAM: We literally know nothing about Marquet.
#
# MATT: "It's hot. It's dry. Bring some water if you
# can."
#
# LIAM: You're not able to leave, are you?
#
# MATT: "I should not. Got to keep this going until
# Allura comes back."
#
# SAM: Is there anyone that we can say maybe vouches
# for us or someone who we are against so that we
#
# can win favor with the locals? Something like a
# no-tail, long-tail binary.
#
# LIAM: We walked into a sort of political snafu
# because we didn't know the lay of the land, so is
#
# there anything we should know in advance?
#
# MATT: "Best I can tell you, because I haven't been
# there since I was very young, one: this going to
#
# "send you not to Ank'Harel itself, it's going to
# send you to Shandal, which is a small oasis
#
# "village a little ways south of Ank'Harel. It's
# where I grew up."
#
# LIAM: What was that name again?
#
# MATT: "Shandal."
#
# LIAM: Shandal.
#
# MATT: "I will say that it has been about 15 years,
# so I don't quite know what to expect there. I
#
# "apologize in advance for any ensuing chaos, but
# it's a nice town. It's small, it's sleepy. It's
#
# "not my speed. Hence why I came here. However, in
# Marquet, it's mostly music, culture, fun people,
#
# "good food. Don't break the laws. Don't drink the
# water freely from the various channels you may
#
# "stumble across. Water there is a commodity. It is
# controlled and sold throughout the city."
#
# LIAM: We got a jug.
#
# TRAVIS: We got loads.
#
# MATT: "Those are the main things I can think of. I
# don't know what else you're really looking for there."
#
# SAM: Well, I can tell you.
#
# TALIESIN: Cabal's Ruin.
#
# SAM: Thank you.
#
# TALIESIN and MARISHA: The Den of Druja.
#
# MARISHA: Druyah. Drujah?
#
# TALIESIN: Druhah.
#
# MARISHA: Jaja.
#
# TALIESIN: Thanks.
#
# MATT: "I don't know anything about that,
# unfortunately, but most folks that have
#
# "information are eager to give what they know with
# a little coin to grease the palm."
#
# TALIESIN: Or a little water.
#
# MATT: "Depends on who you're talking to. Anything
# else?"
#
# LIAM: No, go ahead.
#
# MATT: He pours tea for everyone else who asked for
# it. And for each person that asked for a different
#
# flavor of tea, he begins to snap his fingers and
# the tea color changes.
#
# LAURA: We are looking for a merchant warrior.
# Outside of you, do you know of any very powerful merchants?
#
# MATT: "There are many."
#
# LAURA: One with a missing eye?
#
# MATT: "That would definitely probably narrow it
# down, but none that I can remember off the top of my head."
#
# SAM: Why don't we bring Jarett with us? Is that a
# thing?
#
# LAURA: We should talk to him.
#
# SAM: Okay. Shaun, you do so much for us. We do
# nothing for you. Is there anything we can bring
#
# back for you or messages to give to someone
# there?
#
# LIAM: Is there anyone you haven't seen in all
# these years?
#
# MATT: "When you meet them, and you'll know who
# they are, tell them I say hello. And actually--"
#
# He thinks to himself for a second. Rushes off.
# Comes back with a small backpack made of leather
#
# and thick, light tan wool. He opens it up and
# reaches inside. Pulls out a small silver locket
#
# and takes it and puts it in your hand, Vex. He
# goes, "Just give that to them."
#
# LAURA: To them?
#
# MATT: He closes the bag and places it back in the
# other room.
#
# MARISHA: Shaun, are you doing okay? You look a
# little worn out.
#
# MATT: (sighs) "We do what we must."
#
# MARISHA: I could only imagine a barrier of this
# size of a construct can be quite taxing on one's
#
# physical energy.
#
# MATT: "Yes. I guess if I had one request of all of
# you, this goes universally, can we end this dragon
#
# "business soon? Please? I really just want to set
# up shop again."
#
# LIAM: We would like nothing more. I think we're on
# the same page.
#
# MATT: "Great."
#
# LAURA: We're very interested to start paying you
# for your service again, Gilmore, and stop
#
# expecting it for free.
#
# MATT: "Good. Because I've been keeping a tally. I
# don't know about you guys, but the tab is running
#
# "very deep."
#
# LAURA: Oh, believe me. I have, as well. This
# locket will take a nice little chunk off of that tally.
#
# MATT: "Fantastic. I love it."
#
# LIAM: Birds of a feather, you two.
#
# SAM: Should we go talk to Jarett and then come
# back?
#
# TALIESIN: Let's go talk to Jarett. We'll have
# appropriate clothing set up and prepare ourselves
#
# for the trip.
#
# SAM: Robes and things?
#
# MATT: "I'll be here if you need me."
#
# LAURA: Thank you.
#
# SAM: We'll be back in an hour.
#
# MATT: "All right. You don't want the rest of your
# tea?"
#
# SAM: Oh. I'll drink it.
#
# LAURA: Do you have any to-go cups? (laughs) Just
# kidding.
#
# MATT: "These didn't belong to me, so please, take
# them if you want."
#
# (laughter)
#
# MATT: He transitions the tea over into a couple of
# cups and hands them off to you guys who haven't
#
# finished. You head out. As you're leaving, you see
# Sherri coming up. Her hair's a bit tattered. She's
#
# usually more put together when she runs the shop.
# Now she's in casual Sherri mode. Her hair is
#
# frazzled and pulled back. Her glasses are pushed
# to the end of her nose, and she's carrying a
#
# bundle of groceries, various bits of produce and
# such. "Oh, hello, everyone. I'm bringing Gilmore
#
# "his breakfast."
#
# LIAM: Sherri. We asked him, but he's modest. How's
# he doing?
#
# MATT: "Not that he'd tell me anything, but he
# doesn't have a very lengthy period of keeping this
#
# "up without him probably collapsing like he did
# back in the city. Just please, try to do your best to
#
# "get this over with. I'm worried. At the very
# least, until Allura comes back. At least they can
#
# "share the load. All right." She knocks on the door
# and opens it. "Gilmore? Gilmore, breakfast." The
#
# door closes behind her.
#
# TRAVIS: Hey, I have an idea.
#
# SAM: Oh boy.
#
# TRAVIS: I know, it's thrilling. We need
# eight gallon wine skins or bottles or jugs.
#
# Because the Alchemy Jug can make out eight gallons
# of fresh water. We pour it all out and then at the
#
# end of the day it starts over, so we have eight
# gallons sitting in the bag.
#
# TALIESIN: In theory, we all have water skins,
# don't we?
#
# MARISHA: We should have a spread of our survival
# kits.
#
# LIAM: But all the same, that is a very good idea,
# Grog.
#
# ...
#
# TALIESIN: Come on. 12.
#
# LAURA: You flirted with grass better!
#
# MATT: She goes, "I appreciate your patronage, but
# I am a patient woman, and that is how I hold
#
# "business."
#
# (laughter)
#
# TRAVIS: Stonewalled!
#
# TALIESIN: Keyleth?
#
# MARISHA: Yes?
#
# TALIESIN: I feel like I should have learned some
# sort of lesson here. I'm just not entirely sure
#
# what it was.
#
# MARISHA: Oh, you know--
#
# TALIESIN: Hardly matters, I suppose.
#
# MARISHA: Maybe you'll come to it at the end of
# being in Ank'Harel.
#
# TRAVIS: Hey, guys. I had a thought. You know we
# were all supposed to have a meeting with the king?
#
# And I haven't been paying attention if anyone's
# watching, and we got time to kill. Should we go
#
# have a talk with the big man?
#
# LAURA: Or at least put in for an audience.
#
# TRAVIS: Yeah. Who knows if they'll even get to us
# today?
#
# TALIESIN: I'm sobering up a bit. Which we should
# probably do that.
#
# LAURA: Does it seem like a long walk towards the
# Cerulean Palace?
#
# MATT: Maybe a 45-minute to an hour walk.
#
# LIAM: We've got hours and hours before we have to
# do anything.
#
# TALIESIN: We do. It's 4:00 in the afternoon.
#
# LAURA: What time's the sun set here? Can I ask
# somebody?
#
# MATT: You ask around. It looks to probably be
# about four hours from sunset.
#
# TALIESIN: Perfect.
#
# SAM: All right. Fine. Let's go.
#
# MARISHA: Plus, the best way to see a new city is
# to walk, you guys!
#
# TALIESIN: Wait, hold on. I have to open my
# Pokémon.
#
# MATT: So you guys are making your way towards the
# Cerulean Palace. As you approach the large,
#
# extremely imposing palace, you come upon what
# looks to be an endless series of stairs that
#
# brings you to the upper platform that is the
# central portion of the city where the palace seems
#
# to reside, eventually peaking in the Sandherald
# district that you were referred to earlier as the
#
# location of the palace and where the Bowl of
# Judgment exists. You step up to the very top of
#
# the stairs to find yourself already breathless at
# the sight of the immense purple-blue-colored
#
# palace. A dozen towers reach for the clouds, the
# daylight peeking through their slightly
#
# translucent material, like glassy waters
# ever-frozen in a fall. The central tower, the one
#
# that caught your eye, that ends in a large
# cup-like position, rises above all of them with a
#
# slight spiral-type texture to the outside of the
# palace that is incredibly tall amongst the rest of
#
# the cityscape.
#
# As you get closer, you can see the main palace
# structure presents hundreds of arches pointed at
#
# their apex in its structure, smaller and smaller
# as it recesses further into the palace. Its very
#
# architectural build is a marvel, and seems to both
# have consistency and a chaotic feel to the
#
# placement of some of these arches too, in size.
# It's a very strange but fascinating structure.
#
# You can also see turquoise detailing and trim
# against many of the pillars and carvings and
#
# statues that adorn the exterior of the grounds of
# this palace. As you approach what appear to be the
#
# front gates that ascend, with a very bright blue
# turquoise exterior, close to 50 Hands of Ord
#
# patrol various elements of the grounds around it.
# It looks like there are actual pockets of grass
#
# and gardens that exist around the Cerulean Palace
# in here. The topography changes almost to feel
#
# like it belongs entirely anywhere but the middle
# of the desert. The guards do eye you suspiciously
#
# as you approach, and you watch as one armored
# woman, her dark hair hidden mostly beneath an
#
# ornate helmet of brass and blue, approaches you
# guys. "Welcome to the Cerulean Palace. I must ask
#
# "your business here."
#
# LAURA: Forgive us for our intrusion. We come
# seeking an audience of J'mon Sa Ord.
#
# MATT: "Our emperor does not take meetings. My
# apologies, but I must ask you to leave."
#
# TALIESIN: We are, in fact, a group of ambassadors
# from the continent of Emon, from the cities of--
#
# MARISHA: Continent of Tal'Dorei, city of Emon. It
# concerns the fate of the world.
#
# MATT: Make a persuasion check.
#
# MARISHA: Which one?
#
# TALIESIN: Not that one. That one. See? Listen to
# me. I'm not taking credit for that.
#
# MARISHA: 23. No, 24.
#
# MATT: 24. "Let me inquire with the Grand Maven."
# She turns around, her armor clinking, and walks
#
# back to the palace, leaving you guys there amongst
# these courtyard grounds. A few moments pass before
#
# she returns, the doors opening. As she descends,
# next to her you see an older woman with these
#
# long, ceremonial robes that drag behind her,
# spilling across the stairs as she descends,
#
# seemingly dozens of gemmed bracelets that jingle
# as she walks with each step. She wears a tall
#
# headdress with what looks like brass quills that press
# behind her head and down her back. As she
#
# approaches you all, the woman earlier that you
# spoke to, the Hand that approached you, stays
#
# behind quietly and watches, weapon at the ready.
# The woman steps forward with a smile, and unlike
#
# the abrasive appearance that most of the Hand have
# given, she seems to be more welcoming, and gives, for the
#
# first time since you've been here, a very formal
# welcoming bow with her hand before her, the other
#
# hand out. Says, "Be pleased, everyone."
#
# ALL: Be pleased.
#
# MATT: "I must apologize. We were not aware of your
# arrival here. I am the Grand Maven Gameshega.
#
# "Please, enter and follow me."
#
# TRAVIS: She's the what?
#
# MARISHA: Gameshega?
#
# MATT, LAURA, and LIAM: Gameshega.
#
# MARISHA: Gameshega?
#
# MATT and LIAM: Gameshega.
#
# TALIESIN: This is good. This is very good.
#
# MATT: As she walks past you and the female Hand
# that saw you earlier steps aside and watches you
#
# as you pass, then ends up stepping behind you and
# flanking, keeping a watch from the back as you
#
# guys are led up the final staircase, through the
# front turquoise gates of the Cerulean Palace, and
#
# they close behind you with a resounding (impact),
# the impact echoing through these long halls. From
#
# the interior, massive pointed archways that lead
# down ornately decorated halls that echo with each
#
# footfall that hits across what looks like endless
# white and black bespeckled marble.
#
# She leads you through a series of hallways, more
# Hands walking past, as well as a number of other
#
# robed individuals. What appears to be a central
# chamber that has a number of steps and seats,
#
# where it looks like various philosophers are in
# mid-heated discussion in once again, this same
#
# language that you have not heard on your ears
# before.
#
# You are eventually brought to a very intricate and
# decorated waiting room, with some finely
#
# upholstered silk chairs, couches. The Grand Maven
# stops. "If you would not mind, please have a seat."
#
# TALIESIN: Of course.
#
# SAM: Sure, yeah.
#
# MATT: She walks into a nearby doorway. It looks
# like a single door that leads into a small-looking room,
#
# from the brief moment you have to see it. The door
# closes and you hear a (magic sound). Two minutes
#
# pass. Five minutes pass. Ten eerie, quiet minutes
# pass.
#
# TRAVIS: Windows in this room?
#
# MATT: No windows in this particular room, but you
# notice as you take a close look, the roofs, while
#
# they are built of this deep blue, almost
# glass-like thick crystal, they're ever so slightly
#
# translucent, and it gives this general blue glow
# about the entire room. You can't make out any
#
# details from the outside, but there is this
# strange translucence to the entire structure.
#
# TRAVIS: Was that the only door to the room?
#
# MATT: There is the hallway that you left behind,
# but there standing in the doorway is the same Hand
#
# that approached you guys and has been keeping an
# eye the entire time.
#
# LAURA: He's in the room with us?
#
# MATT: Is away from you, standing in the large
# archway hall that led you into this waiting room.
#
# LAURA: I'm up and pacing the room, trying to pace
# near the door that she went through so I can keep
#
# an ear on the door.
#
# TRAVIS: I walk up to the guard, and I say, sorry.
# I really should have peed before I came in. Is
#
# there a privy I could use?
#
# MATT: She glances at you. "You look like a
# strapping young man. Perhaps you can hold onto
#
# "that for a time."
#
# TRAVIS: It looks that way, but I also have a
# strapping-sized bladder, and I've been known to
#
# leave strapping-sized messes in corners. You see,
# I don't really come from all this finery, so the
#
# side of the wall is just as good with me. It's
# just I'm trying to be polite.
#
# MATT: She leans behind the hallway. (foreign
# language) "Just a moment." Another guard walks up
#
# behind and kicks a bucket into the room.
#
# TRAVIS: That'll do.
#
# LIAM: Put up or shut up.
#
# LAURA: Can I hear anything from the other side of
# the door?
#
# MATT: Make a perception check.
#
# TALIESIN: I'm laughing out loud.
#
# SAM: One?
#
# MATT: You have your ear up against the wall.
#
# LAURA: I didn't want to have my ear against the
# wall. I wanted to be subtly doing it.
#
# MATT: Well, you're subtly doing it, and there's
# nothing. You get closer and closer, and there's
#
# nothing. The rest of you hear (magic sounds), but
# you're still-- Eventually, the door opens again,
#
# and there the Grand Maven stands again. She looks
# up to the rest of you. "Come with me. You have
#
# "been granted an audience." She steps back into the
# chamber.
#
# LAURA: That happened much easier than I expected.
#
# TRAVIS: Thank you for the bucket. I'll hold it.
#
# LAURA: Are you sure, Grog?
#
# LIAM: We were convincing.
#
# SAM: They must know who we are.
#
# TALIESIN: Trust our luck. Our luck is going. I'm
# walking into this.
#
# SAM: Anyone says jenga, kill everyone we meet.
#
# LIAM: It's the only plan we have.
#
# TALIESIN: I'm walking into it.
#
# MARISHA: Yeah.
#
# MATT: You walk into what is a cylindrical chamber
# of smooth blue-purple quartz-like material with
#
# four strands of heavy chains taut between the
# ceiling and floor, about 15 feet above you. No
#
# other exit. You all enter and the door closes
# behind you, the Maven still relaxing, her arms to
#
# her side, her headdress still giving her this
# ominous presence. Looks up, and there's a (impact)
#
# shuddering sound. Suddenly, the bland,
# uncharacteristic walls, compared to the rest of
#
# the palace, begin to slide past the chains, now
# making this rattling sound as the floor itself
#
# seems to be lurching. You feel a bit of pressure
# in the room that wasn't there before. You're all
#
# being lifted, and the walls, now no longer walled
# in by the rest of the palace, you can now see this
#
# occasional traveling-down line as the spiral on
# the outside of the tower you once saw now
#
# surrounds you. The walls are much thinner than the
# rest of the palace, as you can see through this
#
# somewhat-translucent glass exterior the entirety
# of Emon surrounding you from upon high as it goes
#
# lower and lower as you're lifted higher and higher
# into this tower.
#
# LAURA: This is miraculous!
#
# MATT: It's very off-putting, but beautiful at the
# same time. Everything's seen through this
#
# shimmering, somewhat-refracted blue passage. As
# you go higher and higher, you can see the
#
# countless homes, walls, and towers getting smaller
# and smaller, other towers eventually ending as you
#
# go higher in the tower. The Maven says, "I request
# you do not touch the walls, please."
#
# SAM: Okay.
#
# TRAVIS: I really want to touch the walls.
#
# MATT: The view reveals the entirety of the city
# around you, and beyond that, the distant dunes and
#
# the desert that seems to have no end. You view a
# far-off mountainscape a little bit in the northern
#
# direction that just begins to peek past your
# view, then (boom) the floor ceases again. You all
#
# seem to lurch for a moment, yourself, an inch
# before you catch yourself on your feet. The Maven
#
# catches herself, very used to this transition.
#
# You now see behind her, where it has stopped,
# there is another set of doors, similar to the ones
#
# you entered from in the bottom portion of this
# tower. The door opens, (creak) and you can see the
#
# next room is a set of staircases of the same color
# that slowly curl off and disappear upward above you.
#
# "Please, follow me." She walks in, her robe
# dragging behind her. You guys give enough berth
#
# for it to follow. As you're led up the stairway,
# choosing right or left, they both lead to the
#
# upper platform in what is the top of the central
# tower of the Cerulean Palace.
#
# As you enter this room, you see close to a hundred
# dangling silk tapestries from 50 or 60 feet up of
#
# multitudes of different colors; rainbowscapes of
# beautiful translucent cloths and silks, gently
#
# flowing with breezes and mingling and mixing into
# each other around the outside of the wall. High
#
# arched windows on each side, and behind, what
# looks to be a large opening reveals passing clouds
#
# surrounding this height and obfuscating certain
# portions as they meet with the height of this
#
# tower's apex.
#
# You see a large balcony from the opposite side of
# the room that is opened from its own similar-sized
#
# arch that extends outward. It has a railing
# about four feet up that is an opening that
#
# overlooks in open air all above the city to see.
#
# In the center of the chamber, you see a series of
# step-like platforms, circular, that rise up upon
#
# each other, and in the center, you see what seems
# to be a tall throne of bronze and sapphire that
#
# probably sits ten feet up from the base. Thin, but
# extremely long and widens towards the top. You can
#
# see hundreds of sapphires put into and set into
# this shiny, ruddy metallic material that frames
#
# the entirety of the throne.
#
# And there sitting atop this throne, you see a
# slender, human-like entity wearing no jewelry, no
#
# ceremonial adornments, no crown, just a simple
# brown cotton shirt over simple, elegant pants.
#
# Bare feet, no shoes. Androgynous and beautiful;
# you're unable to make out the sex of this
#
# creature. It's not a man, nor elf. Not fey, but
# something somewhat alien, almost. The skin a
#
# deep-set reddish brown, smooth and impeccable. The
# features are extremely fine and delicate. The eyes
#
# are what catch you: black like night, but the
# pupils, burning points of molten metal. The entity
#
# smiles and stands off the throne. Now, at this
# height, seeing it standing almost as tall as Grog,
#
# by comparison. The limbs are elongated. Extends a
# hand towards you as you step into the chamber.
#
# "Welcome to Ank'Harel, heroes of Tal'Dorei. I am
# J'mon Sa Ord, and it is my pleasure to greet you."
#
# And that is where we'll pick up our session in two
# weeks.
#
# LAURA: Oh shit, two weeks.
#
# MATT: Two weeks.
#
# MARISHA: Two weeks.
#
# SAM: Wow, guys. We did a lot of strange things.
#
# MARISHA: Yes, that was a weird day.
#
# TRAVIS: It's the pharaoh king from Stargate.
#
# MATT: Yeah. We have two weeks until we pick up
# from that point in the story. Next week, look
#
# forward once again to Liam running his awesome
# one-shot.
#
# LIAM: I've got a party planned for you!
#
# MATT: It's going to be awesome. It's been fun. But
# anyway, guys, thank you so much. Hope you had a
#
# fun time. Much love to all of you in the
# community. You're awesome; thank you so much for
#
# your support. Thank you for supporting our
# wonderful charities. 826 has been awesome, and
#
# they keep showing up. We saw recently in Target
# ads, actually, which is fantastic, so thank you
#
# guys so much for keeping up with them. You can
# still give them money. You can still support
#
# 826LA, as well as any of the other charities we
# have listed in our Guide to Critmas on the
#
# website. Those are great ways to give and great
# ways to support all of these wonderful people out
#
# there doing wonderful things.
#
# TRAVIS: And thank you, Loot Crate.
#
# MATT: And thank you, Loot Crate, for your support
# of this show and support of our community, giving
#
# them an awesome discount. However, most of us will
# now adjourn to finish signing the posters
#
# forever.
#
# LAURA: Some of us are done.
#
# TALIESIN: Some of us will be doing it until the
# end of time.
#
# MATT: Finishing for a lot of us.
#
# TALIESIN: Are we finishing tonight?
#
# MATT: Finishing this weekend, so they should be
# going out soon to you guys. Thank you for your
#
# patience. The first batch of posters are now out.
# This batch will go out soon.
#
# LIAM: The desert awaits, Matt.
#
# MATT: The desert waits for us, and it is much
# needed. Much love to you all. Have a wonderful
#
# night, and is it Thursday yet?
#
# [music]

# %%
for actor in actorList:
            
    #Find this specific pattern in the text and put into 'matches'
    searchRegex = r"({actor}((, [A-Z]+)?):\s*.*?[A-Z+]:)".format(actor = actor)
#     print(searchRegex)
# Out:
# [("MATT: Hello, everyone, and welcome to tonight's episode of Critical Role, where Taliesin jumps the gun and says his phrase too late. TRAVIS:", '', ''), ("MATT: Welcome. Happy to be back. Very emotional episode last week. We're going to kick it into the next step of Vox Machina's adventure this week, and then, me, Marisha, and Taliesin will be gone next week, so there will not be progression in this current storyline. However, Liam O'Brien over there has been cracking up an awesome one-shot adventure for our remaining players and a few guests. Liam, if you want to talk a little about it? LIAM:", '', ''), ("MATT: Yeah, it's going to be fun. This is Liam's brainchild, and I'm excited to see them play through it. LIAM:", '', ''), ("MATT: I think you'll be fine. If the last game was any indication, I think you'll be fine. All right, other announcements: once again, we have our wonderful sponsor with a new theme kicking in. Sam, you want to take this away? SAM:", '', ''), ('MATT: All right, thank you, Sam. SAM:', '', ''), ("MATT: Perfect. (laughs) All right, other announcements that we have. Let's see. Projects that have come up. They recently announced and put up the English cast video for Final Fantasy XV. I have the pleasure of playing Cor Leonis. It's a lot of fun. As a longtime Final Fantasy fan, being a part of this means a great deal, and I'm excited for the game that comes out in November. So if you haven't checked out the video, do so and you can watch me wax poetic briefly about my love of the series. Look forward to that. MARISHA:", '', ''), ('MATT: Yeah, man! They chose my soundbite for the end of it. I was like (explosion). Felt cool about that. MARISHA:', '', ''), ("MATT: It's like I played a bunch of them. Also, Deus Ex came out. Mankind Divided. I am scattered throughout the game with a very harsh Russian, Eastern European dialect, as many characters, probably yelling at you or being shot in the face. So enjoy that, as well. TRAVIS:", '', ''), ("MATT: Hey, you know? Everyone's got a skillset. Anybody else have anything they want to announce? SAM:", '', ''), ("MATT: That's right! We just got nominated for a Streamy. A Streamy award under gaming. Games. It's awesome! SAM:", '', ''), ('MATT: It is now decided by whatever the Illuminati Streamy committee is. SAM:', '', ''), ("MATT: Love you, Mark. We're just excited to be in that ring. Thank you guys for being so awesome and supporting us, and hopefully some of us will get to dress up fancy and show up and go home proud that we went. TALIESIN:", '', ''), ("MATT: And Muzzled the Musical, which I co-created, which Ashly Burch stars in, who you'll see next week, that got nominated for best indie. MARISHA:", '', ''), ("MATT: It's good. Awesome. Anything else you guys want to talk about? TRAVIS:", '', ''), ('MATT: Anyone else have anything they want to talk about before we jump into the game? TALIESIN:', '', ''), ("MATT: All righty. That being the case, then let's go ahead and hop into tonight's episode of Critical Role. [dramatic music] MATT:", '', ''), ('MATT: All right, so. Vox Machina. Taking your time to mourn in your own interesting ways. What is your path of action? What is your course, going forward? LIAM:', '', ''), ('MATT: Okay. So you\'ve all spent the majority of it in your respective rooms-- most of you in your respective rooms-- figuring out where you are as a person and where this story leads you. After an evening\'s rest, the next morning comes around, breakfast is already prepared by the servants in the castle, though maybe not the amount of bacon you were hoping, and easily rectified upon request. It\'s at your disposal. There is a tension in the city; the barrier remains up. As you\'re having breakfast, you can see Zahra wander in at the smell of bacon, glances over the rest of you, still holding a book at her side that she slams closed. "Oh. I\'m glad to see you\'re all "right, and you\'re safe. Please tell me there\'s more bacon." TRAVIS:', '', ''), (' ...
# [('MARISHA: Soundbiting it up in that. MATT:', '', ''), ("MARISHA: It's like you're an actor. MATT:", '', ''), ('MARISHA: Well, they nominated us, so we got this far because of them, and now we lose to Markiplier. MATT:', '', ''), ("MARISHA: And Sean Becker. Who's my director for Signal Boost. All in the fam. MATT:", '', ''), ('MARISHA: In which particular way do you mean, aside from all of them? LIAM:', '', ''), ("MARISHA: You're talking too much. It's not like I've made myself very accessible either. It's not on you. It might be a little on you, but it's on both of us. Anyway, my point is: for the longest time, I was terrified that I was going to lose you. First to death and then to the Raven Queen, which is still kind of like death, and then ultimately to yourself. And then I had an interesting talk with Pike recently, and she said something that really stood out to me, and that was that some people just have more of themselves to give. And I realized this whole time that I was afraid of losing you to a future that ultimately has not yet been written, which is stupid. LIAM:", '', ''), ("MARISHA: But you're ultimately right. We have nothing to lose. I love you, Vax. And I'm sorry for being me, that it took me this long to say it. LIAM:", '', ''), ('MARISHA: Yeah. Me, too. LIAM:', '', ''), ('MARISHA: That is pretty great, yeah. High five. Yeah! LIAM:', '', ''), ("MARISHA: And that's it for now. SAM:", '', ''), ('MARISHA: Bacon. LAURA:', '', ''), ('MARISHA: Trying to wrangle a beast? TALIESIN:', '', ''), ("MARISHA: And what's our intent in Marquet? To get the next Vestige? TALIESIN:", '', ''), ("MARISHA: Yeah, it's located in Whitestone Castle, correct? The teleport sigil? MATT:", '', ''), ('MARISHA: They said it hunted something really intense recently. LAURA:', '', ''), ('MARISHA: Yeah, they went to the ocean. SAM:', '', ''), ('MARISHA: But I wrote it down. SAM:', '', ''), ('MARISHA: So it wants competition. TALIESIN:', '', ''), ("MARISHA: The Slayer's Take should know. They've got contracts everywhere. SAM:", '', ''), ('MARISHA: We thought about it a little. TALIESIN:', '', ''), ('MARISHA: Wait, are we talking about capturing another dragon to fight another dragon? SAM:', '', ''), ('MARISHA: No more small boys, Percy. No more. LAURA:', '', ''), ('MARISHA: Do they look like townspeople? MATT:', '', ''), ('MARISHA: Any kids? MATT:', '', ''), ('MARISHA: I do want to maybe talk to Gilmore, though. TALIESIN:', '', ''), ("MARISHA: As cynical as Percy is being right now, he's right. LAURA:", '', ''), ("MARISHA: But it doesn't mean that Kashaw is going to think that it's any less important, and I'm sure he might not take it as a compliment if we ask him to be the messenger boy. SAM:", '', ''), ('MARISHA: Yeah, but do we know of any other dragons here? LAURA:', '', ''), ("MARISHA: Let's talk to Kashaw. We go up and we talk to Kashaw. MATT:", '', ''), ('MARISHA: We need a big beast on Draconia. MATT:', '', ''), ('MARISHA: Yeah. See? MATT:', '', ''), ("MARISHA: I'll lend it to them for 100 years. SAM:", '', ''), ("MARISHA: We're basically doing a contract for free. LIAM:", '', ''), ("MARISHA: If they lose, they don't lose anything either, right? LAURA:", '', ''), ("MARISHA: But wouldn't the contract just go right back into cycle? LAURA:", '', ''), ("MARISHA: They're used to having people die. LAURA:", '', ''), ("MARISHA: I think Grog's getting antsy. TALIESIN:", '', ''), ('MARISHA: Hit him in the nuts. LIAM:', '', ''), ('MARISHA: What do you need a writing desk for? TALIESIN:', '', ''), ("MARISHA: Yeah, how's the letter going? TALIESIN:", '', ''), ('MARISHA: Yeah, actually. MATT:', '', ''), ('MARISHA: What? Kashaw? MATT:', '', ''), ("MARISHA: Yeah. We're going to be here the rest of the day, right? SAM:", '', ''), ('MARISHA: Druids. People. Wizards. Sorcerers. SAM:', '', ''), ("MARISHA: All right. Let's go to the Sun Tree. MATT:", '', ''), ('MARISHA: Oh, come on, man. Why are you doing this to me? (laughter) TRAVIS:', '', ''), ('MARIS ...
# [('TRAVIS: Way too late, man! Way too late! MATT:', '', ''), ('TRAVIS: I love shooting you in the face. MATT:', '', ''), ("TRAVIS: Yes! In the world of sportsball, the 2016 future Super Bowl champion Dallas Cowboys are playing the Seattle Seahawks right now! So if you see me looking down, it's not because I'm not paying attention. I'm watching football. TALIESIN:", '', ''), ("TRAVIS: Everybody send Sam a tweet. He's going to be crying at the outset of his team. Sam, a moment of silence. TALIESIN:", '', ''), ('TRAVIS: (laughing) Pan to the fireplace! MATT:', '', ''), ('TRAVIS: Not for long. LAURA:', '', ''), ('TRAVIS: What she said. MATT:', '', ''), ("TRAVIS: Yep, we've got it covered. It's planned out to a T. LAURA:", '', ''), ('TRAVIS: Can you put it in your necklace? SAM:', '', ''), ('TRAVIS: I think Kashaw is a great people-person. TALIESIN:', '', ''), ('TRAVIS: No, we bring the dragon to the creature. SAM:', '', ''), ("TRAVIS: You can't broker a fight between a huge beast and a white dragon? TALIESIN:", '', ''), ("TRAVIS: I think you've done better. LIAM:", '', ''), ('TRAVIS: Can we go somewhere in the next 60 seconds? LAURA:', '', ''), ('TRAVIS: We have 64 pounds of scales from me. We have four claws left. SAM:', '', ''), ('TRAVIS: And we got umber hulk pieces, too. TALIESIN:', '', ''), ('TRAVIS: Yes! MATT:', '', ''), ('TRAVIS: What, train them? MATT:', '', ''), ('TRAVIS: Like when a doctor hits you and your knee jumps? MATT:', '', ''), ('TRAVIS: Do you have a death wish? LIAM:', '', ''), ('TRAVIS: What am I missing here? TALIESIN:', '', ''), ('TRAVIS: I take the Gauntlets and I smash them together, and I grow in size. (laughter) MATT:', '', ''), ('TRAVIS: Yes. SAM:', '', ''), ('TRAVIS: I look at Vax and I go, you were just playing around, right? LIAM:', '', ''), ("TRAVIS: And in my giant state, I'm going to kick him like a soccer ball. LIAM:", '', ''), ("TRAVIS: That's good. 32. LIAM:", '', ''), ('TRAVIS: 15 on the strength check. 25. LIAM:', '', ''), ('TRAVIS: 24. LIAM:', '', ''), ('TRAVIS: The strength was 24. MATT:', '', ''), ('TRAVIS: Seven. MATT:', '', ''), ("TRAVIS: Can I check the Titanstone Knuckles? Have they changed now that I've kicked a friend in the face? MATT:", '', ''), ('TRAVIS: Damn it! Eight. MATT:', '', ''), ('TRAVIS: (chuckles) LIAM:', '', ''), ('TRAVIS: Thank you. I was getting so bored. LIAM:', '', ''), ('TRAVIS: Thanks, bubby. TALIESIN:', '', ''), ('TRAVIS: Good addendum. Whatever that word is. LIAM:', '', ''), ("TRAVIS: Hold on, it's going to happen. Let it happen. MATT:", '', ''), ("TRAVIS: He's got to use the privy at some point. SAM:", '', ''), ('TRAVIS: We got loads. MATT:', '', ''), ('TRAVIS: Hey, I have an idea. SAM:', '', ''), ("TRAVIS: I know, it's thrilling. We need eight gallon wine skins or bottles or jugs. Because the Alchemy Jug can make out eight gallons of fresh water. We pour it all out and then at the end of the day it starts over, so we have eight gallons sitting in the bag. TALIESIN:", '', ''), ('TRAVIS: Yeah, eight gallons. SAM:', '', ''), ('TRAVIS: Yeah, we could give it away, give it away, give it away now. LAURA:', '', ''), ('TRAVIS: (coughing) Bullshit. LAURA:', '', ''), ('TRAVIS: Perpetual oasis. MATT:', '', ''), ('TRAVIS: Source of power. (laughter) SAM:', '', ''), ('TRAVIS: Beep-bleep. LIAM:', '', ''), ('TRAVIS: Is it for food? MATT:', '', ''), ('TRAVIS: To market! SAM:', '', ''), ("TRAVIS: There's no stores. MATT:", '', ''), ('TRAVIS: One for each? TALIESIN:', '', ''), ('TRAVIS: Are we going? LIAM and TALIESIN:', '', ''), ('TRAVIS: Oh yeah, no problem. MATT:', '', ''), ('TRAVIS: Running through! LAURA:', '', ''), ('TRAVIS: Oh shitballs. I have to move. MARISHA:', '', ''), ('TRAVIS: Ten-ten, halftime. MARISHA:', '', ''), ('TRAVIS: No, not good. TALIESIN:', '', ''), ('TRAVIS: Their starting quarterback got hurt. TALIESIN:', '', ''), ("TRAVIS: Because he's an old woman. TALIESIN:", '', ''), ("TRAVIS: That's what I was going with that! LAURA:", '', ''), ("TRAVIS: It's okay. ...
# [("LAURA: It's got Futurama stuff on it. SAM:", '', ''), ("LAURA: But it's not. Fans don't get to vote. MATT:", '', ''), ('LAURA: More than it was. TRAVIS:', '', ''), ("LAURA: Sam walked away so he wouldn't be on the same set as you were saying that. MATT:", '', ''), ('LAURA: Oh! LIAM:', '', ''), ('LAURA: Yeah, I think we need to spend at least the night in Whitestone and get up in the morning. MATT:', '', ''), ("LAURA: There's more coming, dear. TRAVIS:", '', ''), ("LAURA: Sorry you can't be out having your fun, dear. MATT:", '', ''), ("LAURA: Maybe we can stop through on our way back. We are going to Marquet, aren't we? TALIESIN:", '', ''), ("LAURA: Gilmore. Gilmore's from Marquet. TALIESIN:", '', ''), ("LAURA: It's up. As long as the dragon's not here and attacking. MATT:", '', ''), ('LAURA: How are we even going to get a beast? TALIESIN:', '', ''), ('LAURA: I think a large enough beast to attract Vorugal. SAM:', '', ''), ('LAURA: He said they hunted remorhaz? MARISHA:', '', ''), ('LAURA: Oh. Those are big and scary. SAM:', '', ''), ('LAURA: And Vorugal will go to the creature. TALIESIN:', '', ''), ("LAURA: I know, because I'm an expert. LIAM:", '', ''), ("LAURA: We could ask Zahra, but she's busy with research. TRAVIS:", '', ''), ("LAURA: Yeah. Let's go find Kashaw. MATT:", '', ''), ('LAURA: Did we ever talk to Cassandra or anyone else about starting an alarm system here? SAM:', '', ''), ("LAURA: Maybe he's not the best messenger if he's training our armies. TALIESIN:", '', ''), ('LAURA: All right. MARISHA:', '', ''), ("LAURA: It's not just a messenger, it's defeating a dragon. TALIESIN:", '', ''), ('LAURA: No, we take a contract on a really large creature, and then we let the dragon do the work for us. We get the best of both worlds. TALIESIN:', '', ''), ("LAURA: He hunts them. That's what he does. SAM:", '', ''), ("LAURA: Well, then we're going to have to fucking go to the Slayer's Take. TRAVIS:", '', ''), ("LAURA: This'll be great. MARISHA:", '', ''), ('LAURA: And Vanessa really likes you. TALIESIN:', '', ''), ('LAURA: Thank you. TALIESIN:', '', ''), ('LAURA: We have 40 pounds of dragonhide. Black dragonhide. TALIESIN:', '', ''), ("LAURA: We don't have white dragonhide. TALIESIN:", '', ''), ("LAURA: No, that's Keyleth's, remember? In the next century, when she's still living. SAM:", '', ''), ('LAURA: No, they do. They lose a contract. MARISHA:', '', ''), ("LAURA: No, if the dragon kills the creature and then we all die and we can't harvest it, the Slayer's Take doesn't have anything from its previous contract. LIAM:", '', ''), ('LAURA: Well, fuck it. MARISHA:', '', ''), ('LAURA: While all this is going on, Grog, you could be training these soldiers. LIAM:', '', ''), ('LAURA: Seriously? SAM:', '', ''), ("LAURA: Don't kill them, Grog! MATT:", '', ''), ("LAURA: Hey bonus, he's on our side. Eh? That's encouraging. MATT:", '', ''), ('LAURA: Yeah? LIAM:', '', ''), ("LAURA: Don't you have wings? LIAM:", '', ''), ('LAURA: Yes. And make sure to include that this must all be completed within 14 days. SAM:', '', ''), ("LAURA: Yes, that's what he said. TALIESIN:", '', ''), ("LAURA: That's part of that listening thing, Scanlan. SAM:", '', ''), ('LAURA: Kashaw. No mention of Whitestone at all. Anywhere you go. Very important. TRAVIS:', '', ''), ('LAURA: Do we have a way to get him there very quickly? MARISHA:', '', ''), ("LAURA: He's a really smart man. TALIESIN:", '', ''), ("LAURA: Yeah, but then he'll pop where we are. TALIESIN:", '', ''), ("LAURA: Don't worry about it. SAM:", '', ''), ("LAURA: Don't you want to walk with them? LIAM:", '', ''), ("LAURA: So now that that's handled, are we leaving today? TALIESIN:", '', ''), ("LAURA: We've got a limited amount of time on this. MATT:", '', ''), ('LAURA: Did it sound like anyone we knew? MATT:', '', ''), ('LAURA: Is everything okay? MATT:', '', ''), ('LAURA: How are you holding up, Gilmore? MATT:', '', ''), ('LAURA: Oh! You got a whisper on a 15. SAM:', '', ''), ("LAURA: Actually, the  ...
# [("SAM: Yes, I do, Matt Mercer. Guys: Loot Crate. Loot Crate has been such a great sponsor all year long, and we got another great week to share with you. Speed is this month's theme of the Loot Crate. I'm going to read this script first. Lace up your sneakers or rev your engines. September's all about speed. Feel the adrenaline with some of pop culture's quickest vehicles and characters. High-octane assortment of goodies from Batman, the Flash, the Arrow, the Battlestar Galactica, the Iron Man, the Gone in the Sixty the Seconds. (laughter) SAM:", '', ''), ("SAM: Guys, I'm an actor. Why would you listen to me about this stuff? I'm a liar and a deceiver. But what you can listen to, and what you know in your heart, is hardcore facts. I'm talking statistics. I'm talking math. I've broken this down for you guys. If you use the promo-code CriticalRole, you'll get $3 off your first month. Doesn't sound like a lot, you think? Oh, that's 1.2 gallons of gas at the Quik Mart down the street. Regular, unleaded. Or let's say you're generous. You give Loot Crates to everyone in your family. That's four Loot Crates; that's $12. That is 25 and half Forever stamps that you've just gotten for free. For free! Let's say you're more generous than that. You give Loot Crates to everyone in your whole company. All 266 employees. You've just saved enough money to buy a 2002 Kia Sedona with 181,000 miles on it. The transmission is going out, and it doesn't shift in the higher gears, but it is for $800 on Craigslist. Go look for it right now, and it will be yours for free, essentially, if you buy 266 subscriptions to Loot Crate. 266.67. Okay, that is hardcore facts. You can't argue with that. Go out. Subscribe now. Save money. Get stamps and gas. LIAM:", '', ''), ("SAM: Don't forget to use the promo code CriticalRole. MATT:", '', ''), ("SAM: We're nominated for an award, Matt. MATT:", '', ''), ("SAM: It's our first nomination. TALIESIN:", '', ''), ("SAM: Wait, fans don't get to vote? I'm sure they can influence things. MARISHA:", '', ''), ('SAM: Pan to the fireplace. TRAVIS:', '', ''), ("SAM: Yeah, but he's concentrating on the defensive wall right now. LAURA:", '', ''), ('SAM: That would be awesome. TALIESIN:', '', ''), ("SAM: Before we go to Marquet. Let's say Marquet takes 13 days. TALIESIN:", '', ''), ("SAM: I agree, but let's say it does. Do we know what we're doing with regards to Draconia when we come back? Do we have some sort of a plan? We're getting a beast. That's all we know. TRAVIS:", '', ''), ('SAM: What constitutes a beast? Because me and Keyleth can make some beasts. LAURA:', '', ''), ('SAM: Like a triceratops? TALIESIN:', '', ''), ('SAM: What is that? MATT:', '', ''), ('SAM: For me. Ooh, a 19! Plus two. MATT:', '', ''), ('SAM: Is it a gargantuan monster? MATT:', '', ''), ('SAM: And it was bored with that? TALIESIN:', '', ''), ('SAM: And how are we going to get this creature there? TALIESIN:', '', ''), ('SAM: On the continent. What continent? The Draconian continent? TALIESIN:', '', ''), ('SAM: So we have to go back there to search! MARISHA:', '', ''), ('SAM: All right. This is slightly a better plan than I thought. MARISHA:', '', ''), ("SAM: Then we should go talk to the Slayer's Take now so they can get started on this hunt. TALIESIN:", '', ''), ('SAM: A letter?! TALIESIN:', '', ''), ("SAM: Who's the letter carrier and how's he going to get out of this city that's protected by an invisible wall? TALIESIN:", '', ''), ("SAM: No, we're talking about convincing a dragon to go fight this dragon that would clearly kill it. TALIESIN:", '', ''), ('SAM: Wait, is there anyone else who can make this message delivery faster or safer? TALIESIN:', '', ''), ('SAM: No, but faster and safer. TALIESIN:', '', ''), ('SAM: All right. LIAM:', '', ''), ('SAM: Strapping boys? TALIESIN:', '', ''), ("SAM: Yeah, and they were working on it already, weren't they? TALIESIN:", '', ''), ("SAM: I think it's done. TALIESIN:", '', ''), ("SAM: It's an incredibly import ...
# [("LIAM: Yeah, I'll tell you who's coming on by. Sure, I'll say who's coming on by. Mary Elizabeth McGlynn and Ashly Burch. And I don't want to spoil it, but Matt knows. It's different. MATT:", '', ''), ('LIAM: It could blow up in my face. MATT:', '', ''), ("LIAM: If you don't slow your roll, Loot Crate is going to poach you. MATT:", '', ''), ("LIAM: Taking the initiative. This one came to my room, then inside. I think we've probably been quiet for a while, staring at the ceiling, and after a while finally say: We've really fucked things up, haven't we? MARISHA:", '', ''), ("LIAM: I need to tell you. I know with all that's happened, between my new patron and my sister pretending to gag literally every time we attempt to share a word together, and mostly my own being fucked up in the head for weeks now, that I've pushed all of you away. You most of all. Because I've been afraid you would-- I'm sorry. And you didn't deserve any of that. Keyleth, I need you to know, through all of that, everything, nothing has changed about how I-- We've had so many near-misses. And now, finding Tiberius. Death is unavoidable. And it's all the more reason for life to be lived. And it doesn't matter to me what this is. What we call it. If you are willing to spend some time, any time, with me, then I will simply count myself lucky to have it. You're very dear to me. MARISHA:", '', ''), ('LIAM: Maybe so. MARISHA:', '', ''), ("LIAM: (sniffles) I'm sorry. MARISHA:", '', ''), ("LIAM: I love you. That's pretty fucking great. MARISHA:", '', ''), ('LIAM: I tackle her into a bit of a hug into the bed. LAURA:', '', ''), ("LIAM: We're already on the bed. MARISHA:", '', ''), ('LIAM: Sleeping in. MARISHA:', '', ''), ('LIAM: And the means of travel is? TALIESIN:', '', ''), ("LIAM: When we were last there, hadn't they talked about a brass or bronze dragon? But there are brass dragons, as you well know. LAURA:", '', ''), ("LIAM: Is that overkill? We'd have to convince a dragon, not capture a dragon. TALIESIN:", '', ''), ('LIAM: He wants to help. He does. LAURA:', '', ''), ("LIAM: We don't necessarily have to sacrifice a dragon. We're fighting a war here. They're fuckers. SAM:", '', ''), ("LIAM: Well, I'm talking about a dragon. Couldn't we try to talk a dragon into helping us do what we're doing? They're not all evil, are they? They're not! MARISHA:", '', ''), ("LIAM: We don't have the troll dick anymore. That's gone. LAURA:", '', ''), ('LIAM: I was about to say, yeah, we put into the contract that it has the remains of the beast we take down, which we will take down. TALIESIN:', '', ''), ('LIAM: Sure, as a souvenir, right. Yes. MARISHA:', '', ''), ("LIAM: It's a very large creature. SAM:", '', ''), ('LIAM: But that could happen with any contract. Any band of idiots could go die on the battlefield. MARISHA:', '', ''), ("LIAM: I look at Grog and see he's really bored. I pick up a wooden sword and I hit him as hard as I can on the small of his back. TRAVIS:", '', ''), ("LIAM: It's not going to be that hard. LAURA:", '', ''), ('LIAM: 17. TRAVIS:', '', ''), ("LIAM: Come on, big guy! I know you're bored! Come on! I hit him again. MATT:", '', ''), ("LIAM: Okay, cool. That's a 20. Oh! But it's with a stick! Just strength modifier? MATT:", '', ''), ("LIAM: Oh dear. I'm going to use Luck. 14. MATT:", '', ''), ('LIAM: I missed the nut? Ugh. Come on! TRAVIS:', '', ''), ("LIAM: Come on, take a swing! I'm trying to do you a favor! Come on, get it out! TRAVIS:", '', ''), ('LIAM: I see a gauntlet on a table, and I throw it at his face. MATT:', '', ''), ("LIAM: It's a one! (laughter) SAM:", '', ''), ('LIAM: Yes. TRAVIS:', '', ''), ("LIAM: I'm going to dodge. Uncanny Dodge, man. MATT:", '', ''), ("LIAM: Ooh. No, I didn't miss that. MATT:", '', ''), ("LIAM: Wait, I'm going to use another Luck and make him roll again and pick the lower of the two. MATT:", '', ''), ('LIAM: Got to roll again for the hit. MATT:', '', ''), ('LIAM: That hits. MATT:', '', ''), ('LIAM: Uncanny Dodge! MATT ...

# %%
df.head()
# Out:
#               file                                         transcript
# 0     C1E001_FINAL  Matt: Hello everyone. My name is Matthew Merce...
# 1  C1E001_FINAL_V2  MATT: Hello everyone. My name is Matthew Merce...
# 2     C1E002_FINAL  MATT: Hello everyone, and welcome\nto the seco...
# 3     C1E003_FINAL  MATT: Hey, everyone. Sorry about that little i...
# 4     C1E004_FINAL  MATT: Everyone, welcome to the new\nepisode of...

# %%
folder = 'FINAL TEXT FILES'

transcriptDict = dict()

for path in pathlib.Path(folder).iterdir():
    if path.is_file():

        print(path.stem)
        current_file = open(path, "r", encoding = 'utf8')

        transcriptDict[path.stem] = current_file.read()
#         print(current_file.read())
        current_file.close()
# Out:
# C1E001_FINAL
# C1E001_FINAL_V2
# C1E002_FINAL
# C1E003_FINAL
# C1E004_FINAL
# C1E005_FINAL
# C1E006_FINAL
# C1E007_FINAL
# C1E008_FINAL
# C1E009_FINAL
# C1E010_FINAL
# C1E011_FINAL
# C1E012_FINAL
# C1E013_FINAL
# C1E014_FINAL
# C1E015-FINAL
# C1E015_FINAL
# C1E016_FINAL
# C1E017_FINAL
# C1E018_FINAL
# C1E019_FINAL
# C1E020_FINAL
# C1E021_FINAL
# C1E022_FINAL
# C1E023_FINAL
# C1E024_FINAL
# C1E025_FINAL
# C1E026_FINAL
# C1E027_FINAL
# C1E028_FINAL
# C1E029_FINAL
# C1E030_FINAL
# C1E031-1_FINAL
# C1E031-2_FINAL
# C1E032_FINAL
# C1E033-1_FINAL
# C1E033-2_FINAL
# C1E034_FINAL
# C1E035-1_FINAL
# C1E035-2_FINAL
# C1E036_FINAL
# C1E037_FINAL
# C1E038_FINAL
# C1E039_FINAL
# C1E040_FINAL
# C1E041_FINAL
# C1E042_FINAL
# C1E043_FINAL
# C1E044_FINAL
# C1E045_FINAL
# C1E046_FINAL
# C1E047_FINAL
# C1E048_FINAL
# C1E049-5_FINAL
# C1E049_FINAL
# C1E050_FINAL
# C1E051_FINAL
# C1E052_FINAL
# C1E053_FINAL
# C1E054_FINAL
# C1E055_FINAL
# C1E056_FINAL
# C1E057_FINAL
# C1E058-5_FINAL
# C1E058_FINAL
# C1E059_FINAL
# C1E060_FINAL
# C1E061_FINAL
# C1E062_FINAL
# C1E063_FINAL
# C1E064_FINAL
# C1E065-5_FINAL
# C1E065_FINAL
# C1E066_FINAL
# C1E067_FINAL
# C1E068_FINAL
# C1E069_FINAL
# C1E070_FINAL
# C1E071_FINAL
# C1E072_FINAL
# C1E073_FINAL
# C1E074_FINAL
# C1E075_FINAL
# C1E076_FINAL
# C1E077_FINAL
# C1E078_FINAL
# C1E079_FINAL
# C1E080_FINAL
# C1E081_FINAL
# C1E082_FINAL
# C1E083_FINAL
# C1E084_FINAL
# C1E085_FINAL
# C1E086_FINAL
# C1E087_FINAL
# C1E088_FINAL
# C1E089_FINAL
# C1E090_FINAL
# C1E091_FINAL
# C1E092_FINAL
# C1E093_FINAL
# C1E094.5_FINAL
# C1E094_FINAL
# C1E095_FINAL
# C1E096_FINAL
# C1E097_FINAL
# C1E098-5_FINAL
# C1E098_FINAL
# C1E099_FINAL
# C1E100_FINAL
# C1E101_FINAL
# C1E102_FINAL
# C1E103_FINAL
# C1E104_FINAL
# C1E105_FINAL
# C1E106_FINAL
# C1E107_FINAL
# C1E108_FINAL
# C1E109_FINAL
# C1E110-5_FINAL
# C1E110_FINAL
# C1E111_FINAL
# C1E112_FINAL
# C1E113-1_FINAL
# C1E113-2_FINAL
# C1E113_FINAL
# C1E114_FINAL
# C1E115-GROG_FINAL
# C1E115-HH_FINAL
# C1E115-VAMP1_FINAL
# C1E115-VAMP2_FINAL
# C1E115_FINAL
# C2E001_FINAL
# C2E002_FINAL
# C2E003_FINAL
# C2E004_FINAL
# C2E005_FINAL
# C2E006_FINAL
# C2E007_FINAL
# C2E008_FINAL
# C2E009_FINAL
# C2E010_FINAL
# C2E011_FINAL
# C2E012_FINAL.en
# C2E013_FINAL
# C2E014_FINAL
# C2E015_FINAL
# C2E016_FINAL
# C2E017_FINAL
# C2E018_FINAL
# C2E019_FINAL
# C2E020_FINAL
# C2E021_FINAL
# C2E022_FINAL
# C2E023_FINAL
# C2E024_FINAL
# C2E025_FINAL
# C2E026_FINAL
# C2E027_FINAL
# C2E028_FINAL
# C2E029_FINAL
# C2E030_FINAL
# C2E031_FINAL
# C2E032_FINAL
# C2E033_FINAL
# C2E034_FINAL
# C2E035_FINAL
# C2E036_FINAL
# C2E037_REVISED
# C2E038_FINAL
# C2E039_FINAL
# C2E040_FINAL
# C2E041_FINAL
# C2E042_FINAL
# C2E043_FINAL
# C2E043_FINAL
# C2E044_FINAL
# C2E044_FINAL
# C2E045_FINAL
# C2E046_FINAL
# C2E047.en
# C2E048.en
# C2E049.en
# C2E050.en
# CR-Extras_FiresideChat_FINAL
# CR-Extras_GMTips4
# CR-Extra_ClubOfMisfits.en
# CR-Extra_Critical Role Live at Comic-Con 2015
# CR-Extra_Critical Role Q_A Feb 2016
# CR-Extra_Critical Trolls for Extra Life.en
# CR-Extra_CR_Tarot_promotion_FINAL.en
# CR-Extra_Deadlands One-Shot for MDA Charity.en
# CR-Extra_DND-Beyond-trailer
# CR-Extra_DnDiesel
# CR-Extra_Episode 4 12 Dance Party
# CR-Extra_GMTips 14
# CR-Extra_GMTips12
# CR-Extra_GMTips8
# CR-Extra_Hearthstone One-Shot
# CR-Extra_Honey Heist 2 Electric Beargaloo.en
# CR-Extra_M9-Intro
# CR-Extra_One-Shot Epic Level Battle Royale
# CR-Extra_One-Shot Once Upon a Fairytale Cruise
# CR-Extra_Pants Optional Critmas
# CR-Extra_perfume.en
# CR-Extra_RPG Show QA and Battle Royale.en
# CR-Extra_songofthelorelei
# CR-Extra_sorcerers-lair
# CR-Extra_Talks Machina Campaign Wrap-up
# CR-Extra_Talks Machina Fireside Chat
# CR-Extra_Talks Machina Live From Wonder-Con
# CR-Extra_Talks Machina Live SDCC 2017
# CR-Scope_Behind-The-Scenes Critical Role Pathfinder Oneshot Ivan Van Norman Periscope.en
# CR-Scope_Beyond Critical Role  MomoCon 2017 with Matt Marisha Taliesin  Brian Spoilers E98.en
# CR-Scope_Critical Role Panel  TEKKO Pittsburgh PA 2016-04-08 SPOILERS E48.en
# CR-Scope_Critical Role panel w Matt Mercer  Marisha Ray  HAVEN Mackay Australia 2016-07-02 Spoilers E58.en
# CR-Scope_Critical Role panel with Matt Laura Travis  Marisha  GenCon 2016 Spoilers E61.en
# CR-Scope_Critical Role panel with Matt Mercer 4k  HD Sound  OTAFEST Calgary Spoilers C2E019.en
# CR-Scope_Critical Role RPGs  Tabletop Renaissance w Matt Mercer  Paradise City Comic Con SPOILERS C2E1.en
# CR-Scope_Critical Role Talks Machina style w Matt Taliesin Laura Sam  GenCon2017 SPOILERS E108.en
# CR-Scope_Critical Role Talks Machina Style with Matt Marisha Taliesin  Brian  MomoCon 2017 Spoilers E98.en
# CR-Scope_Critical Roles Critmas Talks Machina.en
# CR-Scope_Critical Roles Impromptu QA during technical difficulties at GeekSundry Spoilers E50.en
# CR-Scope_Critical Roles Matthew Mercer  Marisha Ray 2015 11 26 Part 1 of 4 SPOILERS E33.en
# CR-Scope_Critical Roles Matthew Mercer  Marisha Ray 2015 11 26 Part 3 of 4 SPOILERS E33.en
# CR-Scope_Critical Roles Matthew Mercer  Marisha Ray 2015 11 26 Part 4 of 4 SPOILERS E33.en
# CR-Scope_Full Post 2016 Holiday Critmas gifts  hangout w Marisha Matt Taliesin  Brian SPOILERS E81.en
# CR-Scope_Liam  Travis secret plan to win the fight in E52 Spoilers E52.en
# CR-Scope_Liam Obriens first time on Periscope - QA SPOILERS E37.en
# CR-Scope_Liam OBriens missing Periscope  QA 2016-04-27 Spoilers E50.en
# CR-Scope_Matt  Marisha at MAGfest 2017 Maryland Spoilers E80.en
# CR-Scope_Matthew Mercer  Marisha Ray - The Vestiges of Critmas Unpacking  QA  Home Spoilers E51.en
# CR-Scope_Matthew Mercer E52 Impromptu Post-game discussion Spoilers E52.en
# CR-Scope_momocon
# CR-Scope_panel w Matt Marisha Laura  Travis  AnimeMilwaukee 2017 Spoilers E86.en
# CR-Scope_Panel with Matt  Taliesin  Another Anime Con 2016 Manchester NH Spoilers E71.en
# CR-Scope_Part 2 of Matthew Mercer  Marisha Rays Post-Critmas Mini Unboxing  Gen thank you Spoilers E41.en
# CR-Scope_Percy  Taliesin Jaffes first Periscope - QA 2015-11-19 RE UPLOAD SPOILERS E32.en
# CR-Scope_Short Periscope before the start of Critical Role E54 Spoilers E54.en
# CR-Scope_UPDATED Critical Role Panel  WonderCon LA Full Length SPOILERS E46.en
# CR-Scope_Wizard World Portland Day 1.en
# Honey Heist 3 Tovas Honeys.en
# zcharacter-backgrounds_FINAL
# zEP125_FINAL
# zGM-TIPS_1
# zstory-of-VM_captions
# ztwitter_description
